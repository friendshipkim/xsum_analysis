# %% [markdown]
# # Load datasets
# ---

# %%
import datasets
from xsum_dataset import XsumDataset

# %%
xsum_data_raw = datasets.load_dataset("xsum")
# Out:
# Using custom data configuration default
# Reusing dataset xsum (/home/wk247/.cache/huggingface/datasets/xsum/default/1.2.0/32c23220eadddb1149b16ed2e9430a05293768cfffbdfd151058697d4c11f934)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# train/val/test data
# xsum_train_data = XsumDataset(xsum_data_raw["train"])
xsum_val_data = XsumDataset(xsum_data_raw["validation"])
xsum_test_data = XsumDataset(xsum_data_raw["test"])

# %% [markdown]
# # concat data
# xsum_data_raw_cc = datasets.concatenate_datasets(
#     [xsum_data_raw["train"], xsum_data_raw["validation"], xsum_data_raw["test"]]
#     )
# xsum_concat_data = XsumDataset(xsum_data_raw_cc)

# %% [markdown]
# ## select a sample

# %%
from generate_xsum_summary import load_summarization_model_and_tokenizer, generate_summaries, generate_token_entropy_metadata
import random

random.seed(0)

# %% [markdown]
# ### * one to be perturbed

# %%
# sample one bbcid
bbc_id = random.choice(list(xsum_test_data.data_by_id.keys()))
# or fix one: bbc_ids = ["33858956"]
bbc_id
# Out:
# '35616768'

# %%
# selected_data - dict with keys: (id, document, true_summary, (factuality_data, faithfulness_data))
selected_data = xsum_test_data.data_by_id[bbc_id]

# original_docs - documents to sumamrize
original_doc = selected_data["document"]
print("original doc to summarize:\n", original_doc)
# Out:
# original doc to summarize:
#  The agreement, reached late on Friday after two days of talks in Brussels, gives the UK power to limit some EU migrants' benefits.
# It also includes a treaty change so the UK is not bound to "ever closer union" with other EU member states, he said.
# EU exit campaigners said the "hollow" deal offered only "very minor changes".
# Mr Cameron is set to the announce the date of a referendum on whether Britain should remain in the EU after a cabinet meeting which is happening at 10:00 GMT - the referendum is widely expected to be on Thursday, 23 June.
# Once the date is announced, ministers will be allowed to campaign for whichever side they want - one of Mr Cameron's closest political allies Michael Gove has already been named as supporting the Leave camp. Others, such as Iain Duncan Smith are expected to follow - but a question mark remains over which way London Mayor Boris Johnson will jump.
# The key points of the deal are:
# The prime minster had to make concessions to get a deal with the leaders of the 27 other EU members.
# Mr Cameron had originally wanted a complete ban on migrants sending child benefit abroad but had to compromise after some eastern European states rejected that and also insisted that existing claimants should continue to receive the full payment.
# On how long the UK would be able to have a four-year curb on in-work benefits for new arrivals,  Mr Cameron had to give way on hopes of it being in place for 13 years, settling for seven instead.
# The agreement on renegotiating the UK's EU membership was announced by European Council president Donald Tusk, who tweeted: "Deal. Unanimous support for new settlement for #UKinEU."
# German Chancellor Angela Merkel predicted the package of reforms would "elicit support in the UK for the country to remain in the EU".
# Mr Tusk said it "strengthens Britain's special status", while EU Commission president Jean-Claude Juncker described it as "fair".
# Mr Tusk added: "We didn't walk away from the negotiating table. We were willing to sacrifice part of our interests for the common good, to show our unity.
# "I deeply believe the UK needs Europe and Europe needs the UK. But the final decision is in the hands of the British people."
# The ink is hardly dry on the UK's EU deal, but immediately the focus has switched to the substance of what David Cameron has achieved and - possibly an awkward question - how many of his colleagues will argue against him.
# The focus will move to whether the prime minister can keep his party politely together during a period of public disagreement.
# The ability to restrict benefits to migrants is an important victory for Mr Cameron - ammunition for his argument that he has achieved changes to help reduce the number of EU migrants coming to live and work in the UK.
# The proposals are complicated and do not exactly match the promises he made in the Conservative Party manifesto.
# But with it - and the other commitments - it becomes harder for his critics to make the case that the agreement is flimsy and will change nothing.
# Read more from Laura
# Mr Cameron said he had achieved the reforms he wanted, claiming they would put the UK "in the driving seat" of one of the world's biggest markets and create a "more flexible" EU.
# "We have permanently protected the pound and our right to keep it," he added, saying that, for the first time, the EU "has explicitly acknowledged it has more than one currency".
# The prime minister said he had also protected Britain from further political integration inside the EU, adding: "Let me put this as simply as I can: Britain will never be part of a European superstate."
# Outlining his case to remain "in a reformed Europe", Mr Cameron said "turning our back on the EU is no solution at all".
# "We should be suspicious of those who claim that leaving Europe is an automatic fast-track to a land of milk and honey," he added.
# "The British people must now decide whether to stay in this reformed European Union or to leave. This will be a once-in-a-generation moment to shape the destiny of our country."
# Labour leader Jeremy Corbyn dismissed Mr Cameron's deal as a "sideshow" designed to "appease his opponents in the Conservative Party," adding that he had done nothing to protect jobs and fight low pay.
# "We will be campaigning to keep Britain in Europe in the coming referendum, regardless of David Cameron's tinkering, because it brings investment, jobs and protection for British workers and consumers," he said.
# Scotland's First Minister Nicola Sturgeon said it was now "more important than ever" that those who supported Scotland's continued EU membership made the case "as strongly as possible".
# Eurosceptics have dismissed the reforms, saying they will not allow the UK to block unwanted EU laws or reduce migration.
# Matthew Elliott, chief executive of the Vote Leave campaign, said Mr Cameron "will now declare victory but it is an entirely hollow one".
# UKIP leader Nigel Farage tweeted: "This is a truly pathetic deal. Let's Leave the EU, control our borders, run our own country and stop handing Â£55m every day to Brussels. I believe in Britain. We are good enough to be an independent, self-governing nation outside of the EU. This is our golden opportunity."
# As the EU summit was being concluded, another EU exit campaign, Grassroots Out, held a rally in Westminster.
# Conservative MP David Davis said it was time for Britain "to take  control of its own destiny", while UKIP leader Nigel Farage said the cross-party campaign was "absolutely united in fighting to get back our democracy".
# Mr Farage unveiled former Respect MP George Galloway as a "special guest" at the rally, describing him as a "towering figure on the left of British politics".

# %% [markdown]
# ### *one to perturb

# %%
import random

# %%
# sample one bbcid
ptb_id = random.choice(xsum_val_data.ids)
print("ptb_id:", ptb_id)
# Out:
# ptb_id: 29703870

# %%
# selected_data - dict with keys: (id, document, true_summary, (factuality_data, faithfulness_data))
ptb_selected_data = xsum_val_data.data_by_id[ptb_id]

# ptb_docs - documents to sumamrize
ptb_doc = ptb_selected_data["document"]
print("ptb_doc to sample ood sentences:\n", ptb_doc)
# Out:
# ptb_doc to sample ood sentences:
#  Tait, who picked up a medal alongside Kate Hornsey in the women's pair, was diagnosed with cervical cancer in 2013.
# Australian Rowing head coach Chris O'Brien said: "Sarah has been, and will continue to be, an inspiration to many Australian rowers.
# "She was a strong role model to young athletes, and particularly influential with our emerging female athletes."
# Tait and Hornsey finished behind Great Britain's Heather Stanning and Helen Glover in the 2012 pairs final, which was GB's first gold of London 2012.
# Glover became friends with Tait following the final and told BBC World Service she was an "incredible personality".
# She added: "To achieve so much in her too short life - two beautiful children, a husband, an Olympic silver medal, the list goes on.
# "Above all that, she was an inspirational and truly lovely person that has paved the way for women in sport at home in Australia and all over the world."

# %% [markdown]
# ### * insert sents

# %%
sample_sents_n = 2

# %%
ptb_sentences = random.choices(ptb_doc.split("\n"), k=sample_sents_n)
print(ptb_sentences)
# Out:
# ['Australian Rowing head coach Chris O\'Brien said: "Sarah has been, and will continue to be, an inspiration to many Australian rowers.', 'She added: "To achieve so much in her too short life - two beautiful children, a husband, an Olympic silver medal, the list goes on.']

# %%
original_sents = original_doc.split("\n")
len(original_sents)
# Out:
# 35

# %%
for ptb_sent in ptb_sentences:
    insert_idx = random.choice(range(len(original_sents)))
    print("insert_idx", insert_idx)
    original_sents.insert(insert_idx, ptb_sent)
# Out:
# insert_idx 32
# insert_idx 20

# %%
len(original_sents)
# Out:
# 37

# %%
ood_doc = u"\n".join(original_sents)

# %% [markdown]
# ## generate summary from ood document

# %% [markdown]
# ### load model and tokenizer

# %%
model_name = "facebook/bart-large-xsum"
model, tokenizer = load_summarization_model_and_tokenizer(model_name)

# %%
import time

# %%
beam_size = 100

# %%
# generate summaries and metadata
start = time.time()
gen_summaries, gen_metadata = generate_summaries(
    model,
    tokenizer,
    original_doc,
    num_beams=beam_size,
    return_generation_metadata=True
)
end = time.time()
print(f"time: {end - start}")
# Out:
# time: 3.0090742111206055

# %%
# generate summaries and metadata
start = time.time()
ood_summaries, ood_metadata = generate_summaries(
    model,
    tokenizer,
    ood_doc,
    num_beams=beam_size,
    return_generation_metadata=True
)
end = time.time()
print(f"time: {end - start}")
# Out:
# time: 2.862010955810547

# %%
gen_metadata
# Out:
# [[{'token_id': tensor(37703, device='cuda:0'),
#    'token': 'Twenty',
#    'entropy': 5.396252632141113,
#    'beam_token_prob': 0.06844499707221985,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': 'He',
#      'token_id': 894,
#      'beam_token_prob': 0.0970643162727356},
#     {'token': 'The', 'token_id': 133, 'beam_token_prob': 0.08087211847305298},
#     {'token': 'It', 'token_id': 243, 'beam_token_prob': 0.0751330628991127}],
#    'token_in_input': True},
#   {'token_id': tensor(107, device='cuda:0'),
#    'token': ' years',
#    'entropy': 1.4511500597000122,
#    'beam_token_prob': 0.8674792051315308,
#    'beam_idx': 4,
#    'beam_top_probs': [{'token': ' years',
#      'token_id': 107,
#      'beam_token_prob': 0.8674792051315308},
#     {'token': '-', 'token_id': 12, 'beam_token_prob': 0.027631521224975586},
#     {'token': ' two',
#      'token_id': 80,
#      'beam_token_prob': 0.0023367642425000668}],
#    'token_in_input': True},
#   {'token_id': tensor(536, device='cuda:0'),
#    'token': ' ago',
#    'entropy': 2.5522990226745605,
#    'beam_token_prob': 0.30159440636634827,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' after',
#      'token_id': 71,
#      'beam_token_prob': 0.44663143157958984},
#     {'token': ' ago', 'token_id': 536, 'beam_token_prob': 0.30159440636634827},
#     {'token': ' on', 'token_id': 15, 'beam_token_prob': 0.0948895663022995}],
#    'token_in_input': True},
#   {'token_id': tensor(15, device='cuda:0'),
#    'token': ' on',
#    'entropy': 3.6582980155944824,
#    'beam_token_prob': 0.06397517025470734,
#    'beam_idx': 2,
#    'beam_top_probs': [{'token': ',',
#      'token_id': 6,
#      'beam_token_prob': 0.36989620327949524},
#     {'token': ' he', 'token_id': 37, 'beam_token_prob': 0.07730225473642349},
#     {'token': ' the', 'token_id': 5, 'beam_token_prob': 0.06943737715482712}],
#    'token_in_input': True},
#   {'token_id': tensor(294, device='cuda:0'),
#    'token': ' Tuesday',
#    'entropy': 1.2620413303375244,
#    'beam_token_prob': 0.8937318325042725,
#    'beam_idx': 30,
#    'beam_top_probs': [{'token': ' Tuesday',
#      'token_id': 294,
#      'beam_token_prob': 0.8937318325042725},
#     {'token': ' Monday',
#      'token_id': 302,
#      'beam_token_prob': 0.0050851721316576},
#     {'token': ' Wednesday',
#      'token_id': 307,
#      'beam_token_prob': 0.004142507445067167}],
#    'token_in_input': True},
#   {'token_id': tensor(6, device='cuda:0'),
#    'token': ',',
#    'entropy': 1.9175264835357666,
#    'beam_token_prob': 0.8258585929870605,
#    'beam_idx': 19,
#    'beam_top_probs': [{'token': ',',
#      'token_id': 6,
#      'beam_token_prob': 0.8258585929870605},
#     {'token': ' the', 'token_id': 5, 'beam_token_prob': 0.012824295088648796},
#     {'token': ' a', 'token_id': 10, 'beam_token_prob': 0.010208002291619778}],
#    'token_in_input': True},
#   {'token_id': tensor(5363, device='cuda:0'),
#    'token': ' Jean',
#    'entropy': 2.852160930633545,
#    'beam_token_prob': 0.47624003887176514,
#    'beam_idx': 12,
#    'beam_top_probs': [{'token': ' Jean',
#      'token_id': 5363,
#      'beam_token_prob': 0.47624003887176514},
#     {'token': ' a', 'token_id': 10, 'beam_token_prob': 0.20042739808559418},
#     {'token': ' the', 'token_id': 5, 'beam_token_prob': 0.08053369075059891}],
#    'token_in_input': False},
#   {'token_id': tensor(12, device='cuda:0'),
#    'token': '-',
#    'entropy': 0.7427319288253784,
#    'beam_token_prob': 0.9481238722801208,
#    'beam_idx': 10,
#    'beam_top_probs': [{'token': '-',
#      'token_id': 12,
#      'beam_token_prob': 0.9481238722801208},
#     {'token': ' Marc',
#      'token_id': 5908,
#      'beam_token_prob': 0.00045151999802328646},
#     {'token': 'Marc',
#      'token_id': 28987,
#      'beam_token_prob': 0.00011096617527073249}],
#    'token_in_input': True},
#   {'token_id': tensor(28987, device='cuda:0'),
#    'token': 'Marc',
#    'entropy': 0.6587644815444946,
#    'beam_token_prob': 0.9421862959861755,
#    'beam_idx': 3,
#    'beam_top_probs': [{'token': 'Marc',
#      'token_id': 28987,
#      'beam_token_prob': 0.9421862959861755},
#     {'token': ' Marc',
#      'token_id': 5908,
#      'beam_token_prob': 0.011208144016563892},
#     {'token': 'Marie',
#      'token_id': 30557,
#      'beam_token_prob': 0.0029557966627180576}],
#    'token_in_input': True},
#   {'token_id': tensor(9792, device='cuda:0'),
#    'token': ' Bos',
#    'entropy': 1.2628886699676514,
#    'beam_token_prob': 0.9054467082023621,
#    'beam_idx': 1,
#    'beam_top_probs': [{'token': ' Bos',
#      'token_id': 9792,
#      'beam_token_prob': 0.9054467082023621},
#     {'token': ' Bosnia',
#      'token_id': 25305,
#      'beam_token_prob': 0.0014446703717112541},
#     {'token': 'bos',
#      'token_id': 31957,
#      'beam_token_prob': 0.0014331653947010636}],
#    'token_in_input': True},
#   {'token_id': tensor(397, device='cuda:0'),
#    'token': 'man',
#    'entropy': 1.7127372026443481,
#    'beam_token_prob': 0.8648284673690796,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': 'man',
#      'token_id': 397,
#      'beam_token_prob': 0.8648284673690796},
#     {'token': 'mann',
#      'token_id': 4621,
#      'beam_token_prob': 0.001865189173258841},
#     {'token': ' man',
#      'token_id': 313,
#      'beam_token_prob': 0.0018248155247420073}],
#    'token_in_input': True},
#   {'token_id': tensor(4373, device='cuda:0'),
#    'token': ' emerged',
#    'entropy': 4.40602970123291,
#    'beam_token_prob': 0.026429321616888046,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' won',
#      'token_id': 351,
#      'beam_token_prob': 0.25492438673973083},
#     {'token': ' became',
#      'token_id': 1059,
#      'beam_token_prob': 0.12451314181089401},
#     {'token': ' took',
#      'token_id': 362,
#      'beam_token_prob': 0.06432012468576431}],
#    'token_in_input': True},
#   {'token_id': tensor(31, device='cuda:0'),
#    'token': ' from',
#    'entropy': 2.113058090209961,
#    'beam_token_prob': 0.8121741414070129,
#    'beam_idx': 58,
#    'beam_top_probs': [{'token': ' from',
#      'token_id': 31,
#      'beam_token_prob': 0.8121741414070129},
#     {'token': ' as', 'token_id': 25, 'beam_token_prob': 0.018676236271858215},
#     {'token': ' victorious',
#      'token_id': 22518,
#      'beam_token_prob': 0.009459258057177067}],
#    'token_in_input': True},
#   {'token_id': tensor(5, device='cuda:0'),
#    'token': ' the',
#    'entropy': 2.1575827598571777,
#    'beam_token_prob': 0.7003592252731323,
#    'beam_idx': 46,
#    'beam_top_probs': [{'token': ' the',
#      'token_id': 5,
#      'beam_token_prob': 0.7003592252731323},
#     {'token': ' a', 'token_id': 10, 'beam_token_prob': 0.13774658739566803},
#     {'token': ' Europe',
#      'token_id': 1005,
#      'beam_token_prob': 0.014150785282254219}],
#    'token_in_input': True},
#   {'token_id': tensor(796, device='cuda:0'),
#    'token': ' European',
#    'entropy': 1.2838654518127441,
#    'beam_token_prob': 0.893035352230072,
#    'beam_idx': 37,
#    'beam_top_probs': [{'token': ' European',
#      'token_id': 796,
#      'beam_token_prob': 0.893035352230072},
#     {'token': ' EU',
#      'token_id': 1281,
#      'beam_token_prob': 0.003513325471431017},
#     {'token': ' court',
#      'token_id': 461,
#      'beam_token_prob': 0.0034656154457479715}],
#    'token_in_input': True},
#   {'token_id': tensor(837, device='cuda:0'),
#    'token': ' Court',
#    'entropy': 0.7953211069107056,
#    'beam_token_prob': 0.9371880292892456,
#    'beam_idx': 24,
#    'beam_top_probs': [{'token': ' Court',
#      'token_id': 837,
#      'beam_token_prob': 0.9371880292892456},
#     {'token': ' court',
#      'token_id': 461,
#      'beam_token_prob': 0.008324933238327503},
#     {'token': ' courts',
#      'token_id': 4354,
#      'beam_token_prob': 0.0006632149452343583}],
#    'token_in_input': True},
#   {'token_id': tensor(9, device='cuda:0'),
#    'token': ' of',
#    'entropy': 0.8767783045768738,
#    'beam_token_prob': 0.9378726482391357,
#    'beam_idx': 14,
#    'beam_top_probs': [{'token': ' of',
#      'token_id': 9,
#      'beam_token_prob': 0.9378726482391357},
#     {'token': ' in', 'token_id': 11, 'beam_token_prob': 0.0006382831488735974},
#     {'token': ' to', 'token_id': 7, 'beam_token_prob': 0.0006110157701186836}],
#    'token_in_input': True},
#   {'token_id': tensor(1659, device='cuda:0'),
#    'token': ' Justice',
#    'entropy': 0.8176468014717102,
#    'beam_token_prob': 0.932475209236145,
#    'beam_idx': 9,
#    'beam_top_probs': [{'token': ' Justice',
#      'token_id': 1659,
#      'beam_token_prob': 0.932475209236145},
#     {'token': ' justice',
#      'token_id': 2427,
#      'beam_token_prob': 0.008906155824661255},
#     {'token': 'Justice',
#      'token_id': 29890,
#      'beam_token_prob': 0.002301007742062211}],
#    'token_in_input': True},
#   {'token_id': tensor(19, device='cuda:0'),
#    'token': ' with',
#    'entropy': 2.6802382469177246,
#    'beam_token_prob': 0.6545248031616211,
#    'beam_idx': 4,
#    'beam_top_probs': [{'token': ' with',
#      'token_id': 19,
#      'beam_token_prob': 0.6545248031616211},
#     {'token': ' to', 'token_id': 7, 'beam_token_prob': 0.08067305386066437},
#     {'token': ' in', 'token_id': 11, 'beam_token_prob': 0.038640670478343964}],
#    'token_in_input': True},
#   {'token_id': tensor(10, device='cuda:0'),
#    'token': ' a',
#    'entropy': 1.9422426223754883,
#    'beam_token_prob': 0.8095943927764893,
#    'beam_idx': 2,
#    'beam_top_probs': [{'token': ' a',
#      'token_id': 10,
#      'beam_token_prob': 0.8095943927764893},
#     {'token': ' the', 'token_id': 5, 'beam_token_prob': 0.03396853432059288},
#     {'token': ' an', 'token_id': 41, 'beam_token_prob': 0.013767608441412449}],
#    'token_in_input': True},
#   {'token_id': tensor(339, device='cuda:0'),
#    'token': ' win',
#    'entropy': 5.105934143066406,
#    'beam_token_prob': 0.28553342819213867,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' win',
#      'token_id': 339,
#      'beam_token_prob': 0.28553342819213867},
#     {'token': ' ruling',
#      'token_id': 2255,
#      'beam_token_prob': 0.09618625044822693},
#     {'token': ' victory',
#      'token_id': 1124,
#      'beam_token_prob': 0.058507006615400314}],
#    'token_in_input': True},
#   {'token_id': tensor(14, device='cuda:0'),
#    'token': ' that',
#    'entropy': 1.6741855144500732,
#    'beam_token_prob': 0.8637784719467163,
#    'beam_idx': 1,
#    'beam_top_probs': [{'token': ' that',
#      'token_id': 14,
#      'beam_token_prob': 0.8637784719467163},
#     {'token': ' over',
#      'token_id': 81,
#      'beam_token_prob': 0.005928791128098965},
#     {'token': ' in', 'token_id': 11, 'beam_token_prob': 0.003396108979359269}],
#    'token_in_input': True},
#   {'token_id': tensor(1224, device='cuda:0'),
#    'token': ' turned',
#    'entropy': 3.3263652324676514,
#    'beam_token_prob': 0.18251925706863403,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' changed',
#      'token_id': 1714,
#      'beam_token_prob': 0.3195245563983917},
#     {'token': ' transformed',
#      'token_id': 11229,
#      'beam_token_prob': 0.18822577595710754},
#     {'token': ' turned',
#      'token_id': 1224,
#      'beam_token_prob': 0.18251925706863403}],
#    'token_in_input': True},
#   {'token_id': tensor(1005, device='cuda:0'),
#    'token': ' Europe',
#    'entropy': 2.0276389122009277,
#    'beam_token_prob': 0.5105996131896973,
#    'beam_idx': 4,
#    'beam_top_probs': [{'token': ' Europe',
#      'token_id': 1005,
#      'beam_token_prob': 0.5105996131896973},
#     {'token': ' European',
#      'token_id': 796,
#      'beam_token_prob': 0.25628548860549927},
#     {'token': ' football',
#      'token_id': 1037,
#      'beam_token_prob': 0.12236407399177551}],
#    'token_in_input': True},
#   {'token_id': tensor(18, device='cuda:0'),
#    'token': "'s",
#    'entropy': 1.2577499151229858,
#    'beam_token_prob': 0.9085022211074829,
#    'beam_idx': 4,
#    'beam_top_probs': [{'token': "'s",
#      'token_id': 18,
#      'beam_token_prob': 0.9085022211074829},
#     {'token': ' into',
#      'token_id': 88,
#      'beam_token_prob': 0.0020396681502461433},
#     {'token': "'",
#      'token_id': 108,
#      'beam_token_prob': 0.00039010916952975094}],
#    'token_in_input': True},
#   {'token_id': tensor(299, device='cuda:0'),
#    'token': ' top',
#    'entropy': 0.500117838382721,
#    'beam_token_prob': 0.956803023815155,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' top',
#      'token_id': 299,
#      'beam_token_prob': 0.956803023815155},
#     {'token': ' football',
#      'token_id': 1037,
#      'beam_token_prob': 0.003441555891185999},
#     {'token': ' elite',
#      'token_id': 6281,
#      'beam_token_prob': 0.0029838569462299347}],
#    'token_in_input': True},
#   {'token_id': tensor(9696, device='cuda:0'),
#    'token': ' divisions',
#    'entropy': 0.727023720741272,
#    'beam_token_prob': 0.9365754127502441,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' divisions',
#      'token_id': 9696,
#      'beam_token_prob': 0.9365754127502441},
#     {'token': ' leagues',
#      'token_id': 10637,
#      'beam_token_prob': 0.006050164345651865},
#     {'token': ' division',
#      'token_id': 2757,
#      'beam_token_prob': 0.0029010737780481577}],
#    'token_in_input': True},
#   {'token_id': tensor(88, device='cuda:0'),
#    'token': ' into',
#    'entropy': 1.3496620655059814,
#    'beam_token_prob': 0.893301248550415,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' into',
#      'token_id': 88,
#      'beam_token_prob': 0.893301248550415},
#     {'token': ' from',
#      'token_id': 31,
#      'beam_token_prob': 0.004833049140870571},
#     {'token': ' and', 'token_id': 8, 'beam_token_prob': 0.003919592592865229}],
#    'token_in_input': True},
#   {'token_id': tensor(19465, device='cuda:0'),
#    'token': ' glorious',
#    'entropy': 0.21567195653915405,
#    'beam_token_prob': 0.9826367497444153,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' glorious',
#      'token_id': 19465,
#      'beam_token_prob': 0.9826367497444153},
#     {'token': ' magnificent',
#      'token_id': 19243,
#      'beam_token_prob': 0.00044475519098341465},
#     {'token': ' "', 'token_id': 22, 'beam_token_prob': 0.0004443485813681036}],
#    'token_in_input': True},
#   {'token_id': tensor(17528, device='cuda:0'),
#    'token': ' expressions',
#    'entropy': 0.693790078163147,
#    'beam_token_prob': 0.9376828074455261,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' expressions',
#      'token_id': 17528,
#      'beam_token_prob': 0.9376828074455261},
#     {'token': ' expression',
#      'token_id': 8151,
#      'beam_token_prob': 0.0038335430435836315},
#     {'token': ' places',
#      'token_id': 2127,
#      'beam_token_prob': 0.002992658643051982}],
#    'token_in_input': True},
#   {'token_id': tensor(9, device='cuda:0'),
#    'token': ' of',
#    'entropy': 0.6994775533676147,
#    'beam_token_prob': 0.9516291618347168,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' of',
#      'token_id': 9,
#      'beam_token_prob': 0.9516291618347168},
#     {'token': ' for',
#      'token_id': 13,
#      'beam_token_prob': 0.0003758266393560916},
#     {'token': ' and',
#      'token_id': 8,
#      'beam_token_prob': 0.0002461730327922851}],
#    'token_in_input': True},
#   {'token_id': tensor(30286, device='cuda:0'),
#    'token': ' multicultural',
#    'entropy': 0.8515331745147705,
#    'beam_token_prob': 0.921739935874939,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' multicultural',
#      'token_id': 30286,
#      'beam_token_prob': 0.921739935874939},
#     {'token': 'mult',
#      'token_id': 42527,
#      'beam_token_prob': 0.003567121457308531},
#     {'token': ' Mult',
#      'token_id': 14910,
#      'beam_token_prob': 0.002448935993015766}],
#    'token_in_input': True},
#   {'token_id': tensor(1809, device='cuda:0'),
#    'token': 'ism',
#    'entropy': 0.9081904888153076,
#    'beam_token_prob': 0.9269974827766418,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': 'ism',
#      'token_id': 1809,
#      'beam_token_prob': 0.9269974827766418},
#     {'token': 'ismo',
#      'token_id': 19689,
#      'beam_token_prob': 0.0021668579429388046},
#     {'token': 'ist',
#      'token_id': 661,
#      'beam_token_prob': 0.0013161019887775183}],
#    'token_in_input': True},
#   {'token_id': tensor(4, device='cuda:0'),
#    'token': '.',
#    'entropy': 3.7982308864593506,
#    'beam_token_prob': 0.19903810322284698,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' and',
#      'token_id': 8,
#      'beam_token_prob': 0.45545852184295654},
#     {'token': '.', 'token_id': 4, 'beam_token_prob': 0.19903810322284698},
#     {'token': ' -', 'token_id': 111, 'beam_token_prob': 0.07003752887248993}],
#    'token_in_input': True},
#   {'token_id': tensor(2, device='cuda:0'),
#    'token': '</s>',
#    'entropy': 4.813204765319824,
#    'beam_token_prob': 9.737237269291654e-05,
#    'beam_idx': 0,
#    'beam_top_probs': [{'token': ' added',
#      'token_id': 355,
#      'beam_token_prob': 0.2787040174007416},
#     {'token': ' gave',
#      'token_id': 851,
#      'beam_token_prob': 0.06233754754066467},
#     {'token': ' changed',
#      'token_id': 1714,
#      'beam_token_prob': 0.056104518473148346}],
#    'token_in_input': True}]]

# %%
# generate token entropy metadata
gen_token_entropy_metadata = generate_token_entropy_metadata(bbc_ids, gen_metadata)

# %%
# selected_data - list of dicts with keys: (id, document, true_summary, (factuality_data, faithfulness_data))
selected_data = [xsum_test_data.data_by_id[x] for x in bbc_ids]

# original_docs - list of documents to sumamrize
original_docs = [x["document"] for x in selected_data]
print("original docs to summarize:\n", original_docs)

# %%
original_docs[0].split("\n")
# Out:
# ["Sian O'Callaghan, 22, was last seen leaving Suju alone at about 0250 GMT on Saturday to walk half a mile home.",
#  'About 400 people took part in the search of Savernake Forest near Marlborough which is due to resume at 1030 GMT on Wednesday.',
#  'A £20,000 reward to help find her has been offered by an anonymous donor.',
#  'Mobile records put her phone in the area of the 4,500-acre forest 32 minutes after she left the club.',
#  'Police say the journey could only have been made by car.',
#  "Miss O'Callaghan's friends and her boyfriend Kevin Reape joined the search along with local people, many of whom did not know the missing woman, following a police appeal for help.",
#  'Volunteers searching the dense woodland were divided into groups which were then assigned to a specialist police officer.',
#  'Mikey Jack, 19, who plays Sunday league football with Mr Reape, said: "A lot of people here don\'t really know Kevin or Sian but they just want to help any way they can."',
#  'Another volunteer, college student Tizanne Gregory, 17, added: "I came here today in the hope of finding Sian.',
#  '"I\'m just hoping we can do anything to help her parents and it is horrible not knowing where she is."',
#  "A police spokesman said Miss O'Callaghan had an LG E900 Optimus mobile phone and asked for anyone who finds one to contact the force.",
#  "CCTV footage of Miss O'Callaghan alone in the nightclub has been released in the hope that it will jog revellers' memories.",
#  "The black and white footage shows her walking downstairs and outside through the club's entrance, past a small group of men.",
#  'A police spokesman said the times shown on the CCTV were about six minutes slow.',
#  "He urged anyone who remembered seeing Miss O'Callaghan to contact the force.",
#  'Her disappearance has been described as totally out of character.',
#  'More than 60 police officers are working on the investigation which is being treated as a missing person inquiry.',
#  'Det Supt Steve Fulcher said: "Sian left Suju and walked along the High Street in Old Town and there were a number of vehicles moving through the High Street between 2.55am to 3am.',
#  '"We would like to identify the people in those vehicles as possible witnesses.',
#  '"I\'d also like to hear from anyone who saw any vehicles in or near beauty spots between Swindon and Savernake between 3am and 4am.',
#  '"It is very important that people come forward as they may have vital information which will help us to find Sian."',
#  "At a news conference on Monday, her boyfriend Kevin Reape, who shared a flat with Miss O'Callaghan, appealed for information to help find her.",
#  "A Wiltshire Police spokesman said Mr Reape was not being treated as a suspect in Miss O'Callaghan's disappearance.",
#  "Also present at the news conference were Miss O'Callaghan's parents Mick, 51, and Elaine, 48, brother Liam, 24, and sister Lora, 19."]

# %% [markdown]
# # NER Analysis
# ---

# %%
import spacy
from spacy import displacy
NER = spacy.load("en_core_web_lg")

# %% [markdown]
# ## 0-0) file save / load utils

# %%
import pickle
import os

# %%
def save_to_cache_dir(var, file_name):
    cache_path = "../cache"
    file_path = os.path.join(cache_path, file_name + ".pkl")
    with open(file_path, "wb") as f:
        pickle.dump(var, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"saved to '{file_path}'")

# %%
def load_from_cache_dir(file_name):
    cache_path = "../cache"
    file_path = os.path.join(cache_path, file_name + ".pkl")
    with open(file_path, 'rb') as f:
        var = pickle.load(f)
    print(f"'{file_path}' loaded")
    return var

# %% [markdown]
# ## 0-1) NER utils

# %%
# function to display basic entity info: 
def show_ents(doc):
    print(f"original doc: {doc.text}")
    if doc.ents: 
        for ent in doc.ents: 
            print(f"entity: {ent.text : >13} | start_char: {ent.start_char: 3} | end_char: {ent.end_char: 3} | label: {ent.label_} - {spacy.explain(ent.label_)}")
            # print(ent.label)  # entity type's hash value
            # print(ent.start)  # token span's start index position (word index)
            # print(ent.end)  # token span's stop index position (word index)
    else: print('No named entities found.')

# %% [markdown]
# ## 0-2) load cached NER files

# %%
# # train
# train_doc_ents_list = load_from_cache_dir("train_doc_ents_list")
# train_sum_ents_list = load_from_cache_dir("train_sum_ents_list")

# # val
# val_doc_ner_list = load_from_cache_dir("val_doc_ner_list")
# val_sum_ner_list = load_from_cache_dir("val_sum_ner_list")
# val_doc_ents_list = load_from_cache_dir("val_doc_ents_list_pp")  # preprocessed
# val_sum_ents_list = load_from_cache_dir("val_sum_ents_list_pp")

# test
test_doc_ner_list = load_from_cache_dir("test_doc_ner_list")
test_sum_ner_list = load_from_cache_dir("test_sum_ner_list")
test_doc_ents_list = load_from_cache_dir("test_doc_ents_list_pp")  # preprocessed
test_sum_ents_list = load_from_cache_dir("test_sum_ents_list_pp")

# entities pool
concat_ent_pool_dict = load_from_cache_dir("concat_ent_pool_dict_pp")  # preprocessed
# test_ent_pool_dict = load_from_cache_dir("test_ent_pool_dict")
# Out:
# '../cache/test_doc_ner_list.pkl' loaded
# '../cache/test_sum_ner_list.pkl' loaded
# '../cache/test_doc_ents_list_pp.pkl' loaded
# '../cache/test_sum_ents_list_pp.pkl' loaded
# '../cache/concat_ent_pool_dict_pp.pkl' loaded

# %% [markdown]
# ## todo
# * case 1. no entites in true_summary - continue
#     1) ner on summary doesn't recognize the entity correctly
# * case 2. no exact overlap entities btw true_summary - document
#     1) check subset
#         * Edinburgh (summary) - Edinburgh Sheriff Court (document)
#         * (name) Usain Bolt (summary) - Usain (document) - should I replace?
#
# * case 3. ex) 4 - four
# * case 4. case
#
# 1. how to choose the entity?
#     * pick the replacement entity that is not in the source document
# 2. how to replace it?
#
#
#
#
#
# ### other ideas
# * replace the entites that are not in the true summary?

# %% [markdown]
# ## 1) analyze test summaries

# %%
data_idx = 0

# %%
sum_ner = test_sum_ner_list[data_idx]
doc_ner = test_doc_ner_list[data_idx]

# %%
doc_ents_sorted = test_doc_ents_list[data_idx].most_common()
sum_ents_sorted = test_sum_ents_list[data_idx].most_common()

# %%
show_ents(sum_ner)
# Out:
# original doc: There is a "chronic" need for more housing for prison leavers in Wales, according to a charity.
# entity:         Wales | start_char:  65 | end_char:  70 | label: GPE - Countries, cities, states

# %%
sum_ents_sorted
# Out:
# [(('Wales', 'GPE'), 1)]

# %%
doc_ents_sorted
# Out:
# [(('one', 'CARDINAL'), 4),
#  (('Wales', 'GPE'), 2),
#  (('Marc', 'PERSON'), 2),
#  (('1,099', 'CARDINAL'), 1),
#  (('2015-16', 'DATE'), 1),
#  (('up to a year', 'DATE'), 1),
#  (('The Welsh Government', 'ORG'), 1),
#  (('the Housing Act', 'LAW'), 1),
#  (('2015', 'DATE'), 1),
#  (('Andrew Stevens', 'PERSON'), 1),
#  (('six months to a year', 'DATE'), 1),
#  (('six months', 'DATE'), 1),
#  (('Stevens', 'PERSON'), 1),
#  (('a hundred pounds', 'MONEY'), 1),
#  (('830', 'CARDINAL'), 1),
#  (('the year to March 2016', 'DATE'), 1),
#  (('6,900', 'CARDINAL'), 1),
#  (('50', 'DATE'), 1),
#  (('the past 20 years', 'DATE'), 1),
#  (('Tom Clarke', 'PERSON'), 1),
#  (('Emmaus South Wales', 'GPE'), 1),
#  (('Emmaus', 'ORG'), 1),
#  (('Welsh Government', 'ORG'), 1),
#  (('20,000', 'CARDINAL'), 1),
#  (('the next five years', 'DATE'), 1)]

# %% [markdown]
# ## 2) filter entities

# %% [markdown]
# * label list
#     * CARDINAL: Numerals that do not fall under another type
#     * DATE: Absolute or relative dates or periods
#     * EVENT: Named hurricanes, battles, wars, sports events, etc.
#     * FAC: Buildings, airports, highways, bridges, etc.
#     * GPE: Countries, cities, states
#     * LANGUAGE: Any named language
#     * LAW: Named documents made into laws.
#     * LOC: Non-GPE locations, mountain ranges, bodies of water
#     * MONEY: Monetary values, including unit
#     * NORP: Nationalities or religious or political groups
#     * ORDINAL: "first", "second", etc.
#     * ORG: Companies, agencies, institutions, etc.
#     * PERCENT: Percentage, including "%"
#     * PERSON: People, including fictional
#     * PRODUCT: Objects, vehicles, foods, etc. (not services)
#     * QUANTITY: Measurements, as of weight or distance
#     * TIME: Times smaller than a day
#     * WORK_OF_ART: Titles of books, songs, etc.

# %% [markdown]
# FILTER_LABELS = ["PERSON", "FAC", "GPE", "NORP", "LOC", "EVENT"]

# %%
FILTER_LABELS = ["PERSON", "FAC", "GPE", "NORP", "LOC", "EVENT", "LANGUAGE", "LAW", "ORG"]
# without numbers? "DATE", "PERCENT" 
# too many errors: "PRODUCT", "WORK_OF_ART"

# %%
ALL_LABELS = list(NER.get_pipe('ner').labels)

# %% [markdown]
# ## 3) replace entities

# %%
from tqdm.notebook import tqdm

# %% [markdown]
# ### 1) count samples to exclude

# %%
def count_no_overlap(xsum_data, doc_ents_list, sum_ents_list, filter_labels):
    # samples to exclude
    doc_overlap_count = 0
    sum_overlap_count = 0
    no_overlap_count = 0

    for data_idx, data in enumerate(tqdm(xsum_data.dataset)):
        document = data["document"]
        true_summary = data["true_summary"]

        # ner
        # doc_ner = doc_ner_list[data_idx]
        # sum_ner = sum_ner_list[data_idx]

        # entites
        doc_ents = doc_ents_list[data_idx]
        sum_ents = sum_ents_list[data_idx]

        # sort and filter
        doc_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in doc_ents.most_common() 
                                    if label in filter_labels]
        sum_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in sum_ents.most_common() 
                                    if label in filter_labels]

        overlap_flag = False
        # from document side
        for (ent, label), count in doc_ents_filtered_sorted:
            if ent in true_summary:  # overlap exists
                overlap_flag = True
                doc_overlap_count += 1
                break

        # if no overlap from document side, try from summary
        if overlap_flag == False:
            if len(sum_ents) == 0: # no entity in summary -> pass
                pass
            else:
                for (ent, label), count in sum_ents_filtered_sorted:
                    if ent in document:
                        overlap_flag = True
                        sum_overlap_count += 1
                        break

        if overlap_flag == False:
            no_overlap_count += 1 # need to exclude

    # check uncounted sample
    assert doc_overlap_count + sum_overlap_count + no_overlap_count == len(xsum_data.dataset)
    
    return doc_overlap_count, sum_overlap_count, no_overlap_count

# %%
test_overlap_counts = count_no_overlap(xsum_data=xsum_test_data, 
                                       doc_ents_list=test_doc_ents_list, 
                                       sum_ents_list=test_sum_ents_list, 
                                       filter_labels=FILTER_LABELS)
# Out:
#   0%|          | 0/11334 [00:00<?, ?it/s]

# %%
n_test = len(xsum_test_data.dataset)
print(f"overlap from document: {(test_overlap_counts[0]/n_test)*100:.1f}%")
print(f"overlap from summary: {(test_overlap_counts[1]/n_test)*100:.1f}%")
print(f"no overlap: {(test_overlap_counts[2]/n_test)*100:.1f}%")
# Out:
# overlap from document: 72.6%
# overlap from summary: 3.6%
# no overlap: 23.7%

# %% [markdown]
# ### 2) print

# %%
# extract only necessary dicts
for label in ALL_LABELS:
    if label not in FILTER_LABELS:
        del concat_ent_pool_dict[label]

# %%
assert(len(concat_ent_pool_dict) == len(FILTER_LABELS))

# %%
# reduce the size to 5%
reduced_concat_ent_pool_dict = {}
for label in concat_ent_pool_dict.keys():
    ent_pool = concat_ent_pool_dict[label]
    reduced_ent_pool = {k:v for (k,v) in list(ent_pool.items())[:len(ent_pool) // 10]}
    reduced_concat_ent_pool_dict[label] = reduced_ent_pool

# %%
len(concat_ent_pool_dict["PERSON"])
# Out:
# 358369

# %%
len(reduced_concat_ent_pool_dict["PERSON"])
# Out:
# 35836

# %%
import random
random.seed(0)

# %%
chosen_ent_label_list = []
for data_idx, data in enumerate(tqdm(xsum_test_data.dataset)):
    print(f"\n============ data idx: {data_idx} ============")
    document = data["document"]
    true_summary = data["true_summary"]
    
    # ner
    # doc_ner = test_doc_ner_list[data_idx]
    # sum_ner = test_sum_ner_list[data_idx]
    
    # entites
    doc_ents = test_doc_ents_list[data_idx]
    sum_ents = test_sum_ents_list[data_idx]
    
    # sort and filter
    doc_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in doc_ents.most_common() 
                                if label in FILTER_LABELS]
    sum_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in sum_ents.most_common() 
                                if label in FILTER_LABELS]
    
    # if there is an overlap
    overlap_flag = False
    
    
    chosen_ent_label = None
    
    # from document side
#     print(f"* summary: {true_summary}")
#     print(f"* document ents: {doc_ents_filtered_sorted} \n")
    for (ent, label), count in doc_ents_filtered_sorted:
        if ent in true_summary:  # overlap exists
#             print("** overlap from document")
#             print(f"ent: {ent}, label: {label}, count_doc: {count}, count_sum: {true_summary.count(ent)}")
            overlap_flag = True
            chosen_ent_label = (ent, label)
            break
    
    # if no overlap from document side, try from summary
    if overlap_flag == False:
        if len(sum_ents) == 0: # no entity in summary -> pass
            pass
        else:
#             print(f"* summary ents: {sum_ents_filtered_sorted} \n")
            for (ent, label), count in sum_ents_filtered_sorted:
                if ent in document:
#                     print("** overlap from summary")
#                     print(f"ent: {ent}, label: {label}, count_sum: {count}, count_doc: {document.count(ent)}")
                    overlap_flag = True
                    chosen_ent_label = (ent, label)
                    break
    
    
    # check the chosen entity
    if overlap_flag == True:
        chosen_ent_label_list.append(chosen_ent_label)
        
        chosen_ent, chosen_label = chosen_ent_label
        print(f"* summary: {true_summary}")
        print(f"* chosen_ent: {chosen_ent}, label: {chosen_label}")
        
        
        # choose one
        ent_pool = list(reduced_concat_ent_pool_dict[chosen_label].keys())
        replacement = random.choice(ent_pool)
        print(f"* replacement: {replacement}")
        while len(replacement.split()) != len(chosen_ent.split()):  # also this should not be in doc or summary
            print("pick new replacement")
            replacement = random.choice(ent_pool)
            print(f"* replacement: {replacement}")
        
    else:
        print("****** NO OVERLAP ******")
        chosen_ent_label_list.append((None, None))
# Out:
#   0%|          | 0/11334 [00:00<?, ?it/s]
# ============ data idx: 0 ============
# * summary: There is a "chronic" need for more housing for prison leavers in Wales, according to a charity.
# * chosen_ent: Wales, label: GPE
# * replacement: Qingdao
#
# ============ data idx: 1 ============
# * summary: A man has appeared in court after firearms, ammunition and cash were seized by police in Edinburgh.
# * chosen_ent: Edinburgh, label: GPE
# * replacement: Dunblane
#
# ============ data idx: 2 ============
# * summary: Four people accused of kidnapping and torturing a mentally disabled man in a "racially motivated" attack streamed on Facebook have been denied bail.
# * chosen_ent: Facebook, label: ORG
# * replacement: Stam
#
# ============ data idx: 3 ============
# * summary: West Brom have appointed Nicky Hammond as technical director, ending his 20-year association with Reading.
# * chosen_ent: West Brom, label: GPE
# * replacement: the Irish Republic
# pick new replacement
# * replacement: Gymraeg
# pick new replacement
# * replacement: Northwich
# pick new replacement
# * replacement: Thailand
# pick new replacement
# * replacement: Lorient
# pick new replacement
# * replacement: Jadeja
# pick new replacement
# * replacement: Dingwall
# pick new replacement
# * replacement: Bydd
# pick new replacement
# * replacement: Seaford
# pick new replacement
# * replacement: Aleppo
# pick new replacement
# * replacement: Grand Rapids
#
# ============ data idx: 4 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 5 ============
# * summary: Since their impending merger was announced in January, there has been remarkably little comment about the huge proposed deal to combine Essilor and Luxottica.
# * chosen_ent: Luxottica, label: PERSON
# * replacement: Melinda
#
# ============ data idx: 6 ============
# * summary: A "medal at any cost" approach created a "culture of fear" at British Cycling, says former rider Wendy Houvenaghel.
# * chosen_ent: British Cycling, label: ORG
# * replacement: Hezbollah
# pick new replacement
# * replacement: Downpatrick
# pick new replacement
# * replacement: Rowe
# pick new replacement
# * replacement: the Scottish Police Authority
# pick new replacement
# * replacement: the Disasters Emergency Committee
# pick new replacement
# * replacement: National Super Alliance
# pick new replacement
# * replacement: Hatton
# pick new replacement
# * replacement: Collum
# pick new replacement
# * replacement: Guidolin
# pick new replacement
# * replacement: the Royal Exchange
# pick new replacement
# * replacement: Scottish Enterprise
#
# ============ data idx: 7 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 8 ============
# * summary: The reaction from BT's investors told us much about media regulator Ofcom's ruling on the fate of Openreach, the BT subsidiary that provides much of the UK's broadband infrastructure.
# * chosen_ent: BT, label: ORG
# * replacement: European Games
# pick new replacement
# * replacement: Svk/Tinkoff
#
# ============ data idx: 9 ============
# * summary: Manager Brendan Rodgers is sure Celtic can exploit the wide open spaces of Hampden when they meet Rangers in Sunday's League Cup semi-final.
# * chosen_ent: Rodgers, label: PERSON
# * replacement: Ellie
#
# ============ data idx: 10 ============
# * summary: Queen's University Belfast is cutting 236 jobs and 290 student places due to a funding reduction.
# * chosen_ent: Queen, label: PERSON
# * replacement: Pep Clotet
# pick new replacement
# * replacement: Robert Lindsay
# pick new replacement
# * replacement: Henry Cecil
# pick new replacement
# * replacement: Dim ond
# pick new replacement
# * replacement: Raul Jimenez
# pick new replacement
# * replacement: Paul Dixon
# pick new replacement
# * replacement: Colin McMenamin
# pick new replacement
# * replacement: Michael Holding
# pick new replacement
# * replacement: Jimmy Phillips
# pick new replacement
# * replacement: Lee Jones
# pick new replacement
# * replacement: Snapchat
#
# ============ data idx: 11 ============
# * summary: Hospital bosses in Sussex have apologised after about 850 patients were sent leaflets in error suggesting they might have cancer.
# * chosen_ent: Sussex, label: GPE
# * replacement: Port Moresby
# pick new replacement
# * replacement: Latta
#
# ============ data idx: 12 ============
# * summary: The shadow foreign secretary has suggested Labour will continue to support legislation paving the way for Brexit as it passes through Parliament.
# * chosen_ent: Labour, label: ORG
# * replacement: Portstewart
#
# ============ data idx: 13 ============
# * summary: Torquay United boss Kevin Nicholson says none of the money from Eunan O'Kane's move to Leeds from Bournemouth will go to the playing squad.
# * chosen_ent: Nicholson, label: PERSON
# * replacement: Michael Gash
# pick new replacement
# * replacement: Daniel Ek
# pick new replacement
# * replacement: Phil Hindes
# pick new replacement
# * replacement: Craig Brown
# pick new replacement
# * replacement: Tom Meechan
# pick new replacement
# * replacement: Sally Holland
# pick new replacement
# * replacement: J Carty
# pick new replacement
# * replacement: Eamon Martin
# pick new replacement
# * replacement: George VI
# pick new replacement
# * replacement: Maharaj
#
# ============ data idx: 14 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 15 ============
# * summary: Leicester City striker Gary Taylor-Fletcher has joined Sheffield Wednesday on an initial month-long loan.
# * chosen_ent: Taylor-Fletcher, label: ORG
# * replacement: Royal Holloway
# pick new replacement
# * replacement: Moto
#
# ============ data idx: 16 ============
# * summary: Limiting access to federal research would do an "enormous disservice" to the US and the world according to former Nasa chief scientist.
# * chosen_ent: US, label: GPE
# * replacement: Cracksman
#
# ============ data idx: 17 ============
# * summary: John "Brad" Bradbury, drummer with The Specials, has died at the age of 62.
# * chosen_ent: Bradbury, label: PERSON
# * replacement: Jason Demetriou's
# pick new replacement
# * replacement: Ross Murray
# pick new replacement
# * replacement: Farhaan Behardien
# pick new replacement
# * replacement: Lew
#
# ============ data idx: 18 ============
# * summary: Tiger Woods missed the cut at the Farmers Insurance Open, as England's Justin Rose maintained a one-shot lead.
# * chosen_ent: Rose, label: PERSON
# * replacement: Maj Gen Igor Konashenkov
# pick new replacement
# * replacement: Karim El Ahmadi
# pick new replacement
# * replacement: Tom Gilmore
# pick new replacement
# * replacement: Richard Brown
# pick new replacement
# * replacement: Simon Moore
# pick new replacement
# * replacement: Royal Ascot
# pick new replacement
# * replacement: Helen Davies
# pick new replacement
# * replacement: Stephen Brady
# pick new replacement
# * replacement: Shipman
#
# ============ data idx: 19 ============
# * summary: Former England striker Andy Cole says he faces a "long road ahead" as he recovers from his recent kidney transplant.
# * chosen_ent: England, label: GPE
# * replacement: Cesena
#
# ============ data idx: 20 ============
# * summary: Pakistan has unblocked the video sharing site, YouTube, more than three years after it was banned for posting a video deemed insulting to Islam.
# * chosen_ent: Pakistan, label: GPE
# * replacement: Waziristan
#
# ============ data idx: 21 ============
# * summary: Leicester Tigers winger Miles Benjamin is likely to be out for the rest of the season because of a knee injury, reports BBC Radio Leicester.
# * chosen_ent: BBC Radio Leicester, label: ORG
# * replacement: Nespresso
# pick new replacement
# * replacement: The Transport Salaried Staffs' Association
# pick new replacement
# * replacement: the Immigration Services Society of
# pick new replacement
# * replacement: yn cynyddu
# pick new replacement
# * replacement: Plaid
# pick new replacement
# * replacement: the Royal Geographical Society
# pick new replacement
# * replacement: Fema
# pick new replacement
# * replacement: The Bank of Korea
# pick new replacement
# * replacement: SBC
# pick new replacement
# * replacement: Clifton
# pick new replacement
# * replacement: Alonso
# pick new replacement
# * replacement: Kismayo
# pick new replacement
# * replacement: Central European University
#
# ============ data idx: 22 ============
# * summary: Owain Doull has won Wales' first gold of the 2016 Olympics as  he helped the Great Britain men's team pursuit defend their cycling title in Rio.
# * chosen_ent: Doull, label: ORG
# * replacement: Galarza
#
# ============ data idx: 23 ============
# * summary: Floods in the western Indian state of Gujarat have killed 218 people, government officials have confirmed.
# * chosen_ent: India, label: GPE
# * replacement: Fort Worth
# pick new replacement
# * replacement: Lurgan
#
# ============ data idx: 24 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 25 ============
# * summary: Royal Bank of Scotland (RBS) has been fined HK$6m (£460,000) by Hong Kong regulators after it failed to detect a series of unauthorised transactions by one of its traders.
# * chosen_ent: Hong Kong, label: GPE
# * replacement: Brislington
# pick new replacement
# * replacement: Guernsey
# pick new replacement
# * replacement: Richmond
# pick new replacement
# * replacement: Istanbul
# pick new replacement
# * replacement: New Malden
#
# ============ data idx: 26 ============
# * summary: The Bafta awards had laughter, passion and plenty of politics.
# * chosen_ent: Bafta, label: ORG
# * replacement: League Two Carlisle
# pick new replacement
# * replacement: HMP Bedford
# pick new replacement
# * replacement: BBC Cumbria
# pick new replacement
# * replacement: Liverpool Town Hall
# pick new replacement
# * replacement: Abu Dhabi's
# pick new replacement
# * replacement: Schwartzel
#
# ============ data idx: 27 ============
# * summary: Of his last 30 matches in 2016, Andy Murray won 28 and lost just two.
# * chosen_ent: Murray, label: PERSON
# * replacement: Ross Etheridge
# pick new replacement
# * replacement: Dent
#
# ============ data idx: 28 ============
# * summary: South African police say four people have been arrested in connection with the murder of former actor on popular local TV series Generations.
# * chosen_ent: South Africa, label: GPE
# * replacement: Pwllheli
# pick new replacement
# * replacement: West Calder
#
# ============ data idx: 29 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 30 ============
# * summary: Jessica Ennis-Hill has fallen from fourth to eighth place after six events at the Hypo-Meeting in Gotzis.
# * chosen_ent: Ennis-Hill, label: ORG
# * replacement: BBC Match
# pick new replacement
# * replacement: Red Bull -
# pick new replacement
# * replacement: Clydebridge
#
# ============ data idx: 31 ============
# * summary: The Manor team have collapsed after administrators failed to find a buyer for the stricken business.
# * chosen_ent: Manor, label: GPE
# * replacement: Overtown
#
# ============ data idx: 32 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 33 ============
# * summary: With the value of the pound falling dramatically since Brexit, a "flash crash" last week when the currency lost 6% of its value against the dollar, and news on Tuesday that the pound had fallen again, when would be a good time to change those pounds to dollars?
# * chosen_ent: Brexit, label: LAW
# * replacement: the PlayStation 3
# pick new replacement
# * replacement: the Care Act
# pick new replacement
# * replacement: the Lisbon Treaty
# pick new replacement
# * replacement: the Dangerous Dogs Act
# pick new replacement
# * replacement: the Dangerous Dogs Act 1991
# pick new replacement
# * replacement: the Voting Rights Act
# pick new replacement
# * replacement: the Kyoto Protocol
# pick new replacement
# * replacement: the Welfare Reform and Work Bill
# pick new replacement
# * replacement: Pension Schemes Bill
# pick new replacement
# * replacement: the Climate Change Act
# pick new replacement
# * replacement: The Australian Competition and Consumer Commission
# pick new replacement
# * replacement: the Law Society of Scotland
# pick new replacement
# * replacement: iOS 9
# pick new replacement
# * replacement: Section 40 of the Crime and Courts Act
# pick new replacement
# * replacement: the Terrorism Act 2006
# pick new replacement
# * replacement: Section 18
# pick new replacement
# * replacement: the Lisbon Treaty -
# pick new replacement
# * replacement: the Inquiries Act 2005
# pick new replacement
# * replacement: Section 44
# pick new replacement
# * replacement: the Investigatory Powers Act
# pick new replacement
# * replacement: the Marriage Act
# pick new replacement
# * replacement: the Football Act
# pick new replacement
# * replacement: the Unduly Lenient
# pick new replacement
# * replacement: Article 50 of
# pick new replacement
# * replacement: Oslo Accord
# pick new replacement
# * replacement: Article 8 of the Human Rights Act
# pick new replacement
# * replacement: the Renewable Heat Incentive
# pick new replacement
# * replacement: Oslo Accord
# pick new replacement
# * replacement: the Scotland Act 2016
# pick new replacement
# * replacement: the Euro 2012
# pick new replacement
# * replacement: the Treasure Act 1996
# pick new replacement
# * replacement: the US Constitution's
# pick new replacement
# * replacement: the Royal Wedding
# pick new replacement
# * replacement: Article Five
# pick new replacement
# * replacement: Euro 4
# pick new replacement
# * replacement: the Wales Act
# pick new replacement
# * replacement: iOS 8
# pick new replacement
# * replacement: the Royal Assent
# pick new replacement
# * replacement: the 1967 Abortion Act
# pick new replacement
# * replacement: the Renewables Obligation
# pick new replacement
# * replacement: Section 28
# pick new replacement
# * replacement: Article 8 of the Human Rights Act
# pick new replacement
# * replacement: the Royal Welsh Show
# pick new replacement
# * replacement: Oslo Accords
# pick new replacement
# * replacement: the Royal Family
# pick new replacement
# * replacement: the Bribery Act
# pick new replacement
# * replacement: the Oslo Accords
# pick new replacement
# * replacement: the Local Government Act
# pick new replacement
# * replacement: Human Rights Watch
# pick new replacement
# * replacement: the 1967 Act
# pick new replacement
# * replacement: the Challenge Cup
# pick new replacement
# * replacement: the Equality Act 2010
# pick new replacement
# * replacement: the Wales Act
# pick new replacement
# * replacement: Section 41
# pick new replacement
# * replacement: the European Convention on Human Rights
# pick new replacement
# * replacement: a Labour Government
# pick new replacement
# * replacement: the Wales Act
# pick new replacement
# * replacement: Brexiteer
#
# ============ data idx: 34 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 35 ============
# * summary: Plans to move a statue depicting a Royal Marine in the Falklands conflict away from Portsmouth seafront have been criticised.
# * chosen_ent: Falklands, label: GPE
# * replacement: Sarawak
#
# ============ data idx: 36 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 37 ============
# * summary: Sussex have appointed former player James Anyon as head coach of their women's side.
# * chosen_ent: Sussex, label: ORG
# * replacement: Parish
#
# ============ data idx: 38 ============
# * summary: League One side Bury have signed former Barnsley defender Reece Brown on a six-month contract.
# * chosen_ent: Brown, label: PERSON
# * replacement: Saint-Etienne
#
# ============ data idx: 39 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 40 ============
# * summary: Performers from 42 countries strode down a long red carpet near Ukraine's parliament this week, as a curtain-raiser to this year's Eurovision Song Contest.
# * chosen_ent: Eurovision, label: GPE
# * replacement: Vancouver
#
# ============ data idx: 41 ============
# * summary: It was 50 years ago today that The Beatles played their first gig at the Cavern Club in Liverpool - the venue where the band built their reputation and where Beatlemania was born.
# * chosen_ent: Cavern, label: ORG
# * replacement: Al Hilal
# pick new replacement
# * replacement: Breast Cancer Campaign
# pick new replacement
# * replacement: Motherland
#
# ============ data idx: 42 ============
# * summary: South Africa's government has proposed a national minimum wage of 3,500 rand ($242; Â£199) a month.
# * chosen_ent: South Africa, label: GPE
# * replacement: Lanzarote
# pick new replacement
# * replacement: Ibiza
# pick new replacement
# * replacement: Chandigarh
# pick new replacement
# * replacement: Swanwick
# pick new replacement
# * replacement: Sabah
# pick new replacement
# * replacement: north Wales'
#
# ============ data idx: 43 ============
# * summary: The death of Ethiopian Prime Minister Meles Zenawi has thrown the populous Horn of Africa giant into a period of deep uncertainty and created a serious leadership vacuum in the region with profound geopolitical implications.
# * chosen_ent: Ethiopia, label: GPE
# * replacement: Palamo
#
# ============ data idx: 44 ============
# * summary: Azhar Ali's unbeaten 66 helped Pakistan to reach 142-4 against Australia on a rain-affected first day of the Boxing Day Test in Melbourne.
# * chosen_ent: Australia, label: GPE
# * replacement: Greenwich
#
# ============ data idx: 45 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 46 ============
# * summary: Russia has said it will carry on bombing rebel-held eastern Aleppo in Syria, defying US demands to stop.
# * chosen_ent: US, label: GPE
# * replacement: Mountaineering Scotland
# pick new replacement
# * replacement: Penryn
#
# ============ data idx: 47 ============
# * summary: Wales Under-20 Grand Slam winners Shaun Evans and Dafydd Hughes have signed their first professional contracts with Scarlets.
# * chosen_ent: Wales, label: GPE
# * replacement: Perranporth
#
# ============ data idx: 48 ============
# * summary: The expulsion of 35 Russian diplomats from the US over the email hacking scandal has drawn a barrage of abuse from Moscow, which seems poised to respond in kind.
# * chosen_ent: Russia, label: GPE
# * replacement: BST
#
# ============ data idx: 49 ============
# * summary: Scrapping tuition fees in England is the biggest and most expensive proposal in Labour's £25bn worth of pledges for education.
# * chosen_ent: Labour, label: ORG
# * replacement: Kincardine
#
# ============ data idx: 50 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 51 ============
# * summary: The US director of national intelligence has said he "never felt pressured" to influence the inquiry into Russia's political meddling.
# * chosen_ent: Russia, label: GPE
# * replacement: Olympic
#
# ============ data idx: 52 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 53 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 54 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 55 ============
# * summary: US investigators have closed an inquiry into whether To Kill A Mockingbird author Harper Lee was pressured into publishing a sequel.
# * chosen_ent: Lee, label: PERSON
# * replacement: Solo
#
# ============ data idx: 56 ============
# * summary: The US has said it is suspending talks with Russia over Syria, accusing Moscow of having "failed to live up" to its commitments under a ceasefire deal.
# * chosen_ent: Russia, label: GPE
# * replacement: the South Bank
# pick new replacement
# * replacement: the Netherlands
# pick new replacement
# * replacement: Trowbridge
#
# ============ data idx: 57 ============
# * summary: Labour's Sadiq Khan has been elected Mayor of London, becoming the city's first Muslim mayor.
# * chosen_ent: Khan, label: PERSON
# * replacement: Peter Martin
# pick new replacement
# * replacement: Frederic Frans
# pick new replacement
# * replacement: Peter Pan
# pick new replacement
# * replacement: Fuller
#
# ============ data idx: 58 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 59 ============
# * summary: Manchester City midfielder Kevin de Bruyne says he will be out for about 10 weeks after injuring his right knee during Wednesday's League Cup semi-final victory over Everton.
# * chosen_ent: Kevin, label: PERSON
# * replacement: David Gower
# pick new replacement
# * replacement: Dr Carson
# pick new replacement
# * replacement: Rijeka
#
# ============ data idx: 60 ============
# * summary: A 34-year-old woman who was injured in an attack by a knifeman on a Swiss train has died in hospital, police say.
# * chosen_ent: Swiss, label: NORP
# * replacement: Arabic
#
# ============ data idx: 61 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 62 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 63 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 64 ============
# * summary: Regional official Tim Roache has been elected to become the new general secretary of the GMB union.
# * chosen_ent: GMB, label: ORG
# * replacement: Patchell
#
# ============ data idx: 65 ============
# * summary: We go behind the scenes with singer Laura Mvula as she prepares to debut her new material and kick off the 48th series of Later... with Jools Holland.
# * chosen_ent: Laura, label: PERSON
# * replacement: Livett
#
# ============ data idx: 66 ============
# * summary: Newcastle midfielder Jonas Gutierrez says he feels "born again" following his return to Premier League action after overcoming testicular cancer.
# * chosen_ent: Gutierrez, label: PERSON
# * replacement: Ben Botica
# pick new replacement
# * replacement: Kiko Femenía
# pick new replacement
# * replacement: David Harris
# pick new replacement
# * replacement: Churchill Way
# pick new replacement
# * replacement: Lawlor
#
# ============ data idx: 67 ============
# * summary: League Two Exeter City made a profit of over £1.6m last year, according to the club's latest accounts.
# * chosen_ent: Exeter, label: ORG
# * replacement: Poleon
#
# ============ data idx: 68 ============
# * summary: Para-athlete Abdullah Hayayei died after a metal throwing cage fell on him during training.
# * chosen_ent: Hayayei, label: PERSON
# * replacement: Wickham
#
# ============ data idx: 69 ============
# * summary: Manufacturers have reported positive business trends, in the latest survey from the Scottish Chambers of Commerce.
# * chosen_ent: Scottish, label: NORP
# * replacement: Islamism
#
# ============ data idx: 70 ============
# * summary: The public inquiry into undercover policing may "expose both creditable and discreditable conduct", chairman Lord Justice Pitchford has warned.
# * chosen_ent: Pitchford, label: PERSON
# * replacement: Shirley Williams
# pick new replacement
# * replacement: Wayne Bennett
# pick new replacement
# * replacement: Andrew Foster
# pick new replacement
# * replacement: Ivan Lucic
# pick new replacement
# * replacement: John F Kennedy
# pick new replacement
# * replacement: Download
#
# ============ data idx: 71 ============
# * summary: Reigning champions New Zealand are into their fourth World Cup final after slogging past South Africa in another Twickenham epic.
# * chosen_ent: South Africa, label: GPE
# * replacement: M23
# pick new replacement
# * replacement: Muzaffarabad
# pick new replacement
# * replacement: Ballynahinch
# pick new replacement
# * replacement: Dunstable
# pick new replacement
# * replacement: Fairfax
# pick new replacement
# * replacement: Standing Rock
#
# ============ data idx: 72 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 73 ============
# * summary: Profit jumped at Zara owner Inditex in the first half of the year as the firm opened new stores and invested in online.
# * chosen_ent: Zara, label: PERSON
# * replacement: Nikolai Patrushev
# pick new replacement
# * replacement: Asmir Begovic
# pick new replacement
# * replacement: Courtney Davies
# pick new replacement
# * replacement: Greenwood
#
# ============ data idx: 74 ============
# * summary: Lady Gaga is leading the pitch invasion at Sunday's Super Bowl, where she'll perform the all-important half-time show.
# * chosen_ent: Super Bowl, label: EVENT
# * replacement: The Daily Show
# pick new replacement
# * replacement: Aberdare
# pick new replacement
# * replacement: 7 September
#
# ============ data idx: 75 ============
# * summary: A victim of the Rochdale grooming gang says the convictions were still "not fazing" Asian child sex abusers.
# * chosen_ent: Asian, label: NORP
# * replacement: Mormon
#
# ============ data idx: 76 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 77 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 78 ============
# * summary: New Sale Sharks chairman Fran Cotton has conceded they must work to restore their relationship with some fans.
# * chosen_ent: Cotton, label: PERSON
# * replacement: Jeremy Chardy
# pick new replacement
# * replacement: Pulse
#
# ============ data idx: 79 ============
# * summary: Disney's latest animation Moana dominated the Thanksgiving box office over the five-day US holiday weekend.
# * chosen_ent: Disney, label: ORG
# * replacement: Finance Wales'
# pick new replacement
# * replacement: Buckie
#
# ============ data idx: 80 ============
# * summary: British number one Johanna Konta reached the quarter-finals of the Bank of the West Classic in Stanford with a straight-set win over Julia Boserup.
# * chosen_ent: Konta, label: GPE
# * replacement: Andalusia
#
# ============ data idx: 81 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 82 ============
# * summary: The Ebola victim who is believed to have triggered the current outbreak - a two-year-old boy called Emile Ouamouno from Guinea - may have been infected by playing in a hollow tree housing a colony of bats, say scientists.
# * chosen_ent: Emile, label: PERSON
# * replacement: Malek Jaziri
# pick new replacement
# * replacement: William Hurt
# pick new replacement
# * replacement: Fernando Hierro
# pick new replacement
# * replacement: Jen
#
# ============ data idx: 83 ============
# * summary: Stuart Bingham may pull out of the Masters if his wife goes into labour with their third child.
# * chosen_ent: Bingham, label: PERSON
# * replacement: Christopher Donnellan QC
# pick new replacement
# * replacement: Aimee
#
# ============ data idx: 84 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 85 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 86 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 87 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 88 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 89 ============
# * summary: Uzbekistan's Hasanboy Dusmatov won Olympic gold in the men's light-flyweight with victory over Colombian Yuberjen Herney Martinez.
# * chosen_ent: Martinez, label: GPE
# * replacement: Zurich
#
# ============ data idx: 90 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 91 ============
# * summary: Controversial proposals to shut a Catholic school in East Dunbartonshire are to be examined by the Scottish government.
# * chosen_ent: Scottish, label: NORP
# * replacement: Northern Irishman
# pick new replacement
# * replacement: Ecuadorian
#
# ============ data idx: 92 ============
# * summary: Japanese footballer Kazuyoshi Miura has signed a one-year contract extension with Yokohama FC at the age of 48.
# * chosen_ent: Miura, label: ORG
# * replacement: Rebels
#
# ============ data idx: 93 ============
# * summary: Clashes have broken out in Indian-administered Kashmir on the anniversary of the killing of a militant leader.
# * chosen_ent: Indian, label: NORP
# * replacement: sub-Saharan
#
# ============ data idx: 94 ============
# * summary: Economic policymakers must now decide whether and how they should respond to the UK's vote to leave the EU.
# * chosen_ent: UK, label: GPE
# * replacement: Oasis
#
# ============ data idx: 95 ============
# * summary: Sale Sharks forward Mark Easter has announced he will retire at the end of the season to take up a teaching role.
# * chosen_ent: Sale, label: ORG
# * replacement: Newcastle United 3
# pick new replacement
# * replacement: SACP
#
# ============ data idx: 96 ============
# * summary: The quality of care on a scandal-hit ward for dementia patients may have contributed to at least seven deaths, BBC Wales can reveal.
# * chosen_ent: BBC Wales, label: ORG
# * replacement: Camberley
# pick new replacement
# * replacement: Eltham
# pick new replacement
# * replacement: Kings Norton
#
# ============ data idx: 97 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 98 ============
# * summary: The United States women's team goalkeeper Hope Solo has been suspended for 30 days by US Soccer following an incident during a training camp.
# * chosen_ent: Solo, label: ORG
# * replacement: Hawick Knitwear
# pick new replacement
# * replacement: Consumer Prices Index
# pick new replacement
# * replacement: Medway Secure Training Centre
# pick new replacement
# * replacement: Hampstead
#
# ============ data idx: 99 ============
# * summary: A barrister who was due to move into his own chambers in Huddersfield has pleaded guilty to supplying cocaine.
# * chosen_ent: Huddersfield, label: GPE
# * replacement: South Carolina's
# pick new replacement
# * replacement: Valparaiso
#
# ============ data idx: 100 ============
# * summary: Officers who police Scotland's railways are to be armed with Tasers in a bid to increase security on the network.
# * chosen_ent: Taser, label: NORP
# * replacement: Irish
#
# ============ data idx: 101 ============
# * summary: Scottish engineering services company ID Systems Ltd has announced plans to create 120 new jobs after securing a six-figure investment from UK Steel Enterprise (UKSE).
# * chosen_ent: UKSE, label: ORG
# * replacement: Kmart
#
# ============ data idx: 102 ============
# * summary: A Brazilian football player who survived a plane crash in Colombia on Monday is recovering and may be able to resume his career, his father says.
# * chosen_ent: Brazil, label: GPE
# * replacement: West Derby
# pick new replacement
# * replacement: Kismayo
#
# ============ data idx: 103 ============
# * summary: Actor and broadcaster Sir Tony Robinson has said plans for a tunnel near Stonehenge in Wiltshire are too "old-fashioned" in outlook.
# * chosen_ent: Robinson, label: PERSON
# * replacement: Rose Polge
# pick new replacement
# * replacement: Darren Price
# pick new replacement
# * replacement: Nikita Khrushchev
# pick new replacement
# * replacement: Alan Clarke
# pick new replacement
# * replacement: Hanan Ashrawi
# pick new replacement
# * replacement: David McMillan
# pick new replacement
# * replacement: Russell Griffiths
# pick new replacement
# * replacement: Duncan McNeil
# pick new replacement
# * replacement: Alexander Perepilichnyy
# pick new replacement
# * replacement: Pussy Riot
# pick new replacement
# * replacement: Lai
#
# ============ data idx: 104 ============
# * summary: Everton marked their Europa League return with a dominant victory over Germans Wolfsburg at Goodison Park.
# * chosen_ent: Wolfsburg, label: ORG
# * replacement: McCulloch
#
# ============ data idx: 105 ============
# * summary: Scunthorpe midfielder Neal Bishop has signed a one-year contract extension.
# * chosen_ent: Bishop, label: ORG
# * replacement: Elliptic
#
# ============ data idx: 106 ============
# * summary: A man from Croydon has been charged with murder after the death of his partner last month.
# * chosen_ent: Croydon, label: GPE
# * replacement: Scot
#
# ============ data idx: 107 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 108 ============
# * summary: The Premiership's top try scorer Christian Wade scored two tries as leaders Wasps moved five points clear with a bonus-point win over Worcester.
# * chosen_ent: Worcester, label: GPE
# * replacement: Washington DC's
# pick new replacement
# * replacement: Charlotte
#
# ============ data idx: 109 ============
# * summary: A Frenchwoman injured in the attack on Tunisia's national museum has died of her wounds, bringing the total killed in the assault by Islamists to 22.
# * chosen_ent: Tunisia, label: GPE
# * replacement: Puebla
#
# ============ data idx: 110 ============
# * summary: Satellite images of Mosul have revealed how fighters from so-called Islamic State (IS) have destroyed much of the city's airport to render it unusable as Iraqi forces close in.
# * chosen_ent: Mosul, label: GPE
# * replacement: Toronto
#
# ============ data idx: 111 ============
# * summary: Network Rail has promised to do "everything in its power" to stop a repeat of the rail chaos at Christmas when it carries out work over Easter.
# * chosen_ent: Network Rail, label: ORG
# * replacement: NHS Employers
#
# ============ data idx: 112 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 113 ============
# * summary: Amazon, the global online retailer, is changing the way it records sales in a move that could see it paying more tax.
# * chosen_ent: Amazon, label: ORG
# * replacement: iTele
#
# ============ data idx: 114 ============
# * summary: Junior doctors should suspend Tuesday's strike action over pay and conditions while talks continue, the chief medical officer for England has urged.
# * chosen_ent: England, label: GPE
# * replacement: Lorient
#
# ============ data idx: 115 ============
# * summary: Oxford United have extended the loan of right-back Jonjoe Kenny from Premier League side Everton until the end of the season.
# * chosen_ent: Kenny, label: PERSON
# * replacement: Joe Ward
# pick new replacement
# * replacement: Berra
#
# ============ data idx: 116 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 117 ============
# * summary: The family of the former footballer Jeff Astle is to meet the FA chairman next month to discuss head injuries in the game, as part of their campaign.
# * chosen_ent: Astle, label: PERSON
# * replacement: Wesson
#
# ============ data idx: 118 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 119 ============
# * summary: Brothers Ben and Tom Curry have signed five-year contracts with Sale Sharks.
# * chosen_ent: Sale, label: ORG
# * replacement: Walker
#
# ============ data idx: 120 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 121 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 122 ============
# * summary: Fracking for shale gas in Wales should still be opposed despite plans to fast-track such schemes in England, the Welsh government has said.
# * chosen_ent: Wales, label: GPE
# * replacement: El Chapo
# pick new replacement
# * replacement: Saundersfoot
#
# ============ data idx: 123 ============
# * summary: For a man often described as capricious, Tyson Fury's chaotic reign as world heavyweight champion was strangely predictable.
# * chosen_ent: Fury, label: ORG
# * replacement: Â£15bn
#
# ============ data idx: 124 ============
# * summary: England coach Eddie Jones will name his 45-man Elite Player Squad squad ahead of the autumn Tests at 10:00 BST on Friday.
# * chosen_ent: England, label: GPE
# * replacement: Haringey
#
# ============ data idx: 125 ============
# * summary: A collection of paintings capturing the landscapes and legacy of life on the North East coast is going on display.
# * chosen_ent: the North East, label: LOC
# * replacement: Jungle
# pick new replacement
# * replacement: South-East Asian
# pick new replacement
# * replacement: Ms Park
# pick new replacement
# * replacement: Severn
# pick new replacement
# * replacement: Byron Bay
# pick new replacement
# * replacement: Pacific Ocean
# pick new replacement
# * replacement: Lakes
# pick new replacement
# * replacement: Southbank
# pick new replacement
# * replacement: the Bay of Bengal
# pick new replacement
# * replacement: Arctic sea
# pick new replacement
# * replacement: South East Coast Ambulance Service
# pick new replacement
# * replacement: MacKenzie
# pick new replacement
# * replacement: Rift Valley
# pick new replacement
# * replacement: the River Avon
#
# ============ data idx: 126 ============
# * summary: Hibernian's Neil Lennon believes Scott Brown retired too soon from Scotland duty and still has plenty to offer now he has decided to return.
# * chosen_ent: Lennon, label: PERSON
# * replacement: Jes Staley
# pick new replacement
# * replacement: Stefan Marsh
# pick new replacement
# * replacement: Niamh Briggs
# pick new replacement
# * replacement: Alex
#
# ============ data idx: 127 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 128 ============
# * summary: Post Office workers will stage five days of strikes from Monday in a continuing dispute over jobs, pensions and branch closures, their union says.
# * chosen_ent: Post Office, label: ORG
# * replacement: La Linea
#
# ============ data idx: 129 ============
# * summary: The Ulster Unionist leader has denied he made a mistake by saying he intends to give the SDLP his second preference in the Assembly election.
# * chosen_ent: Ulster, label: ORG
# * replacement: Crisis
#
# ============ data idx: 130 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 131 ============
# * summary: Sinn FÃ©in leader Gerry Adams has said there is "a need to be open and imaginative" on new constitutional arrangements.
# * chosen_ent: Adams, label: PERSON
# * replacement: Sara Pascoe
# pick new replacement
# * replacement: Tom Beere
# pick new replacement
# * replacement: McGhee
#
# ============ data idx: 132 ============
# * summary: Morecambe must not get carried away despite sitting top of League Two, says Shrimps boss Jim Bentley.
# * chosen_ent: Bentley, label: ORG
# * replacement: the Scottish Fishermen's Federation
# pick new replacement
# * replacement: BluMarble
#
# ============ data idx: 133 ============
# * summary: Some demands set by four Arab states on Qatar in return for lifting sanctions will be "difficult to meet", US Secretary of State Rex Tillerson says.
# * chosen_ent: Qatar, label: GPE
# * replacement: Yorkshire Dales
# pick new replacement
# * replacement: Duns
#
# ============ data idx: 134 ============
# * summary: UKIP ex-deputy chairwoman Suzanne Evans says she has given up hope of becoming the party's next leader - but insists she will not "give up" on UKIP.
# * chosen_ent: UKIP, label: ORG
# * replacement: the Fire Brigades Union
# pick new replacement
# * replacement: National Eisteddfod
# pick new replacement
# * replacement: Turing
#
# ============ data idx: 135 ============
# * summary: A court in the Indian capital has formally charged a driver of the Uber web-based taxi firm with the rape and kidnapping of a passenger last month.
# * chosen_ent: Indian, label: NORP
# * replacement: Azerbaijani
#
# ============ data idx: 136 ============
# * summary: Standing hand-in-hand like theatre actors at their curtain call, Wales' players were met with a spine-tingling rendition of the national anthem from their fans following their European Championship semi-final defeat by Portugal.
# * chosen_ent: Wales, label: GPE
# * replacement: Cwmbran
#
# ============ data idx: 137 ============
# * summary: Ferguslie Park in Paisley has been identified as the area of Scotland with the greatest level of deprivation.
# * chosen_ent: Scotland, label: GPE
# * replacement: Kuwait City
# pick new replacement
# * replacement: New Delhi
# pick new replacement
# * replacement: Linwood
#
# ============ data idx: 138 ============
# * summary: Coleraine rower Joel Cassells and Great Britain team-mate Sam Scrimgeour remain on course to defend their lightweight pairs world title after winning their semi-final in Rotterdam on Thursday.
# * chosen_ent: Cassells, label: ORG
# * replacement: Big Yellow Taxi
# pick new replacement
# * replacement: Traynor
#
# ============ data idx: 139 ============
# * summary: Former Kilmarnock winger Chris Johnston has become the third player to sign for Dumbarton this summer after leaving relegated Raith Rovers.
# * chosen_ent: Rovers, label: ORG
# * replacement: Arriva Trains
# pick new replacement
# * replacement: Nottingham City Hospital
# pick new replacement
# * replacement: Gameiro
#
# ============ data idx: 140 ============
# * summary: James Milner's late penalty gave Liverpool a hard-fought victory over Swansea, increasing the scrutiny on Swans boss Francesco Guidolin.
# * chosen_ent: Liverpool, label: GPE
# * replacement: Lerwick
#
# ============ data idx: 141 ============
# * summary: Scottish rugby suffered two body blows this week and, rather like boxer Ricky Burns who "drew" with his opponent after getting one heck of a hiding from opponent Raymundo Beltran, it's a little battered, a little broken and in need of time off the canvas.
# * chosen_ent: Scottish, label: NORP
# * replacement: Acpo
#
# ============ data idx: 142 ============
# * summary: The three-day TRNSMT music festival in Glasgow is to start later with a Friday line-up of acts including Radiohead and Belle and Sebastian.
# * chosen_ent: TRNSMT, label: PERSON
# * replacement: Mr Warner
# pick new replacement
# * replacement: Jobi McAnuff
# pick new replacement
# * replacement: Vincent Kompany
# pick new replacement
# * replacement: Dan Sarginson
# pick new replacement
# * replacement: Glen Affric
# pick new replacement
# * replacement: Jonathan Shepherd
# pick new replacement
# * replacement: Keogh
#
# ============ data idx: 143 ============
# * summary: The US has warned North Korea to refrain from "irresponsible provocation" after the communist state said its main nuclear facility had resumed normal operations.
# * chosen_ent: North Korea, label: GPE
# * replacement: Braley
# pick new replacement
# * replacement: Boulder
# pick new replacement
# * replacement: Stow
# pick new replacement
# * replacement: Zouma
# pick new replacement
# * replacement: Adamsdown
# pick new replacement
# * replacement: Rapids
# pick new replacement
# * replacement: Guatemala City
#
# ============ data idx: 144 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 145 ============
# * summary: Picture the scene inside the BBC 5 live studio: a millionaire owner of a now managerless Super League club, a highly rated out-of-work coach keen for a return to the sport and an iconic player from a rival club that the owner wants to sign.
# * chosen_ent: Super League, label: ORG
# * replacement: 2013 Lions
#
# ============ data idx: 146 ============
# * summary: Ireland eased to seven-wicket win over Zimbabwe to top their Women's World Twenty20 qualifying group and set up a semi-final against Scotland.
# * chosen_ent: Zimbabwe, label: GPE
# * replacement: Porto
#
# ============ data idx: 147 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 148 ============
# * summary: Great Britain's Mark Cavendish is third after day one of the men's omnium as he aims for his first Olympic Games medal.
# * chosen_ent: Cavendish, label: PERSON
# * replacement: John Kerry's
# pick new replacement
# * replacement: Paulo Dybala
# pick new replacement
# * replacement: François Hollande
# pick new replacement
# * replacement: McGowan
#
# ============ data idx: 149 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 150 ============
# * summary: The Winklevoss brothers have re-started their long-running legal dispute with Facebook and its boss Mark Zuckerberg.
# * chosen_ent: Facebook, label: ORG
# * replacement: S4C.
#
# ============ data idx: 151 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 152 ============
# * summary: Chapman Pincher was known as "the lone wolf of Fleet Street".
# * chosen_ent: Pincher, label: PERSON
# * replacement: Cory Hill
# pick new replacement
# * replacement: Bashar Assad
# pick new replacement
# * replacement: Clarence Place
# pick new replacement
# * replacement: Scott Rumsby
# pick new replacement
# * replacement: Mr Kinnock
# pick new replacement
# * replacement: Kim Cattrall
# pick new replacement
# * replacement: Mrs Hughes
# pick new replacement
# * replacement: Callum McGregor's
# pick new replacement
# * replacement: Luke Bartholomew
# pick new replacement
# * replacement: Gigg Lane
# pick new replacement
# * replacement: Simona
#
# ============ data idx: 153 ============
# * summary: Birmingham City have signed Dundee forward Greg Stewart on a three-year deal for a fee believed to be around £500,000.
# * chosen_ent: Birmingham, label: GPE
# * replacement: Shenton
#
# ============ data idx: 154 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 155 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 156 ============
# * summary: Four men were arrested in north London when police found a gun, a sword and a knife in the car they were travelling in.
# * chosen_ent: London, label: GPE
# * replacement: White City
# pick new replacement
# * replacement: Atlanta
#
# ============ data idx: 157 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 158 ============
# * summary: Lord Derby has won a key High Court stage of his fight to build 400 homes on his land.
# * chosen_ent: Derby, label: GPE
# * replacement: Karanka
#
# ============ data idx: 159 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 160 ============
# * summary: French side Lille have exercised their option to sign Naim Sliti on a permanent deal when his loan move from second-tier side Red Star expires this summer.
# * chosen_ent: Lille, label: GPE
# * replacement: Minto
#
# ============ data idx: 161 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 162 ============
# * summary: World champion cyclist Martyn Irvine has been named the 2013 BBC Northern Ireland Sports Personality of the Year.
# * chosen_ent: Irvine, label: GPE
# * replacement: Peterlee
#
# ============ data idx: 163 ============
# * summary: A civilian cargo aircraft has landed safely after being escorted into Prestwick Airport in Ayrshire after suffering technical problems with its communications equipment.
# * chosen_ent: Prestwick, label: GPE
# * replacement: Marseilles
#
# ============ data idx: 164 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 165 ============
# * summary: Euro 2016 will be contested by 24 teams over 30 days at 10 different venues in France.
# * chosen_ent: France, label: GPE
# * replacement: Yarde
#
# ============ data idx: 166 ============
# * summary: BBC Sport is showing live coverage of the EuroBasket warm-up game between Great Britain and Greece at the Copper Box in London on Saturday 19 August.
# * chosen_ent: Greece, label: GPE
# * replacement: Preseli Pembrokeshire
# pick new replacement
# * replacement: The Gambia
# pick new replacement
# * replacement: Gauteng
#
# ============ data idx: 167 ============
# * summary: Australia weathered a Welsh storm to win World Cup Pool A with a 15-6 victory at Twickenham.
# * chosen_ent: Australia, label: GPE
# * replacement: South Wales Fire and Rescue Service
# pick new replacement
# * replacement: Hammond
#
# ============ data idx: 168 ============
# * summary: Josh Strauss believes Vern Cotter's impending departure will provide added motivation for Scotland to have a successful Six Nations.
# * chosen_ent: Scotland, label: GPE
# * replacement: County Kildare
# pick new replacement
# * replacement: Palestine
#
# ============ data idx: 169 ============
# * summary: Ex-CIA Director David Petraeus has told the BBC that Islamic State militants can only be defeated through a dual military and political approach.
# * chosen_ent: Petraeus, label: PERSON
# * replacement: Ed Joyce
# pick new replacement
# * replacement: Joelle Murray
# pick new replacement
# * replacement: Ms Price
# pick new replacement
# * replacement: Alfred Hitchcock
# pick new replacement
# * replacement: Dave Callaghan
# pick new replacement
# * replacement: Stephen Milne
# pick new replacement
# * replacement: Mark McDonald
# pick new replacement
# * replacement: Gerardo Martino
# pick new replacement
# * replacement: Ajmal Shahzad
# pick new replacement
# * replacement: McGurk
#
# ============ data idx: 170 ============
# * summary: More than 13,000 email addresses have been stolen from Edinburgh city council's database following a "malicious cyber attack".
# * chosen_ent: Edinburgh, label: GPE
# * replacement: Medellin
#
# ============ data idx: 171 ============
# * summary: Rebels say they have begun a new battle in north-western Syria in response to alleged truce violations by the army.
# * chosen_ent: Syria, label: GPE
# * replacement: Carlisle United 0
# pick new replacement
# * replacement: Faslane
#
# ============ data idx: 172 ============
# * summary: The photo sharing service Instagram announced it will start placing ads in US users photo streams in a posting on its website.
# * chosen_ent: Instagram, label: ORG
# * replacement: the Association of Chief Police Officers
# pick new replacement
# * replacement: HSENI
#
# ============ data idx: 173 ============
# * summary: Actor Michael C Hall is to perform a tribute to David Bowie at this week's Mercury Music Prize ceremony.
# * chosen_ent: Bowie, label: PERSON
# * replacement: Medwin Hughes
# pick new replacement
# * replacement: Dr Sentamu
# pick new replacement
# * replacement: Valeant
#
# ============ data idx: 174 ============
# * summary: A former Metropolitan Police officer has been found not guilty of sexually assaulting a teenage boy in the back of a police van nearly 30 years ago.
# * chosen_ent: Metropolitan Police, label: ORG
# * replacement: AGM
# pick new replacement
# * replacement: Wigan Council
#
# ============ data idx: 175 ============
# * summary: Welsh Secretary Alun Cairns has rejected calls for a "softer" Brexit after the general election result led to a hung parliament.
# * chosen_ent: Brexit, label: LAW
# ...
# * replacement: the Scottish Police Authority
# pick new replacement
# * replacement: Connected TV
# pick new replacement
# * replacement: The North East Counter Terrorism Unit
# pick new replacement
# * replacement: the Department for Business, Innovation and Skills
# pick new replacement
# * replacement: Y Combinator
# pick new replacement
# * replacement: Plymouth Coroner's Court
# pick new replacement
# * replacement: King Salman
# pick new replacement
# * replacement: Scotland Women
# pick new replacement
# * replacement: Mafia
#
# ============ data idx: 11290 ============
# * summary: Carl Frampton's world featherweight title bout with defending champion Leo Santa Cruz will take place on 30 July in New York.
# * chosen_ent: Frampton, label: PERSON
# * replacement: Bashar Jaafari
# pick new replacement
# * replacement: John Newman
# pick new replacement
# * replacement: Harry Redknapp
# pick new replacement
# * replacement: Mohammad
#
# ============ data idx: 11291 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11292 ============
# * summary: All-rounder Sean Ervine made a vital century for Hampshire as they reached 281-6 on the opening day against Somerset at Taunton.
# * chosen_ent: Somerset, label: GPE
# * replacement: Virgin Atlantic
# pick new replacement
# * replacement: mid Wales
# pick new replacement
# * replacement: Hoffenheim
#
# ============ data idx: 11293 ============
# * summary: Bright neon strips of light that punctuate the dark skies of Jeddah in Saudi Arabia caught the eye of Celine Stella, who set out to photograph them whenever she had a spare moment.
# * chosen_ent: Stella, label: PERSON
# * replacement: Maggie Chapman
# pick new replacement
# * replacement: Mrs Allen
# pick new replacement
# * replacement: Halford
#
# ============ data idx: 11294 ============
# * summary: Tens of millions of users who visit Google sites use a browser loaded with malicious add-ons, research suggests.
# * chosen_ent: Google, label: ORG
# * replacement: Scunthorpe United 1
# pick new replacement
# * replacement: Heineken
#
# ============ data idx: 11295 ============
# * summary: PM Malcolm Turnbull has said there are more urgent issues facing Australia than the debate on becoming a republic.
# * chosen_ent: Australia, label: GPE
# * replacement: Neymar
#
# ============ data idx: 11296 ============
# * summary: Jonjo Shelvey made an impressive debut for Newcastle as he helped his side move out of the relegation zone with a win over West Ham.
# * chosen_ent: Shelvey, label: ORG
# * replacement: Park View School
# pick new replacement
# * replacement: The Ulster Farmers' Union
# pick new replacement
# * replacement: The Hillsborough Family Support Group
# pick new replacement
# * replacement: Ringrose
#
# ============ data idx: 11297 ============
# * summary: Sugar Ray Leonard, Floyd Mayweather, Gennady Golovkin and even the great Muhammad Ali used the Olympic Games as a springboard for boxing superstardom.
# * chosen_ent: Olympic, label: EVENT
# * replacement: the Autumn Statement
# pick new replacement
# * replacement: the FA Cup quarter
# pick new replacement
# * replacement: the 2012 Olympic Games
# pick new replacement
# * replacement: County Championship
# pick new replacement
# * replacement: Vietnam War
# pick new replacement
# * replacement: the EFL Cup
# pick new replacement
# * replacement: Tokyo Games
# pick new replacement
# * replacement: South China Morning Post
# pick new replacement
# * replacement: the British Soap Awards
# pick new replacement
# * replacement: a League Cup
# pick new replacement
# * replacement: World Tour
# pick new replacement
# * replacement: the French Open
# pick new replacement
# * replacement: the Syrian war
# pick new replacement
# * replacement: the Afghan war
# pick new replacement
# * replacement: the 2011 Worlds
# pick new replacement
# * replacement: 2010 World Cup
# pick new replacement
# * replacement: European Champions Cup
# pick new replacement
# * replacement: the European Convention on Human Rights
# pick new replacement
# * replacement: Asia Cup
# pick new replacement
# * replacement: the Spanish Civil War
# pick new replacement
# * replacement: the Paris Agreement
# pick new replacement
# * replacement: the Royal Festival Hall
# pick new replacement
# * replacement: the Australian Open
# pick new replacement
# * replacement: Cold War
# pick new replacement
# * replacement: the Challenge Cup
# pick new replacement
# * replacement: London 2012
# pick new replacement
# * replacement: this World Cup
# pick new replacement
# * replacement: the Cold War years
# pick new replacement
# * replacement: the 2018 World Cup
# pick new replacement
# * replacement: Republic Day
# pick new replacement
# * replacement: the Syrian war
# pick new replacement
# * replacement: Winter Olympics
# pick new replacement
# * replacement: Canadian Grand Prix
# pick new replacement
# * replacement: Super Cup
# pick new replacement
# * replacement: the World Series
# pick new replacement
# * replacement: Pool Four
# pick new replacement
# * replacement: the 2012 Tour
# pick new replacement
# * replacement: the Wales Bill
# pick new replacement
# * replacement: U-20 World Cup
# pick new replacement
# * replacement: Island Games
# pick new replacement
# * replacement: the 1966 World Cup
# pick new replacement
# * replacement: The Sydney Morning Herald
# pick new replacement
# * replacement: the 2010
# pick new replacement
# * replacement: the Iraq War
# pick new replacement
# * replacement: World Book Day
# pick new replacement
# * replacement: London Olympics
# pick new replacement
# * replacement: Astral Weeks
# pick new replacement
# * replacement: Hurricane Katrina
# pick new replacement
# * replacement: Bahrain Grand Prix
# pick new replacement
# * replacement: the Euro 2012
# pick new replacement
# * replacement: the Northern Trust Open
# pick new replacement
# * replacement: World Golf Championship
# pick new replacement
# * replacement: Women's World Cup
# pick new replacement
# * replacement: the PGA Championship
# pick new replacement
# * replacement: Spanish Grand Prix
# pick new replacement
# * replacement: World Championship
# pick new replacement
# * replacement: a US Open
# pick new replacement
# * replacement: European Challenge Cup
# pick new replacement
# * replacement: Whitby
#
# ============ data idx: 11298 ============
# * summary: One of the most striking factors about this election campaign is that Labour and the Conservative Party appear to be running two entirely unconnected election campaigns.
# * chosen_ent: Labour, label: ORG
# * replacement: Agen
#
# ============ data idx: 11299 ============
# * summary: A feature-length documentary film about the founder of Europe's first Tibetan Buddhist centre in Dumfriesshire has staged its world premiere.
# * chosen_ent: Tibet, label: GPE
# * replacement: Bronx
#
# ============ data idx: 11300 ============
# * summary: The chancellor has announced a £2bn rescue package for the social care sector in England.
# * chosen_ent: England, label: GPE
# * replacement: Fort William
# pick new replacement
# * replacement: Tibet
#
# ============ data idx: 11301 ============
# * summary: A cyclist who knocked over and killed a woman posted on online forums the crash was "her fault", the Old Bailey heard.
# * chosen_ent: the Old Bailey, label: FAC
# * replacement: Vicarage Road
# pick new replacement
# * replacement: Pearl Roundabout
# pick new replacement
# * replacement: Bridle Close
# pick new replacement
# * replacement: the Royal Free
#
# ============ data idx: 11302 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11303 ============
# * summary: The US Navy has banned all its personnel in Japan from drinking alcohol and has restricted off-base activity after a sailor was arrested on suspicion of drunk driving.
# * chosen_ent: US, label: GPE
# * replacement: South Tyneside
# pick new replacement
# * replacement: Williams
#
# ============ data idx: 11304 ============
# * summary: What a week - first Clarkson, then Zayn, and now Bercow?
# * chosen_ent: Bercow, label: PERSON
# * replacement: Francois Molins
# pick new replacement
# * replacement: Gower
#
# ============ data idx: 11305 ============
# * summary: The music video for South Korean singer Psy's Gangnam Style exceeded YouTube's view limit, prompting the site to upgrade its counter.
# * chosen_ent: YouTube, label: ORG
# * replacement: Bharti Airtel
# pick new replacement
# * replacement: India Direct
# pick new replacement
# * replacement: Det Supt
# pick new replacement
# * replacement: CfD
#
# ============ data idx: 11306 ============
# * summary: Patrick Ah Van scored two tries on his return from a five-match ban to help Widnes to victory at Castleford.
# * chosen_ent: Castleford, label: GPE
# * replacement: Hartley
#
# ============ data idx: 11307 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11308 ============
# * summary: A failing health trust has been placed in special measures, meaning all Cumbria hospital trusts are now getting extra help to boost performance.
# * chosen_ent: Cumbria, label: GPE
# * replacement: Abkhazia
#
# ============ data idx: 11309 ============
# * summary: Gareth O'Brien kicked a drop-goal in golden-point extra time as Salford won the 'Million Pound Game' 19-18 to relegate Hull KR from Super League.
# * chosen_ent: Salford, label: GPE
# * replacement: Baton Rouge
# pick new replacement
# * replacement: Liverpool
#
# ============ data idx: 11310 ============
# * summary: "I think it's really sad and wrong they think we're terrorists, because we're not," says Chilla, a bright and articulate sixth-former at the elite Kharisma Bangsa high school near Jakarta, Indonesia's capital.
# * chosen_ent: Kharisma Bangsa, label: PERSON
# * replacement: Jo Love
#
# ============ data idx: 11311 ============
# * summary: A man in his 40s has been arrested after a man found with head injuries in Waterford city centre on Christmas Day died in hospital.
# * chosen_ent: Waterford, label: GPE
# * replacement: Heremaia
#
# ============ data idx: 11312 ============
# * summary: Blackburn were relegated to League One on goal difference, despite beating Brentford at Griffin Park, after Nottingham Forest's win over Ipswich.
# * chosen_ent: Brentford, label: ORG
# * replacement: the Syrian Observatory for Human Rights
# pick new replacement
# * replacement: Fantastic Beasts
# pick new replacement
# * replacement: Annan Athletic
# pick new replacement
# * replacement: Wales Cricket Board's
# pick new replacement
# * replacement: Invictus Games
# pick new replacement
# * replacement: Harland
#
# ============ data idx: 11313 ============
# * summary: School lunches can tempt fussy eaters to try new foods, a survey for the School Food Trust has suggested.
# * chosen_ent: School Food Trust, label: ORG
# * replacement: Capitol Hill
# pick new replacement
# * replacement: Dale Farm
# pick new replacement
# * replacement: Chirk
# pick new replacement
# * replacement: the Police Ombudsman
#
# ============ data idx: 11314 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11315 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11316 ============
# * summary: The two candidates competing to be the next managing director of the International Monetary Fund (IMF) could not be more different in their appearance.
# * chosen_ent: IMF, label: ORG
# * replacement: Care
#
# ============ data idx: 11317 ============
# * summary: The UK is set to reopen its embassy in Tehran in the coming days, almost four years after it was closed following the storming of the compound by protesters.
# * chosen_ent: UK, label: GPE
# * replacement: Helmshore
#
# ============ data idx: 11318 ============
# * summary: Promotion-chasing Stevenage were held to a by Cambridge in League Two.
# * chosen_ent: Stevenage, label: GPE
# * replacement: Bridport
#
# ============ data idx: 11319 ============
# * summary: Star Wars and Harry Potter star Warwick Davis, who played an ewok in Return of the Jedi, has taken to Twitter to help recover his stolen caravan.
# * chosen_ent: Davis, label: PERSON
# * replacement: Andy Young
# pick new replacement
# * replacement: Jason Donovan
# pick new replacement
# * replacement: Jeff Hendrick
# pick new replacement
# * replacement: Adriano Moke
# pick new replacement
# * replacement: Samuel Badree
# pick new replacement
# * replacement: Jelle Vossen
# pick new replacement
# * replacement: Harvey Hosein
# pick new replacement
# * replacement: Duncan Selbie
# pick new replacement
# * replacement: al-Murabitoun
#
# ============ data idx: 11320 ============
# * summary: Former US president Barack Obama is to make his first visit to Scotland when he addresses business leaders in the capital next month.
# * chosen_ent: Scotland, label: GPE
# * replacement: Senkaku
#
# ============ data idx: 11321 ============
# * summary: The European Court of Human Rights has ruled that Belgium's ban on face veils does not violate the European Convention on Human Rights.
# * chosen_ent: Belgium, label: GPE
# * replacement: Melania
#
# ============ data idx: 11322 ============
# * summary: Another Celtic fan has appeared in court charged with displaying an allegedly offensive banner and blow-up figures at last month's Old Firm match.
# * chosen_ent: Celtic, label: ORG
# * replacement: parish council
# pick new replacement
# * replacement: Mossad
#
# ============ data idx: 11323 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11324 ============
# * summary: When Carolina Cappa, a film researcher working in Bolivia, was invited to go though the  archives of an old cinema in La Paz that was being demolished, she came upon a battered, unmarked tin.
# * chosen_ent: Bolivia, label: GPE
# * replacement: Tbilisi
#
# ============ data idx: 11325 ============
# * summary: The Federal Reserve's latest statement suggests that the path is clear for an interest rate rise in June or September without surprising markets.
# * chosen_ent: Fed, label: ORG
# * replacement: Columbia University's
# pick new replacement
# * replacement: Ford Focus
# pick new replacement
# * replacement: the Western Conference
# pick new replacement
# * replacement: Pimlico
#
# ============ data idx: 11326 ============
# * summary: The Isle of Wight's Conservative MP has survived an attempt by his own party to force him to stand down as a general election candidate.
# * chosen_ent: The Isle of Wight's, label: GPE
# * replacement: Blida
# pick new replacement
# * replacement: the State of Israel
#
# ============ data idx: 11327 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11328 ============
# * summary: Flappy Bird is flapping its wings no more.
# * chosen_ent: Flappy Bird, label: PERSON
# * replacement: Henning
# pick new replacement
# * replacement: Wynne Evans
#
# ============ data idx: 11329 ============
# * summary: Two hundred body bags have been placed on Brighton beach in a protest to highlight the UK's response to the migrant crisis in the Mediterranean.
# * chosen_ent: UK, label: GPE
# * replacement: Hexham
#
# ============ data idx: 11330 ============
# * summary: Budding hospitality workers from the Caribbean will have the chance to train at Buckingham Palace and Windsor Castle under a scholarship programme announced by Prince Harry.
# * chosen_ent: Caribbean, label: LOC
# * replacement: East-West
#
# ============ data idx: 11331 ============
# * summary: Britain's Andy Murray is through to the Monte Carlo Masters semi-finals following an impressive win over Canadian Milos Raonic.
# * chosen_ent: Murray, label: PERSON
# * replacement: Lisa McAlister
# pick new replacement
# * replacement: Niamh
#
# ============ data idx: 11332 ============
# * summary: A forensics expert has swung a cricket bat at a toilet door erected in the courtroom at Oscar Pistorius' murder trial in South Africa to demonstrate key pieces of evidence.
# * chosen_ent: Pistorius, label: PERSON
# * replacement: Russell George
# pick new replacement
# * replacement: Graham Main
# pick new replacement
# * replacement: J Carty
# pick new replacement
# * replacement: Alexis Tsipras
# pick new replacement
# * replacement: Justin Wilson
# pick new replacement
# * replacement: Benoit Costil
# pick new replacement
# * replacement: Mark Walport
# pick new replacement
# * replacement: Matthew Gilks
# pick new replacement
# * replacement: Mr Lloyd
# pick new replacement
# * replacement: Coleraine
#
# ============ data idx: 11333 ============
# * summary: Martin went to the German Occupation Museum to see what life was like for a family living on Guernsey in World War II.
# * chosen_ent: Martin, label: PERSON
# * replacement: Boswell

# %%
chosen_ent_list

# %%
# chosen_ent_groupby_label
chosen_ent_groupby_label = {l:{} for l in FILTER_LABELS}

# %%
for l in FILTER_LABELS:
    print(l)
    print(len([ent for (ent, label) in chosen_ent_list if label == l]))
# Out:
# PERSON
# 2149
# FAC
# 66
# GPE
# 3357
# NORP
# 602
# LOC
# 158
# EVENT
# 56
# LANGUAGE
# 8
# LAW
# 21
# ORG
# 2226

# %%
# groupby entities by their names
for data_idx, (ent, label) in enumerate(chosen_ent_list):
    chosen_ent_groupby_label[label] = {"ent": ent,
                                       "doc_idcount

# %%
nouse_count
# Out:
# 15

# %% [markdown]
# * 완전히 같은 entity 통일하기

# %%
exclude_count = 0
for data_idx, data in enumerate(tqdm(xsum_test_data.dataset[:100])):
#     print(f"============ data idx: {data_idx} ============")
    document = data["document"]
    true_summary = data["true_summary"]
    
    # ner
    doc_doc = NER(document.replace("\n", " "))  # removing newline changes the ner result
    doc_sum = NER(true_summary)
    
    doc_doc_list.append(doc_doc)
    doc_sum_list.append(doc_sum)
    
    # extract entities from document
    doc_ents_filtered = [(ent.text, ent.label_) for ent in doc_doc.ents if ent.label_ in LABELS]
    doc_ents_filtered_sorted = Counter(ents_filtered).most_common()
    
    # find overlapping entities from document
    ent_overlap_flag = False
    
    for (ent, label), count in doc_ents_filtered_sorted:
        if ent in true_summary:  # there is an overlap
#             print(f"replace ent: {ent}, label: {label}, count: {count}")
            ent_overlap_flag = True
            
    
    # find overlapping entities from summary
    if ent_overlap_flag == False:
#         print("**no overlap from document**")
        
        # extract entities from summary
        sum_ents_filtered = [(ent.text, ent.label_) for ent in doc_sum.ents if ent.label_ in LABELS]
        sum_ents_filtered_sorted = Counter(sum_ents_filtered).most_common()
#         print("summary entities", sum_ents_filtered_sorted)
        
        
        if len(sum_ents_filtered_sorted) == 0: # no entity in summary -> pass
            pass
        else: # entity found in summary
            for (ent, label), count in sum_ents_filtered_sorted:
                if ent in document:  # there is an overlap from the summary
#                     print("found summary entity in the document!")
#                     print(f"replace ent: {ent}, label: {label}, count: {count}")
                    ent_overlap_flag = True
    
    if ent_overlap_flag == False:
        exclude_count += 1 # need to exclude
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
doc_doc_list[0].ents
# Out:
# (1,099,
#  2015-16,
#  up to a year,
#  The Welsh Government,
#  the Housing Act,
#  Wales,
#  2015,
#  Andrew Stevens,
#  six months to a year,
#  six months,
#  Stevens,
#  one,
#  a hundred pounds,
#  830,
#  one,
#  the year to March 2016,
#  6,900,
#  Wales,
#  Marc,
#  50,
#  the past 20 years,
#  Marc,
#  Tom Clarke,
#  Emmaus South Wales,
#  Emmaus,
#  one,
#  Welsh Government,
#  one,
#  20,000,
#  the next five years)

# %%
exclude_count
# Out:
# 35

# %%
xsum_test_data.dataset[idx]

# %%
sum_doc = NER(["true_summary"])

# %% [markdown]
# # example 1

# %%
import spacy
from spacy import displacy
NER = spacy.load("en_core_web_sm")

# %%
raw_text="The Indian Space Research Organisation or is the national space agency of India, \
    headquartered in Bengaluru. It operates under Department of Space which is directly \
    overseen by the Prime Minister of India while Chairman of ISRO acts as executive of DOS as well."

# %%
raw_text2 = "The Mars Orbiter Mission (MOM), informally known as Mangalyaan, \
    was launched into Earth orbit on 5 November 2013 by the Indian Space Research Organisation (ISRO) \
    and has entered Mars orbit on 24 September 2014. India thus became the first country to enter \
    Mars orbit on its first attempt. It was completed at a record low cost of $74 million."

# %%
text = NER(raw_text2)

# %%
for word in text.ents:
    print(word.text,word.label_)
# Out:
# The Mars Orbiter Mission (MOM PRODUCT
# Mangalyaan PERSON
# Earth LOC
# 5 November 2013 DATE
# the Indian Space Research Organisation ORG
# Mars LOC
# 24 September 2014 DATE
# India GPE
# first ORDINAL
# Mars LOC
# $74 million MONEY

# %%
# list of ner labels
for ner_label in NER.get_pipe('ner').labels:
    print(f"* {ner_label}: {spacy.explain(ner_label)}")
# Out:
# * CARDINAL: Numerals that do not fall under another type
# * DATE: Absolute or relative dates or periods
# * EVENT: Named hurricanes, battles, wars, sports events, etc.
# * FAC: Buildings, airports, highways, bridges, etc.
# * GPE: Countries, cities, states
# * LANGUAGE: Any named language
# * LAW: Named documents made into laws.
# * LOC: Non-GPE locations, mountain ranges, bodies of water
# * MONEY: Monetary values, including unit
# * NORP: Nationalities or religious or political groups
# * ORDINAL: "first", "second", etc.
# * ORG: Companies, agencies, institutions, etc.
# * PERCENT: Percentage, including "%"
# * PERSON: People, including fictional
# * PRODUCT: Objects, vehicles, foods, etc. (not services)
# * QUANTITY: Measurements, as of weight or distance
# * TIME: Times smaller than a day
# * WORK_OF_ART: Titles of books, songs, etc.

# %%
displacy.render(text,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Mars Orbiter Mission (MOM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ), informally known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mangalyaan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,     was launched into
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  orbit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 November 2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian Space Research Organisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (ISRO)     and has entered
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  orbit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24 September 2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  thus became the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  country to enter
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  orbit on its first attempt. It was completed at a record low cost of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $74 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %% [markdown]
# # another example

# %%
# function to display basic entity info: 
def show_ents(doc):
    print(f"original doc: {doc.text}")
    if doc.ents: 
        for ent in doc.ents: 
            print(f"entity: {ent.text : >13} | start_char: {ent.start_char: 3} | end_char: {ent.end_char: 3} | label: {ent.label_} - {spacy.explain(ent.label_)}")
            # print(ent.label)  # entity type's hash value
            # print(ent.start)  # token span's start index position (word index)
            # print(ent.end)  # token span's stop index position (word index)
    else: print('No named entities found.')

# %%
doc1 = NER("Apple is looking at buying U.K. startup for $1 billion") 
show_ents(doc1)
# Out:
# original doc: Apple is looking at buying U.K. startup for $1 billion
# entity:         Apple | start_char:   0 | end_char:   5 | label: ORG - Companies, agencies, institutions, etc.
# entity:          U.K. | start_char:  27 | end_char:  31 | label: GPE - Countries, cities, states
# entity:    $1 billion | start_char:  44 | end_char:  54 | label: MONEY - Monetary values, including unit

# %% [markdown]
# ## document level

# %%
doc = NER("San Francisco considers banning sidewalk delivery robots") 
# document level 
for e in doc.ents: 
    print(e.text, e.start_char, e.end_char, e.label_) 

# OR 
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents] 
print(ents)
# Out:
# San Francisco 0 13 GPE
# [('San Francisco', 0, 13, 'GPE')]

# %% [markdown]
# ## token level

# %%
# token level 
# doc[0], doc[1] ...will have tokens stored. 

ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_] 
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
ent_considers = [doc[2].text, doc[2].ent_iob_, doc[2].ent_type_] 
print(ent_san) 
print(ent_francisco)
print(ent_considers)

# token.ent_iob indicates whether an entity starts continues or ends on the tag
# I - Token is inside an entity. 
# O - Token is outside an entity. 
# B - Token is the beginning of an entity.
# Out:
# ['San', 'B', 'GPE']
# ['Francisco', 'I', 'GPE']
# ['considers', 'O', '']

# %% [markdown]
# ## User-Defined Named Entity and Adding it to a Span

# %% [markdown]
# ### Example 1

# %%
doc = NER(u'Tesla to build a U.K. factory for $6 million.')
show_ents(doc)
# Out:
# original doc: Tesla to build a U.K. factory for $6 million.
# entity:          U.K. | start_char:  17 | end_char:  21 | label: GPE - Countries, cities, states
# entity:    $6 million | start_char:  34 | end_char:  44 | label: MONEY - Monetary values, including unit

# %%
from spacy.tokens import Span

# %%
# get the hash value of the ORG entity label
ORG = doc.vocab.strings[u"ORG"]
print(ORG)

# create a span for the new entity
new_ent = Span(doc=doc, start=0, end=1, label=ORG)
print(new_ent)

# add the entity to the existing doc object
doc.ents = list(doc.ents) + [new_ent]
print(doc.ents)
# Out:
# 383
# Tesla
# (Tesla, U.K., $6 million)

# %%
show_ents(doc)
# Out:
# original doc: Tesla to build a U.K. factory for $6 million.
# entity:         Tesla | start_char:   0 | end_char:   5 | label: ORG - Companies, agencies, institutions, etc.
# entity:          U.K. | start_char:  17 | end_char:  21 | label: GPE - Countries, cities, states
# entity:    $6 million | start_char:  34 | end_char:  44 | label: MONEY - Monetary values, including unit

# %% [markdown]
# ## Adding Named Entities to All Matching Spans

# %%
doc = NER(u'Our company plans to introduce a new vacuum cleaner. If successful, the vacuum cleaner will be our first product.') 
show_ents(doc)
# Out:
# original doc: Our company plans to introduce a new vacuum cleaner. If successful, the vacuum cleaner will be our first product.
# entity:         first | start_char:  99 | end_char:  104 | label: ORDINAL - "first", "second", etc.

# %%
# Import PhraseMatcher and create a matcher object: 
from spacy.matcher import PhraseMatcher 
matcher = PhraseMatcher(NER.vocab)

# %%
# Create the desired phrase patterns:
phrase_list = ['vacuum cleaner', 'vacuum-cleaner']
phrase_patterns = [NER(text) for text in phrase_list]
print(phrase_list)
print(phrase_patterns)
# Out:
# ['vacuum cleaner', 'vacuum-cleaner']
# [vacuum cleaner, vacuum-cleaner]

# %%
# Apply the patterns to our matcher object:
matcher.add('newproduct', None, *phrase_patterns)

# %%
# Apply the matcher to our Doc object:
matches = matcher(doc)
#See what matches occur: 
matches
# Out:
# [(2689272359382549672, 7, 9), (2689272359382549672, 14, 16)]

# %%
# Here we create Spans from each match, and create named entities from them: 
from spacy.tokens import Span 
PROD = doc.vocab.strings[u'PRODUCT'] 
new_ents = [Span(doc, match[1], match[2],label=PROD) for match in matches]
new_ents
# Out:
# [vacuum cleaner, vacuum cleaner]

# %%
# match[1] contains the start index of the the token and match[2] the stop index (exclusive) of the token in the doc. 
doc.ents = list(doc.ents) + new_ents 
show_ents(doc)
# Out:
# original doc: Our company plans to introduce a new vacuum cleaner. If successful, the vacuum cleaner will be our first product.
# entity: vacuum cleaner | start_char:  37 | end_char:  51 | label: PRODUCT - Objects, vehicles, foods, etc. (not services)
# entity: vacuum cleaner | start_char:  72 | end_char:  86 | label: PRODUCT - Objects, vehicles, foods, etc. (not services)
# entity:         first | start_char:  99 | end_char:  104 | label: ORDINAL - "first", "second", etc.

# %% [markdown]
# ## counting entities

# %%
doc = NER(u"originally priced at $29.50, now it's marked down to five dollars")
show_ents(doc)
# Out:
# original doc: originally priced at $29.50, now it's marked down to five dollars
# entity:         29.50 | start_char:  22 | end_char:  27 | label: MONEY - Monetary values, including unit
# entity:  five dollars | start_char:  53 | end_char:  65 | label: MONEY - Monetary values, including unit

# %%
len([ent for ent in doc.ents if ent.label_ == "MONEY"])
# Out:
# 2

# %% [markdown]
# ## Visualizing NER

# %%
from spacy import displacy

# %%
doc = NER(u"Tesla to build a U.K. factory for $6 million. "
          u"originally priced at $29.50, now it's marked down to five dollars")
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tesla to build a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . originally priced at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , now it's marked down to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
# line by line
for sent in doc.sents:
    displacy.render(sent, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tesla to build a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">originally priced at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , now it's marked down to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
# viewing specific entries
options = {"ents": ["MONEY"]}
displacy.render(doc, style="ent", jupyter=True, options = options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tesla to build a U.K. factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . originally priced at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , now it's marked down to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>
