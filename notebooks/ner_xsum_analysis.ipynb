# %% [markdown]
# # Load datasets
# ---

# %%
import datasets
from xsum_dataset import XsumDataset

# %%
xsum_data_raw = datasets.load_dataset("xsum")
# Out:
# Using custom data configuration default
# Reusing dataset xsum (/home/wk247/.cache/huggingface/datasets/xsum/default/1.2.0/32c23220eadddb1149b16ed2e9430a05293768cfffbdfd151058697d4c11f934)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# train/val/test data
xsum_train_data = XsumDataset(xsum_data_raw["train"])
xsum_val_data = XsumDataset(xsum_data_raw["validation"])
xsum_test_data = XsumDataset(xsum_data_raw["test"])

# %%
# concat data
xsum_data_raw_cc = datasets.concatenate_datasets(
    [xsum_data_raw["train"], xsum_data_raw["validation"], xsum_data_raw["test"]]
    )
xsum_concat_data = XsumDataset(xsum_data_raw_cc)

# %% [markdown]
# # NER Analysis
# ---

# %%
import spacy
from spacy import displacy
NER = spacy.load("en_core_web_trf")
cache_dir = "../cache_trf"

# %%
from ner_utils import *

# %%
# function to display basic entity info: 
def show_ents(doc):
    print(f"original doc: {doc.text}")
    if doc.ents: 
        for ent in doc.ents: 
            print(f"entity: {ent.text : >13} | start_char: {ent.start_char: 3} | end_char: {ent.end_char: 3} | label: {ent.label_} - {spacy.explain(ent.label_)}")
            # print(ent.label)  # entity type's hash value
            # print(ent.start)  # token span's start index position (word index)
            # print(ent.end)  # token span's stop index position (word index)
    else: print('No named entities found.')

# %% [markdown]
# ## 0-2) load cached NER files

# %%
# # train
# train_doc_ents_list = load_from_cache_dir("train_doc_ents_list")
# train_sum_ents_list = load_from_cache_dir("train_sum_ents_list")

# # val
# val_doc_ner_list = load_from_cache_dir("val_doc_ner_list", cache_dir)
# val_sum_ner_list = load_from_cache_dir("val_sum_ner_list", cache_dir)
# val_doc_ents_list = load_from_cache_dir("val_doc_ents_list_no_dup", cache_dir)  # no duplicate
# val_sum_ents_list = load_from_cache_dir("val_sum_ents_list_no_dup", cache_dir)

# test
# test_doc_ner_list = load_from_cache_dir("test_doc_ner_list", cache_dir)
# test_sum_ner_list = load_from_cache_dir("test_sum_ner_list", cache_dir)
test_doc_ents_list = load_from_cache_dir("test_doc_ents_list_no_dup", cache_dir)  # no duplicate
test_sum_ents_list = load_from_cache_dir("test_sum_ents_list_no_dup", cache_dir)

# entities pool
# concat_ent_pool_dict = load_from_cache_dir("concat_ent_pool_dict", cache_dir)  # preprocessed
# test_ent_pool_dict = load_from_cache_dir("test_ent_pool_dict", cache_dir)
val_test_ent_pool_dict = load_from_cache_dir("val_test_ent_pool_dict", cache_dir)
# Out:
# '../cache_trf/test_doc_ents_list_no_dup.pkl' loaded
# '../cache_trf/test_sum_ents_list_no_dup.pkl' loaded
# '../cache_trf/val_test_ent_pool_dict.pkl' loaded

# %% [markdown]
# ## todo
# * case 1. no entites in true_summary - continue
#     1) ner on summary doesn't recognize the entity correctly
# * case 2. no exact overlap entities btw true_summary - document
#     1) check subset
#         * Edinburgh (summary) - Edinburgh Sheriff Court (document)
#         * (name) Usain Bolt (summary) - Usain (document) - should I replace?
#
# * case 3. ex) 4 - four
# * case 4. case
#
# 1. how to choose the entity?
#     * pick the replacement entity that is not in the source document
# 2. how to replace it?
#
#
#
#
#
# ### other ideas
# * replace the entites that are not in the true summary?

# %% [markdown]
# ## 1) analyze test summaries

# %%
data_idx = 0

# %%
sum_ner = test_sum_ner_list[data_idx]
doc_ner = test_doc_ner_list[data_idx]

# %%
doc_ents_sorted = test_doc_ents_list[data_idx].most_common()
sum_ents_sorted = test_sum_ents_list[data_idx].most_common()

# %%
show_ents(sum_ner)
# Out:
# original doc: There is a "chronic" need for more housing for prison leavers in Wales, according to a charity.
# entity:         Wales | start_char:  65 | end_char:  70 | label: GPE - Countries, cities, states

# %%
sum_ents_sorted
# Out:
# [(('Wales', 'GPE'), 1)]

# %%
doc_ents_sorted
# Out:
# [(('one', 'CARDINAL'), 4),
#  (('Wales', 'GPE'), 2),
#  (('Marc', 'PERSON'), 2),
#  (('1,099', 'CARDINAL'), 1),
#  (('2015-16', 'DATE'), 1),
#  (('up to a year', 'DATE'), 1),
#  (('The Welsh Government', 'ORG'), 1),
#  (('the Housing Act', 'LAW'), 1),
#  (('2015', 'DATE'), 1),
#  (('Andrew Stevens', 'PERSON'), 1),
#  (('six months to a year', 'DATE'), 1),
#  (('six months', 'DATE'), 1),
#  (('Stevens', 'PERSON'), 1),
#  (('a hundred pounds', 'MONEY'), 1),
#  (('830', 'CARDINAL'), 1),
#  (('the year to March 2016', 'DATE'), 1),
#  (('6,900', 'CARDINAL'), 1),
#  (('50', 'DATE'), 1),
#  (('the past 20 years', 'DATE'), 1),
#  (('Tom Clarke', 'PERSON'), 1),
#  (('Emmaus South Wales', 'GPE'), 1),
#  (('Emmaus', 'ORG'), 1),
#  (('Welsh Government', 'ORG'), 1),
#  (('20,000', 'CARDINAL'), 1),
#  (('the next five years', 'DATE'), 1)]

# %% [markdown]
# ## 2) filter entities

# %% [markdown]
# * label list
#     * CARDINAL: Numerals that do not fall under another type
#     * DATE: Absolute or relative dates or periods
#     * EVENT: Named hurricanes, battles, wars, sports events, etc.
#     * FAC: Buildings, airports, highways, bridges, etc.
#     * GPE: Countries, cities, states
#     * LANGUAGE: Any named language
#     * LAW: Named documents made into laws.
#     * LOC: Non-GPE locations, mountain ranges, bodies of water
#     * MONEY: Monetary values, including unit
#     * NORP: Nationalities or religious or political groups
#     * ORDINAL: "first", "second", etc.
#     * ORG: Companies, agencies, institutions, etc.
#     * PERCENT: Percentage, including "%"
#     * PERSON: People, including fictional
#     * PRODUCT: Objects, vehicles, foods, etc. (not services)
#     * QUANTITY: Measurements, as of weight or distance
#     * TIME: Times smaller than a day
#     * WORK_OF_ART: Titles of books, songs, etc.

# %% [markdown]
# FILTER_LABELS = ["PERSON", "FAC", "GPE", "NORP", "LOC", "EVENT"]

# %%
FILTER_LABELS = ["PERSON", "FAC", "GPE", "NORP", "LOC", "EVENT", "LANGUAGE", "LAW", "ORG"]
# without numbers? "DATE", "PERCENT" 
# too many errors: "PRODUCT", "WORK_OF_ART"

# %%
ALL_LABELS = list(NER.get_pipe('ner').labels)

# %% [markdown]
# ## 3) replace entities

# %%
from tqdm.notebook import tqdm

# %% [markdown]
# ### 1) count samples to exclude

# %%
def count_no_overlap(xsum_data, doc_ents_list, sum_ents_list, filter_labels):
    # samples to exclude
    doc_overlap_count = 0
    sum_overlap_count = 0
    no_overlap_count = 0

    for data_idx, data in enumerate(tqdm(xsum_data.dataset)):
        document = data["document"]
        true_summary = data["true_summary"]

        # ner
        # doc_ner = doc_ner_list[data_idx]
        # sum_ner = sum_ner_list[data_idx]

        # entites
        doc_ents = doc_ents_list[data_idx]
        sum_ents = sum_ents_list[data_idx]

        # sort and filter
        doc_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in doc_ents.most_common() 
                                    if label in filter_labels]
        sum_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in sum_ents.most_common() 
                                    if label in filter_labels]

        overlap_flag = False
        # from document side
        for (ent, label), count in doc_ents_filtered_sorted:
            if ent in true_summary:  # overlap exists
                overlap_flag = True
                doc_overlap_count += 1
                break

        # if no overlap from document side, try from summary
        if overlap_flag == False:
            if len(sum_ents) == 0: # no entity in summary -> pass
                pass
            else:
                for (ent, label), count in sum_ents_filtered_sorted:
                    if ent in document:
                        overlap_flag = True
                        sum_overlap_count += 1
                        break

        if overlap_flag == False:
            no_overlap_count += 1 # need to exclude

    # check uncounted sample
    assert doc_overlap_count + sum_overlap_count + no_overlap_count == len(xsum_data.dataset)
    
    return doc_overlap_count, sum_overlap_count, no_overlap_count

# %%
test_overlap_counts = count_no_overlap(xsum_data=xsum_test_data, 
                                       doc_ents_list=test_doc_ents_list, 
                                       sum_ents_list=test_sum_ents_list, 
                                       filter_labels=FILTER_LABELS)
# Out:
#   0%|          | 0/11334 [00:00<?, ?it/s]

# %%
n_test = len(xsum_test_data.dataset)
print(f"overlap from document: {(test_overlap_counts[0]/n_test)*100:.1f}%")
print(f"overlap from summary: {(test_overlap_counts[1]/n_test)*100:.1f}%")
print(f"no overlap: {(test_overlap_counts[2]/n_test)*100:.1f}%")
# Out:
# overlap from document: 73.9%
# overlap from summary: 3.2%
# no overlap: 22.9%

# %% [markdown]
# ### 2) print

# %%
ent_pool_dict = val_test_ent_pool_dict

# %%
# extract only necessary dicts
for label in ALL_LABELS:
    if label not in FILTER_LABELS:
        del ent_pool_dict[label]

# %%
assert(len(ent_pool_dict) == len(FILTER_LABELS))

# %%
# reduce the size to 20%
reduced_ent_pool_dict = {}
for label in ent_pool_dict.keys():
    ent_pool = ent_pool_dict[label]
    reduced_ent_pool = {k:v for (k,v) in list(ent_pool.items())[:len(ent_pool) // 10]}
    reduced_ent_pool_dict[label] = reduced_ent_pool

# %%
len(ent_pool_dict["PERSON"])
# Out:
# 67832

# %%
len(reduced_ent_pool_dict["PERSON"])
# Out:
# 6783

# %%
import random
random.seed(0)

# %%
def if_improper_replacement(chosen_ent, chosen_label, replace_ent, document, true_summary):
    # sample again if one of the below is true
    # 1. if label is person, replacement must have same # of words
    # 2. if replace entity is in the true document
    # 3. if replace entity is in the true summary
    # 4. if replace entity is a subset of chosen entity
    # 5. if chosen entity is a subset of replace entity
    
    violations = [chosen_label == "PERSON" and len(replace_ent.split()) != len(chosen_ent.split()),
                   replace_ent in document,
                   replace_ent in true_summary,
                   replace_ent in chosen_ent,
                   chosen_ent in replace_ent]
    
    # if violations are all false -> return false
    # if one of them are true -> return true
    return any(violations)

# %%
ood_list = []

# %%
replacement_info = []
for data_idx, data in enumerate(tqdm(xsum_test_data.dataset)):
    print(f"\n============ data idx: {data_idx} ============")
    original_id = data["id"]
    original_doc = data["document"]
    true_summary = data["true_summary"]
    
    # ner
    # doc_ner = test_doc_ner_list[data_idx]
    # sum_ner = test_sum_ner_list[data_idx]
    
    # entites
    doc_ents = test_doc_ents_list[data_idx]
    sum_ents = test_sum_ents_list[data_idx]
    
    # sort and filter
    doc_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in doc_ents.most_common() 
                                if label in FILTER_LABELS]
    sum_ents_filtered_sorted = [((ent, label), count) for ((ent, label), count) in sum_ents.most_common() 
                                if label in FILTER_LABELS]
    
    # if there is an overlap
    overlap_flag = False
    
    
    chosen_ent = None
    chosen_label = None
    
    # from document side
#     print(f"* summary: {true_summary}")
#     print(f"* document ents: {doc_ents_filtered_sorted} \n")
    for (ent, label), count in doc_ents_filtered_sorted:
        if ent in true_summary:  # overlap exists
#             print("** overlap from document")
#             print(f"ent: {ent}, label: {label}, count_doc: {count}, count_sum: {true_summary.count(ent)}")
            overlap_flag = True
            chosen_ent, chosen_label = ent, label
            break
    
    # if no overlap from document side, try from summary
    if overlap_flag == False:
        if len(sum_ents) == 0: # no entity in summary -> pass
            pass
        else:
#             print(f"* summary ents: {sum_ents_filtered_sorted} \n")
            for (ent, label), count in sum_ents_filtered_sorted:
                if ent in original_doc:
#                     print("** overlap from summary")
#                     print(f"ent: {ent}, label: {label}, count_sum: {count}, count_doc: {original_doc.count(ent)}")
                    overlap_flag = True
                    chosen_ent, chosen_label = ent, label
                    break
    
    
    # check the chosen entity
    if overlap_flag == True:
        print(f"* summary: {true_summary}")
        print(f"* chosen_ent: {chosen_ent}, label: {chosen_label}")
        
        
        # choose one
        ent_pool = list(reduced_ent_pool_dict[chosen_label].keys())
        replace_ent = random.choice(ent_pool)
        print(f"* replace_ent: {replace_ent}")
        
        while if_improper_replacement(chosen_ent, chosen_label, replace_ent, original_doc, true_summary):
            print("pick new replacement")
            replace_ent = random.choice(ent_pool)
            print(f"* replace_ent: {replace_ent}")
        
        
        metadata_dict = {"chosen_ent": chosen_ent,
                         "replace_ent": replace_ent,
                         "label": chosen_label,}
        
        ood_doc = original_doc.replace(chosen_ent, replace_ent)
        ood_summary = true_summary.replace(chosen_ent, replace_ent)
        ood_list.append({"original_id": original_id,
                         "ood_doc": ood_doc,
                         "ood_true_summary": ood_summary,
                         "metadata": metadata_dict})
        
    else:
        print("****** NO OVERLAP ******")
        ood_list.append(None)
# Out:
#   0%|          | 0/11334 [00:00<?, ?it/s]
# ============ data idx: 0 ============
# * summary: There is a "chronic" need for more housing for prison leavers in Wales, according to a charity.
# * chosen_ent: Wales, label: GPE
# * replace_ent: Maldives
#
# ============ data idx: 1 ============
# * summary: A man has appeared in court after firearms, ammunition and cash were seized by police in Edinburgh.
# * chosen_ent: Edinburgh, label: GPE
# * replace_ent: Costa Rica
#
# ============ data idx: 2 ============
# * summary: Four people accused of kidnapping and torturing a mentally disabled man in a "racially motivated" attack streamed on Facebook have been denied bail.
# * chosen_ent: Facebook, label: ORG
# * replace_ent: The Foreign and Commonwealth Office
#
# ============ data idx: 3 ============
# * summary: West Brom have appointed Nicky Hammond as technical director, ending his 20-year association with Reading.
# * chosen_ent: West Brom, label: ORG
# * replace_ent: Staggies
#
# ============ data idx: 4 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 5 ============
# * summary: Since their impending merger was announced in January, there has been remarkably little comment about the huge proposed deal to combine Essilor and Luxottica.
# * chosen_ent: Essilor, label: ORG
# * replace_ent: Gunners
#
# ============ data idx: 6 ============
# * summary: A "medal at any cost" approach created a "culture of fear" at British Cycling, says former rider Wendy Houvenaghel.
# * chosen_ent: Houvenaghel, label: PERSON
# * replace_ent: Moriarty
#
# ============ data idx: 7 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 8 ============
# * summary: The reaction from BT's investors told us much about media regulator Ofcom's ruling on the fate of Openreach, the BT subsidiary that provides much of the UK's broadband infrastructure.
# * chosen_ent: BT, label: ORG
# * replace_ent: Pars
#
# ============ data idx: 9 ============
# * summary: Manager Brendan Rodgers is sure Celtic can exploit the wide open spaces of Hampden when they meet Rangers in Sunday's League Cup semi-final.
# * chosen_ent: Rodgers, label: PERSON
# * replace_ent: Christy Pym
# pick new replacement
# * replace_ent: Jacqueline Morton
# pick new replacement
# * replace_ent: Greig
#
# ============ data idx: 10 ============
# * summary: Queen's University Belfast is cutting 236 jobs and 290 student places due to a funding reduction.
# * chosen_ent: Queen's, label: ORG
# * replace_ent: USA Today
#
# ============ data idx: 11 ============
# * summary: Hospital bosses in Sussex have apologised after about 850 patients were sent leaflets in error suggesting they might have cancer.
# * chosen_ent: Sussex, label: GPE
# * replace_ent: Toronto
#
# ============ data idx: 12 ============
# * summary: The shadow foreign secretary has suggested Labour will continue to support legislation paving the way for Brexit as it passes through Parliament.
# * chosen_ent: Labour, label: ORG
# * replace_ent: CSKA Moscow
#
# ============ data idx: 13 ============
# * summary: Torquay United boss Kevin Nicholson says none of the money from Eunan O'Kane's move to Leeds from Bournemouth will go to the playing squad.
# * chosen_ent: Nicholson, label: PERSON
# * replace_ent: Michael Noonan
# pick new replacement
# * replace_ent: Elia Viviani
# pick new replacement
# * replace_ent: Darren Fletcher
# pick new replacement
# * replace_ent: Whitaker
#
# ============ data idx: 14 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 15 ============
# * summary: Leicester City striker Gary Taylor-Fletcher has joined Sheffield Wednesday on an initial month-long loan.
# * chosen_ent: Taylor-Fletcher, label: PERSON
# * replace_ent: Walters
#
# ============ data idx: 16 ============
# * summary: Limiting access to federal research would do an "enormous disservice" to the US and the world according to former Nasa chief scientist.
# * chosen_ent: US, label: GPE
# * replace_ent: the Czech Republic
#
# ============ data idx: 17 ============
# * summary: John "Brad" Bradbury, drummer with The Specials, has died at the age of 62.
# * chosen_ent: Bradbury, label: PERSON
# * replace_ent: Healy
#
# ============ data idx: 18 ============
# * summary: Tiger Woods missed the cut at the Farmers Insurance Open, as England's Justin Rose maintained a one-shot lead.
# * chosen_ent: Rose, label: PERSON
# * replace_ent: Gary Middleton
# pick new replacement
# * replace_ent: the Prince of Wales
# pick new replacement
# * replace_ent: Macleod
#
# ============ data idx: 19 ============
# * summary: Former England striker Andy Cole says he faces a "long road ahead" as he recovers from his recent kidney transplant.
# * chosen_ent: Cole, label: PERSON
# * replace_ent: Michael Timlin
# pick new replacement
# * replace_ent: Ryan Moore
# pick new replacement
# * replace_ent: Lee Holmes
# pick new replacement
# * replace_ent: Marie Harf
# pick new replacement
# * replace_ent: Erik Pieters
# pick new replacement
# * replace_ent: Forbes
#
# ============ data idx: 20 ============
# * summary: Pakistan has unblocked the video sharing site, YouTube, more than three years after it was banned for posting a video deemed insulting to Islam.
# * chosen_ent: Pakistan, label: GPE
# * replace_ent: Oklahoma
#
# ============ data idx: 21 ============
# * summary: Leicester Tigers winger Miles Benjamin is likely to be out for the rest of the season because of a knee injury, reports BBC Radio Leicester.
# * chosen_ent: BBC Radio Leicester, label: ORG
# * replace_ent: Napoli
#
# ============ data idx: 22 ============
# * summary: Owain Doull has won Wales' first gold of the 2016 Olympics as  he helped the Great Britain men's team pursuit defend their cycling title in Rio.
# * chosen_ent: Doull, label: PERSON
# * replace_ent: Hurst
#
# ============ data idx: 23 ============
# * summary: Floods in the western Indian state of Gujarat have killed 218 people, government officials have confirmed.
# * chosen_ent: India, label: GPE
# * replace_ent: Malaysia
#
# ============ data idx: 24 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 25 ============
# * summary: Royal Bank of Scotland (RBS) has been fined HK$6m (£460,000) by Hong Kong regulators after it failed to detect a series of unauthorised transactions by one of its traders.
# * chosen_ent: RBS, label: ORG
# * replace_ent: Mamelodi Sundowns
#
# ============ data idx: 26 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 27 ============
# * summary: Of his last 30 matches in 2016, Andy Murray won 28 and lost just two.
# * chosen_ent: Murray, label: PERSON
# * replace_ent: Lawro
#
# ============ data idx: 28 ============
# * summary: South African police say four people have been arrested in connection with the murder of former actor on popular local TV series Generations.
# * chosen_ent: South Africa, label: GPE
# * replace_ent: Birkenhead
#
# ============ data idx: 29 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 30 ============
# * summary: Jessica Ennis-Hill has fallen from fourth to eighth place after six events at the Hypo-Meeting in Gotzis.
# * chosen_ent: Ennis-Hill, label: PERSON
# * replace_ent: Jim Boyce
# pick new replacement
# * replace_ent: Gildart
#
# ============ data idx: 31 ============
# * summary: The Manor team have collapsed after administrators failed to find a buyer for the stricken business.
# * chosen_ent: Manor, label: ORG
# * replace_ent: Birmingham Magistrates' Court
#
# ============ data idx: 32 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 33 ============
# * summary: With the value of the pound falling dramatically since Brexit, a "flash crash" last week when the currency lost 6% of its value against the dollar, and news on Tuesday that the pound had fallen again, when would be a good time to change those pounds to dollars?
# * chosen_ent: Brexit, label: EVENT
# * replace_ent: F1
#
# ============ data idx: 34 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 35 ============
# * summary: Plans to move a statue depicting a Royal Marine in the Falklands conflict away from Portsmouth seafront have been criticised.
# * chosen_ent: Portsmouth, label: GPE
# * replace_ent: Melbourne
#
# ============ data idx: 36 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 37 ============
# * summary: Sussex have appointed former player James Anyon as head coach of their women's side.
# * chosen_ent: Sussex, label: ORG
# * replace_ent: Radio 5
#
# ============ data idx: 38 ============
# * summary: League One side Bury have signed former Barnsley defender Reece Brown on a six-month contract.
# * chosen_ent: Brown, label: PERSON
# * replace_ent: Michael Morrison
# pick new replacement
# * replace_ent: Peter Hunt
# pick new replacement
# * replace_ent: Ann Clwyd
# pick new replacement
# * replace_ent: Millie
#
# ============ data idx: 39 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 40 ============
# * summary: Performers from 42 countries strode down a long red carpet near Ukraine's parliament this week, as a curtain-raiser to this year's Eurovision Song Contest.
# * chosen_ent: Eurovision, label: ORG
# * replace_ent: BBC Essex
#
# ============ data idx: 41 ============
# * summary: It was 50 years ago today that The Beatles played their first gig at the Cavern Club in Liverpool - the venue where the band built their reputation and where Beatlemania was born.
# * chosen_ent: Beatles, label: ORG
# * replace_ent: Radio Times
#
# ============ data idx: 42 ============
# * summary: South Africa's government has proposed a national minimum wage of 3,500 rand ($242; Â£199) a month.
# * chosen_ent: South Africa, label: GPE
# * replace_ent: Kolkata
#
# ============ data idx: 43 ============
# * summary: The death of Ethiopian Prime Minister Meles Zenawi has thrown the populous Horn of Africa giant into a period of deep uncertainty and created a serious leadership vacuum in the region with profound geopolitical implications.
# * chosen_ent: Meles, label: PERSON
# * replace_ent: Peter Trego
# pick new replacement
# * replace_ent: Quade Cooper
# pick new replacement
# * replace_ent: Stephen Ward
# pick new replacement
# * replace_ent: Rebecca
#
# ============ data idx: 44 ============
# * summary: Azhar Ali's unbeaten 66 helped Pakistan to reach 142-4 against Australia on a rain-affected first day of the Boxing Day Test in Melbourne.
# * chosen_ent: Australia, label: GPE
# * replace_ent: Ely
#
# ============ data idx: 45 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 46 ============
# * summary: Russia has said it will carry on bombing rebel-held eastern Aleppo in Syria, defying US demands to stop.
# * chosen_ent: US, label: GPE
# * replace_ent: Canberra
#
# ============ data idx: 47 ============
# * summary: Wales Under-20 Grand Slam winners Shaun Evans and Dafydd Hughes have signed their first professional contracts with Scarlets.
# * chosen_ent: Scarlets, label: ORG
# * replace_ent: Sunderland
#
# ============ data idx: 48 ============
# * summary: The expulsion of 35 Russian diplomats from the US over the email hacking scandal has drawn a barrage of abuse from Moscow, which seems poised to respond in kind.
# * chosen_ent: Russia, label: GPE
# * replace_ent: Inverness
#
# ============ data idx: 49 ============
# * summary: Scrapping tuition fees in England is the biggest and most expensive proposal in Labour's £25bn worth of pledges for education.
# * chosen_ent: Labour, label: ORG
# * replace_ent: BSkyB
#
# ============ data idx: 50 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 51 ============
# * summary: The US director of national intelligence has said he "never felt pressured" to influence the inquiry into Russia's political meddling.
# * chosen_ent: Russia, label: GPE
# * replace_ent: Florence
#
# ============ data idx: 52 ============
# * summary: White House officials will not say whether pop star Prince performed at a weekend party at the executive residence despite guests posting about it on social media.
# * chosen_ent: Prince, label: PERSON
# * replace_ent: Redknapp
#
# ============ data idx: 53 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 54 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 55 ============
# * summary: US investigators have closed an inquiry into whether To Kill A Mockingbird author Harper Lee was pressured into publishing a sequel.
# * chosen_ent: Lee, label: PERSON
# * replace_ent: Bellew
#
# ============ data idx: 56 ============
# * summary: The US has said it is suspending talks with Russia over Syria, accusing Moscow of having "failed to live up" to its commitments under a ceasefire deal.
# * chosen_ent: Russia, label: GPE
# * replace_ent: the Russian Federation
# pick new replacement
# * replace_ent: Malmo
#
# ============ data idx: 57 ============
# * summary: Labour's Sadiq Khan has been elected Mayor of London, becoming the city's first Muslim mayor.
# * chosen_ent: Khan, label: PERSON
# * replace_ent: Peggy
#
# ============ data idx: 58 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 59 ============
# * summary: Manchester City midfielder Kevin de Bruyne says he will be out for about 10 weeks after injuring his right knee during Wednesday's League Cup semi-final victory over Everton.
# * chosen_ent: City, label: ORG
# * replace_ent: Stonewall
#
# ============ data idx: 60 ============
# * summary: A 34-year-old woman who was injured in an attack by a knifeman on a Swiss train has died in hospital, police say.
# * chosen_ent: Swiss, label: NORP
# * replace_ent: British
#
# ============ data idx: 61 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 62 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 63 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 64 ============
# * summary: Regional official Tim Roache has been elected to become the new general secretary of the GMB union.
# * chosen_ent: GMB, label: ORG
# * replace_ent: Taylor Wimpey
#
# ============ data idx: 65 ============
# * summary: We go behind the scenes with singer Laura Mvula as she prepares to debut her new material and kick off the 48th series of Later... with Jools Holland.
# * chosen_ent: Laura, label: PERSON
# * replace_ent: Muller
#
# ============ data idx: 66 ============
# * summary: Newcastle midfielder Jonas Gutierrez says he feels "born again" following his return to Premier League action after overcoming testicular cancer.
# * chosen_ent: Gutierrez, label: PERSON
# * replace_ent: Paul Hurst
# pick new replacement
# * replace_ent: Steven Spielberg
# pick new replacement
# * replace_ent: Stuart Thompson
# pick new replacement
# * replace_ent: Timo Werner
# pick new replacement
# * replace_ent: Bowe Bergdahl
# pick new replacement
# * replace_ent: Singh
#
# ============ data idx: 67 ============
# * summary: League Two Exeter City made a profit of over £1.6m last year, according to the club's latest accounts.
# * chosen_ent: Exeter, label: ORG
# * replace_ent: Harvard University
#
# ============ data idx: 68 ============
# * summary: Para-athlete Abdullah Hayayei died after a metal throwing cage fell on him during training.
# * chosen_ent: Hayayei, label: PERSON
# * replace_ent: Olly Woodburn
# pick new replacement
# * replace_ent: Gary Locke
# pick new replacement
# * replace_ent: Henry Slade
# pick new replacement
# * replace_ent: Mateo Kovacic
# pick new replacement
# * replace_ent: Matt Smith
# pick new replacement
# * replace_ent: Alex Fergusson
# pick new replacement
# * replace_ent: Assange
#
# ============ data idx: 69 ============
# * summary: Manufacturers have reported positive business trends, in the latest survey from the Scottish Chambers of Commerce.
# * chosen_ent: Scottish, label: NORP
# * replace_ent: Thai
#
# ============ data idx: 70 ============
# * summary: The public inquiry into undercover policing may "expose both creditable and discreditable conduct", chairman Lord Justice Pitchford has warned.
# * chosen_ent: Pitchford, label: PERSON
# * replace_ent: Lynch
#
# ============ data idx: 71 ============
# * summary: Reigning champions New Zealand are into their fourth World Cup final after slogging past South Africa in another Twickenham epic.
# * chosen_ent: South Africa, label: GPE
# * replace_ent: Cornwall
#
# ============ data idx: 72 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 73 ============
# * summary: Profit jumped at Zara owner Inditex in the first half of the year as the firm opened new stores and invested in online.
# * chosen_ent: Inditex, label: ORG
# * replace_ent: Southend United
#
# ============ data idx: 74 ============
# * summary: Lady Gaga is leading the pitch invasion at Sunday's Super Bowl, where she'll perform the all-important half-time show.
# * chosen_ent: Super Bowl, label: EVENT
# * replace_ent: the Irish Open
#
# ============ data idx: 75 ============
# * summary: A victim of the Rochdale grooming gang says the convictions were still "not fazing" Asian child sex abusers.
# * chosen_ent: Asian, label: NORP
# * replace_ent: Serb
#
# ============ data idx: 76 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 77 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 78 ============
# * summary: New Sale Sharks chairman Fran Cotton has conceded they must work to restore their relationship with some fans.
# * chosen_ent: Cotton, label: PERSON
# * replace_ent: Janet Yellen
# pick new replacement
# * replace_ent: Baines
#
# ============ data idx: 79 ============
# * summary: Disney's latest animation Moana dominated the Thanksgiving box office over the five-day US holiday weekend.
# * chosen_ent: Disney, label: ORG
# * replace_ent: First Great Western
#
# ============ data idx: 80 ============
# * summary: British number one Johanna Konta reached the quarter-finals of the Bank of the West Classic in Stanford with a straight-set win over Julia Boserup.
# * chosen_ent: Konta, label: PERSON
# * replace_ent: Marcelo
#
# ============ data idx: 81 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 82 ============
# * summary: The Ebola victim who is believed to have triggered the current outbreak - a two-year-old boy called Emile Ouamouno from Guinea - may have been infected by playing in a hollow tree housing a colony of bats, say scientists.
# * chosen_ent: Emile, label: PERSON
# * replace_ent: Moray Low
# pick new replacement
# * replace_ent: Tommy Seymour
# pick new replacement
# * replace_ent: Ewing
#
# ============ data idx: 83 ============
# * summary: Stuart Bingham may pull out of the Masters if his wife goes into labour with their third child.
# * chosen_ent: Bingham, label: PERSON
# * replace_ent: Jolyon Palmer
# pick new replacement
# * replace_ent: Burden
#
# ============ data idx: 84 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 85 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 86 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 87 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 88 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 89 ============
# * summary: Uzbekistan's Hasanboy Dusmatov won Olympic gold in the men's light-flyweight with victory over Colombian Yuberjen Herney Martinez.
# * chosen_ent: Dusmatov, label: PERSON
# * replace_ent: Huw Stephens
# pick new replacement
# * replace_ent: Nikita Parris
# pick new replacement
# * replace_ent: Michael Timlin
# pick new replacement
# * replace_ent: Hördur Bjorgvin Magnusson
# pick new replacement
# * replace_ent: Haye
#
# ============ data idx: 90 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 91 ============
# * summary: Controversial proposals to shut a Catholic school in East Dunbartonshire are to be examined by the Scottish government.
# * chosen_ent: Scottish, label: NORP
# * replace_ent: Vietnamese
#
# ============ data idx: 92 ============
# * summary: Japanese footballer Kazuyoshi Miura has signed a one-year contract extension with Yokohama FC at the age of 48.
# * chosen_ent: Kazu, label: PERSON
# * replace_ent: Cunningham
#
# ============ data idx: 93 ============
# * summary: Clashes have broken out in Indian-administered Kashmir on the anniversary of the killing of a militant leader.
# * chosen_ent: Indian, label: NORP
# * replace_ent: The Lib Dems
#
# ============ data idx: 94 ============
# * summary: Economic policymakers must now decide whether and how they should respond to the UK's vote to leave the EU.
# * chosen_ent: UK, label: GPE
# * replace_ent: Newport
#
# ============ data idx: 95 ============
# * summary: Sale Sharks forward Mark Easter has announced he will retire at the end of the season to take up a teaching role.
# * chosen_ent: Sale, label: ORG
# * replace_ent: The Age
#
# ============ data idx: 96 ============
# * summary: The quality of care on a scandal-hit ward for dementia patients may have contributed to at least seven deaths, BBC Wales can reveal.
# * chosen_ent: Wales, label: GPE
# * replace_ent: Portrush
#
# ============ data idx: 97 ============
# * summary: A 25-year-old man from Limavady has been jailed for knocking out two men in separate attacks on the same night.
# * chosen_ent: Limavady, label: GPE
# * replace_ent: Costa Rica
#
# ============ data idx: 98 ============
# * summary: The United States women's team goalkeeper Hope Solo has been suspended for 30 days by US Soccer following an incident during a training camp.
# * chosen_ent: Solo, label: PERSON
# * replace_ent: Michael Laudrup
# pick new replacement
# * replace_ent: Neeskens Kebano
# pick new replacement
# * replace_ent: Richie
#
# ============ data idx: 99 ============
# * summary: A barrister who was due to move into his own chambers in Huddersfield has pleaded guilty to supplying cocaine.
# * chosen_ent: Huddersfield, label: GPE
# * replace_ent: UAE
#
# ============ data idx: 100 ============
# * summary: Officers who police Scotland's railways are to be armed with Tasers in a bid to increase security on the network.
# * chosen_ent: Scotland, label: GPE
# * replace_ent: Norwich
#
# ============ data idx: 101 ============
# * summary: Scottish engineering services company ID Systems Ltd has announced plans to create 120 new jobs after securing a six-figure investment from UK Steel Enterprise (UKSE).
# * chosen_ent: UKSE, label: ORG
# * replace_ent: AA
#
# ============ data idx: 102 ============
# * summary: A Brazilian football player who survived a plane crash in Colombia on Monday is recovering and may be able to resume his career, his father says.
# * chosen_ent: Brazil, label: GPE
# * replace_ent: Welshpool
#
# ============ data idx: 103 ============
# * summary: Actor and broadcaster Sir Tony Robinson has said plans for a tunnel near Stonehenge in Wiltshire are too "old-fashioned" in outlook.
# * chosen_ent: Robinson, label: PERSON
# * replace_ent: Shaun MacDonald
# pick new replacement
# * replace_ent: Neil Lennon
# pick new replacement
# * replace_ent: Bravo
#
# ============ data idx: 104 ============
# * summary: Everton marked their Europa League return with a dominant victory over Germans Wolfsburg at Goodison Park.
# * chosen_ent: Wolfsburg, label: ORG
# * replace_ent: the National Union of Students
#
# ============ data idx: 105 ============
# * summary: Scunthorpe midfielder Neal Bishop has signed a one-year contract extension.
# * chosen_ent: Bishop, label: PERSON
# * replace_ent: Karolina Pliskova
# pick new replacement
# * replace_ent: Sally
#
# ============ data idx: 106 ============
# * summary: A man from Croydon has been charged with murder after the death of his partner last month.
# * chosen_ent: Croydon, label: GPE
# * replace_ent: Leeds
#
# ============ data idx: 107 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 108 ============
# * summary: The Premiership's top try scorer Christian Wade scored two tries as leaders Wasps moved five points clear with a bonus-point win over Worcester.
# * chosen_ent: Wasps, label: ORG
# * replace_ent: Notts
#
# ============ data idx: 109 ============
# * summary: A Frenchwoman injured in the attack on Tunisia's national museum has died of her wounds, bringing the total killed in the assault by Islamists to 22.
# * chosen_ent: Tunisia, label: GPE
# * replace_ent: Dewsbury
#
# ============ data idx: 110 ============
# * summary: Satellite images of Mosul have revealed how fighters from so-called Islamic State (IS) have destroyed much of the city's airport to render it unusable as Iraqi forces close in.
# * chosen_ent: IS, label: ORG
# * replace_ent: Peterhead Sheriff Court
#
# ============ data idx: 111 ============
# * summary: Network Rail has promised to do "everything in its power" to stop a repeat of the rail chaos at Christmas when it carries out work over Easter.
# * chosen_ent: Network Rail, label: ORG
# * replace_ent: Bristol Crown Court
#
# ============ data idx: 112 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 113 ============
# * summary: Amazon, the global online retailer, is changing the way it records sales in a move that could see it paying more tax.
# * chosen_ent: Amazon, label: ORG
# * replace_ent: Barrow
#
# ============ data idx: 114 ============
# * summary: Junior doctors should suspend Tuesday's strike action over pay and conditions while talks continue, the chief medical officer for England has urged.
# * chosen_ent: England, label: GPE
# * replace_ent: California
#
# ============ data idx: 115 ============
# * summary: Oxford United have extended the loan of right-back Jonjoe Kenny from Premier League side Everton until the end of the season.
# * chosen_ent: Kenny, label: PERSON
# * replace_ent: Frank
#
# ============ data idx: 116 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 117 ============
# * summary: The family of the former footballer Jeff Astle is to meet the FA chairman next month to discuss head injuries in the game, as part of their campaign.
# * chosen_ent: Astle, label: PERSON
# * replace_ent: Zverev
#
# ============ data idx: 118 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 119 ============
# * summary: Brothers Ben and Tom Curry have signed five-year contracts with Sale Sharks.
# * chosen_ent: Sale, label: ORG
# * replace_ent: Sixers
#
# ============ data idx: 120 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 121 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 122 ============
# * summary: Fracking for shale gas in Wales should still be opposed despite plans to fast-track such schemes in England, the Welsh government has said.
# * chosen_ent: Wales, label: GPE
# * replace_ent: Telford
#
# ============ data idx: 123 ============
# * summary: For a man often described as capricious, Tyson Fury's chaotic reign as world heavyweight champion was strangely predictable.
# * chosen_ent: Fury, label: PERSON
# * replace_ent: Jakupovic
#
# ============ data idx: 124 ============
# * summary: England coach Eddie Jones will name his 45-man Elite Player Squad squad ahead of the autumn Tests at 10:00 BST on Friday.
# * chosen_ent: England, label: GPE
# * replace_ent: Stirling
#
# ============ data idx: 125 ============
# * summary: A collection of paintings capturing the landscapes and legacy of life on the North East coast is going on display.
# * chosen_ent: the North East, label: LOC
# * replace_ent: the Severn Estuary
#
# ============ data idx: 126 ============
# * summary: Hibernian's Neil Lennon believes Scott Brown retired too soon from Scotland duty and still has plenty to offer now he has decided to return.
# * chosen_ent: Lennon, label: PERSON
# * replace_ent: Wyles
#
# ============ data idx: 127 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 128 ============
# * summary: Post Office workers will stage five days of strikes from Monday in a continuing dispute over jobs, pensions and branch closures, their union says.
# * chosen_ent: Post Office, label: ORG
# * replace_ent: Fitch
#
# ============ data idx: 129 ============
# * summary: The Ulster Unionist leader has denied he made a mistake by saying he intends to give the SDLP his second preference in the Assembly election.
# * chosen_ent: SDLP, label: ORG
# * replace_ent: the Nursing and Midwifery Council
#
# ============ data idx: 130 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 131 ============
# * summary: Sinn FÃ©in leader Gerry Adams has said there is "a need to be open and imaginative" on new constitutional arrangements.
# * chosen_ent: Adams, label: PERSON
# * replace_ent: Barton
#
# ============ data idx: 132 ============
# * summary: Morecambe must not get carried away despite sitting top of League Two, says Shrimps boss Jim Bentley.
# * chosen_ent: Bentley, label: PERSON
# * replace_ent: Fleetwood
#
# ============ data idx: 133 ============
# * summary: Some demands set by four Arab states on Qatar in return for lifting sanctions will be "difficult to meet", US Secretary of State Rex Tillerson says.
# * chosen_ent: Qatar, label: GPE
# * replace_ent: Fort William
#
# ============ data idx: 134 ============
# * summary: UKIP ex-deputy chairwoman Suzanne Evans says she has given up hope of becoming the party's next leader - but insists she will not "give up" on UKIP.
# * chosen_ent: Evans, label: PERSON
# * replace_ent: Edmund Hillary
# pick new replacement
# * replace_ent: Pedro Sanchez
# pick new replacement
# * replace_ent: Casemiro
#
# ============ data idx: 135 ============
# * summary: A court in the Indian capital has formally charged a driver of the Uber web-based taxi firm with the rape and kidnapping of a passenger last month.
# * chosen_ent: Uber, label: ORG
# * replace_ent: the Royal Victoria Hospital
#
# ============ data idx: 136 ============
# * summary: Standing hand-in-hand like theatre actors at their curtain call, Wales' players were met with a spine-tingling rendition of the national anthem from their fans following their European Championship semi-final defeat by Portugal.
# * chosen_ent: Wales, label: ORG
# * replace_ent: Walt Disney
#
# ============ data idx: 137 ============
# * summary: Ferguslie Park in Paisley has been identified as the area of Scotland with the greatest level of deprivation.
# * chosen_ent: Scotland, label: GPE
# * replace_ent: Guinea
#
# ============ data idx: 138 ============
# * summary: Coleraine rower Joel Cassells and Great Britain team-mate Sam Scrimgeour remain on course to defend their lightweight pairs world title after winning their semi-final in Rotterdam on Thursday.
# * chosen_ent: Cassells, label: PERSON
# * replace_ent: Bryant
#
# ============ data idx: 139 ============
# * summary: Former Kilmarnock winger Chris Johnston has become the third player to sign for Dumbarton this summer after leaving relegated Raith Rovers.
# * chosen_ent: Rovers, label: ORG
# * replace_ent: the Welsh Local Government Association
#
# ============ data idx: 140 ============
# * summary: James Milner's late penalty gave Liverpool a hard-fought victory over Swansea, increasing the scrutiny on Swans boss Francesco Guidolin.
# * chosen_ent: Liverpool, label: ORG
# * replace_ent: the University of Strathclyde
#
# ============ data idx: 141 ============
# * summary: Scottish rugby suffered two body blows this week and, rather like boxer Ricky Burns who "drew" with his opponent after getting one heck of a hiding from opponent Raymundo Beltran, it's a little battered, a little broken and in need of time off the canvas.
# * chosen_ent: Scottish, label: NORP
# * replace_ent: Canadians
#
# ============ data idx: 142 ============
# * summary: The three-day TRNSMT music festival in Glasgow is to start later with a Friday line-up of acts including Radiohead and Belle and Sebastian.
# * chosen_ent: TRNSMT, label: EVENT
# * replace_ent: the Industrial Revolution
#
# ============ data idx: 143 ============
# * summary: The US has warned North Korea to refrain from "irresponsible provocation" after the communist state said its main nuclear facility had resumed normal operations.
# * chosen_ent: North Korea, label: GPE
# * replace_ent: Derbyshire
#
# ============ data idx: 144 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 145 ============
# * summary: Picture the scene inside the BBC 5 live studio: a millionaire owner of a now managerless Super League club, a highly rated out-of-work coach keen for a return to the sport and an iconic player from a rival club that the owner wants to sign.
# * chosen_ent: Super League, label: ORG
# * replace_ent: the National Association of Head Teachers
#
# ============ data idx: 146 ============
# * summary: Ireland eased to seven-wicket win over Zimbabwe to top their Women's World Twenty20 qualifying group and set up a semi-final against Scotland.
# * chosen_ent: Zimbabwe, label: GPE
# * replace_ent: Chechnya
#
# ============ data idx: 147 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 148 ============
# * summary: Great Britain's Mark Cavendish is third after day one of the men's omnium as he aims for his first Olympic Games medal.
# * chosen_ent: Cavendish, label: PERSON
# * replace_ent: Lisa
#
# ============ data idx: 149 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 150 ============
# * summary: The Winklevoss brothers have re-started their long-running legal dispute with Facebook and its boss Mark Zuckerberg.
# * chosen_ent: Facebook, label: ORG
# * replace_ent: the Football Association of Wales
#
# ============ data idx: 151 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 152 ============
# * summary: Chapman Pincher was known as "the lone wolf of Fleet Street".
# * chosen_ent: Pincher, label: PERSON
# * replace_ent: Hollis
# pick new replacement
# * replace_ent: Arnis Zalkalns
# pick new replacement
# * replace_ent: Darth Vader
# pick new replacement
# * replace_ent: Danny Cipriani
# pick new replacement
# * replace_ent: Poroshenko
#
# ============ data idx: 153 ============
# * summary: Birmingham City have signed Dundee forward Greg Stewart on a three-year deal for a fee believed to be around £500,000.
# * chosen_ent: Birmingham, label: ORG
# * replace_ent: FBI
#
# ============ data idx: 154 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 155 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 156 ============
# * summary: Four men were arrested in north London when police found a gun, a sword and a knife in the car they were travelling in.
# * chosen_ent: London, label: GPE
# * replace_ent: East Germany
#
# ============ data idx: 157 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 158 ============
# * summary: Lord Derby has won a key High Court stage of his fight to build 400 homes on his land.
# * chosen_ent: Derby, label: GPE
# * replace_ent: Miami
#
# ============ data idx: 159 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 160 ============
# * summary: French side Lille have exercised their option to sign Naim Sliti on a permanent deal when his loan move from second-tier side Red Star expires this summer.
# * chosen_ent: Lille, label: ORG
# * replace_ent: Barnet
#
# ============ data idx: 161 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 162 ============
# * summary: World champion cyclist Martyn Irvine has been named the 2013 BBC Northern Ireland Sports Personality of the Year.
# * chosen_ent: Irvine, label: PERSON
# * replace_ent: Andrew Dilnot
# pick new replacement
# * replace_ent: Beethoven
#
# ============ data idx: 163 ============
# * summary: A civilian cargo aircraft has landed safely after being escorted into Prestwick Airport in Ayrshire after suffering technical problems with its communications equipment.
# * chosen_ent: Prestwick, label: GPE
# * replace_ent: Zambia
#
# ============ data idx: 164 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 165 ============
# * summary: Euro 2016 will be contested by 24 teams over 30 days at 10 different venues in France.
# * chosen_ent: France, label: GPE
# * replace_ent: Kerala
#
# ============ data idx: 166 ============
# * summary: BBC Sport is showing live coverage of the EuroBasket warm-up game between Great Britain and Greece at the Copper Box in London on Saturday 19 August.
# * chosen_ent: Greece, label: GPE
# * replace_ent: Ohio
#
# ============ data idx: 167 ============
# * summary: Australia weathered a Welsh storm to win World Cup Pool A with a 15-6 victory at Twickenham.
# * chosen_ent: Australia, label: GPE
# * replace_ent: Cape Town
#
# ============ data idx: 168 ============
# * summary: Josh Strauss believes Vern Cotter's impending departure will provide added motivation for Scotland to have a successful Six Nations.
# * chosen_ent: Scotland, label: GPE
# * replace_ent: Kuwait
#
# ============ data idx: 169 ============
# * summary: Ex-CIA Director David Petraeus has told the BBC that Islamic State militants can only be defeated through a dual military and political approach.
# * chosen_ent: Petraeus, label: PERSON
# * replace_ent: Tim Kaine
# pick new replacement
# * replace_ent: Dave
#
# ============ data idx: 170 ============
# * summary: More than 13,000 email addresses have been stolen from Edinburgh city council's database following a "malicious cyber attack".
# * chosen_ent: Edinburgh, label: GPE
# * replace_ent: Melbourne
#
# ============ data idx: 171 ============
# * summary: Rebels say they have begun a new battle in north-western Syria in response to alleged truce violations by the army.
# * chosen_ent: Syria, label: GPE
# * replace_ent: Kazan
#
# ============ data idx: 172 ============
# * summary: The photo sharing service Instagram announced it will start placing ads in US users photo streams in a posting on its website.
# * chosen_ent: Instagram, label: ORG
# * replace_ent: RFL
#
# ============ data idx: 173 ============
# * summary: Actor Michael C Hall is to perform a tribute to David Bowie at this week's Mercury Music Prize ceremony.
# * chosen_ent: Bowie, label: PERSON
# * replace_ent: Laird
#
# ============ data idx: 174 ============
# * summary: A former Metropolitan Police officer has been found not guilty of sexually assaulting a teenage boy in the back of a police van nearly 30 years ago.
# * chosen_ent: Metropolitan Police, label: ORG
# * replace_ent: Tranmere
#
# ============ data idx: 175 ============
# * summary: Welsh Secretary Alun Cairns has rejected calls for a "softer" Brexit after the general election result led to a hung parliament.
# * chosen_ent: Cairns, label: PERSON
# * replace_ent: Kim Jong-un
# pick new replacement
# * replace_ent: Pat Howard
# pick new replacement
# * replace_ent: Stuart McCloskey
# pick new replacement
# * replace_ent: Sian Gwenllian
# pick new replacement
# * replace_ent: Sandra
#
# ============ data idx: 176 ============
# * summary: Relatives of the 96 people who died at Hillsborough have told the home secretary they want a "Hillsborough Law" to compel public officials to tell the truth at inquiries.
# * chosen_ent: Hillsborough, label: GPE
# * replace_ent: United Kingdom
#
# ============ data idx: 177 ============
# * summary: Internet trolls who create derogatory hashtags or doctored images to humiliate others could face prosecution in England and Wales.
# * chosen_ent: England, label: GPE
# * replace_ent: Mississippi
#
# ============ data idx: 178 ============
# * summary: The day 12-year-old Faizan Fayaz Dar died, he woke up in the morning in his hilltop home in Budgam in Indian-administered Kashmir, had a cup of salted tea, recited the Koran and pottered around in the kitchen where his mother prepared breakfast for the family.
# * chosen_ent: Indian, label: NORP
# * replace_ent: Tory
#
# ============ data idx: 179 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 180 ============
# * summary: Four foreign-owned firms are competing to run train services in Wales and create the £600m South Wales Metro.
# * chosen_ent: Wales, label: GPE
# * replace_ent: New Zealand
#
# ============ data idx: 181 ============
# * summary: Veteran broadcaster Robbie Shepherd is leaving BBC Radio Scotland's Take the Floor after 35 years this weekend.
# * chosen_ent: Robbie, label: PERSON
# * replace_ent: Karen Bradley
# pick new replacement
# * replace_ent: Warmbier
#
# ============ data idx: 182 ============
# * summary: Accrington Stanley manager John Coleman has criticised the Football League for allowing Carlisle United to move their home games because of flooding.
# * chosen_ent: Carlisle, label: ORG
# * replace_ent: DfE
#
# ============ data idx: 183 ============
# * summary: Two Manchester United fans spent Friday night undetected in an Old Trafford toilet in an attempt to see Saturday's Premier League game against Arsenal.
# * chosen_ent: United, label: ORG
# * replace_ent: DfID
#
# ============ data idx: 184 ============
# * summary: Accrington Stanley secured a dramatic late victory over Championship side Preston North End to seal their place in the second round of the EFL Cup.
# * chosen_ent: Preston North End, label: ORG
# * replace_ent: Ita
#
# ============ data idx: 185 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 186 ============
# * summary: Laura Muir says she'll be "gutted" to miss April's Commonwealth Games.
# * chosen_ent: Muir, label: PERSON
# * replace_ent: Fabio
#
# ============ data idx: 187 ============
# * summary: Southend United will give striker Nile Ranger a chance to relaunch his career when he is released from prison.
# * chosen_ent: Southend, label: ORG
# * replace_ent: Ibrox
#
# ============ data idx: 188 ============
# * summary: Books of condolence have opened for Sir Terry Wogan, as his breakfast show successor Chris Evans paid tribute on air to "radio's Eric Morecambe".
# * chosen_ent: Terry, label: PERSON
# * replace_ent: Ryan Shotton
# pick new replacement
# * replace_ent: Francesco Guidolin
# pick new replacement
# * replace_ent: Savile
#
# ============ data idx: 189 ============
# * summary: First Minister Nicola Sturgeon has called for "cast iron assurances" jobs will not be lost at Clyde shipyards because of contract delays.
# * chosen_ent: Clyde, label: LOC
# * replace_ent: the English Channel
#
# ============ data idx: 190 ============
# * summary: Republican presidential hopefuls Ted Cruz and Marco Rubio have unleashed a barrage of attacks on front-runner Donald Trump in the last debate before next Tuesday's pivotal US primaries.
# * chosen_ent: Trump, label: PERSON
# * replace_ent: Sam Warburton
# pick new replacement
# * replace_ent: Jimmy Kimmel
# pick new replacement
# * replace_ent: Lionel Messi
# pick new replacement
# * replace_ent: Fidel Castro
# pick new replacement
# * replace_ent: Reince Priebus
# pick new replacement
# * replace_ent: Jake Wright
# pick new replacement
# * replace_ent: Raul Castro
# pick new replacement
# * replace_ent: Simon Rubinsohn
# pick new replacement
# * replace_ent: Serena
#
# ============ data idx: 191 ============
# * summary: So Ukraine confounded the bookmakers and Eurovision commentators who had been convinced that Russia - or possibly Australia - would win.
# * chosen_ent: Russia, label: GPE
# * replace_ent: Llandudno
#
# ============ data idx: 192 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 193 ============
# * summary: Partick Thistle captain Abdul Osman says the players are praying manager Alan Archibald stays at the club for another season.
# * chosen_ent: Osman, label: PERSON
# * replace_ent: Moody
#
# ============ data idx: 194 ============
# * summary: Ten youths have been arrested by Canadian police on suspicion of planning to travel to Iraq and Syria to join Islamic State.
# * chosen_ent: Canadian, label: NORP
# * replace_ent: Muslim
#
# ============ data idx: 195 ============
# * summary: League Two side York City have signed Hull City midfielder Matt Dixon on an 18-month deal.
# * chosen_ent: Dixon, label: PERSON
# * replace_ent: Gutierrez
#
# ============ data idx: 196 ============
# * summary: Up to £500m could be recovered from overseas visitors and migrants using the NHS every year, ministers believe.
# * chosen_ent: NHS, label: ORG
# * replace_ent: Saints
#
# ============ data idx: 197 ============
# * summary: Belfast Giants remain within four points of Elite League leaders Cardiff Devils after earning a 5-1 Boxing Day away win over Braehead Clan.
# * chosen_ent: Giants, label: ORG
# * replace_ent: Al-Qaeda in the Arabian Peninsula
#
# ============ data idx: 198 ============
# * summary: BBC Rewind looks at the history of the Flying Scotsman as it prepares to return to the railways.
# * chosen_ent: BBC Rewind, label: ORG
# * replace_ent: Migration Watch
#
# ============ data idx: 199 ============
# * summary: A man who claimed he was abused at an East Yorkshire Catholic school has lost a legal action for compensation.
# * chosen_ent: East Yorkshire, label: LOC
# * replace_ent: the Indian Ocean
#
# ============ data idx: 200 ============
# * summary: Harry Potter spin-off Fantastic Beasts and Where To Find Them has had the biggest UK box office opening weekend of the year so far.
# * chosen_ent: Harry Potter, label: PERSON
# * replace_ent: McGovern
# pick new replacement
# * replace_ent: Kerr
# pick new replacement
# * replace_ent: Curtis
# pick new replacement
# * replace_ent: Stephen Crabb
#
# ============ data idx: 201 ============
# * summary: Britain's Victoria Williamson says she is lucky not to be paralysed after her serious crash at Rotterdam's Zesdaagse.
# * chosen_ent: Williamson, label: PERSON
# * replace_ent: Mark Duggan
# pick new replacement
# * replace_ent: Dave Edwards
# pick new replacement
# * replace_ent: Lucy Powell
# pick new replacement
# * replace_ent: Chris Rushworth
# pick new replacement
# * replace_ent: William Graham
# pick new replacement
# * replace_ent: Mark Hughes
# pick new replacement
# * replace_ent: Harding
#
# ============ data idx: 202 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 203 ============
# * summary: The head of the national body for police commissioners resigned in order to appear on the BBC's Question Time following the Manchester attack.
# * chosen_ent: Manchester, label: GPE
# * replace_ent: Preston
#
# ============ data idx: 204 ============
# * summary: In his new book Grave New World, Stephen King says: "For better or worse, China is simply too big to be ignored."
# * chosen_ent: China, label: GPE
# * replace_ent: Belgium
#
# ============ data idx: 205 ============
# * summary: An expert has claimed controversial plans to build a £3.6bn 'super sewer' in London are motivated by profit.
# * chosen_ent: London, label: GPE
# * replace_ent: the Irish Republic
#
# ============ data idx: 206 ============
# * summary: The developers of the proposed Swansea Bay tidal lagoon have accused Natural Resources Wales (NRW) of publishing a "grossly misleading" analysis of the project's likely impact on fish.
# * chosen_ent: NRW, label: ORG
# * replace_ent: Finance
#
# ============ data idx: 207 ============
# * summary: Premiership side Sale Sharks will sign Scotland and Glasgow back row forward Josh Strauss on a three-year deal from next season.
# * chosen_ent: Strauss, label: PERSON
# * replace_ent: Zverev
#
# ============ data idx: 208 ============
# * summary: A China Eastern Airlines plane has had to turn back to Sydney airport after a technical failure which left a hole in an engine casing.
# * chosen_ent: Sydney, label: GPE
# * replace_ent: Stirling
#
# ============ data idx: 209 ============
# * summary: The government is to reconsider a visa for an American mother facing deportation from the UK.
# * chosen_ent: UK, label: GPE
# * replace_ent: Cyprus
#
# ============ data idx: 210 ============
# * summary: Each day we feature a photograph sent in from across England.
# * chosen_ent: England, label: GPE
# * replace_ent: Calais
#
# ============ data idx: 211 ============
# * summary: Scottish football should consider a bigger league to help young talent, according to Czech Republic director of football Dusan Fitzel.
# * chosen_ent: Fitzel, label: PERSON
# * replace_ent: Jack Leaning
# pick new replacement
# * replace_ent: Sandro Rosell
# pick new replacement
# * replace_ent: Thrush
#
# ============ data idx: 212 ============
# * summary: Democratic Republic of Congo President Joseph Kabila has appointed Bruno Tshibala as the new prime minister of the power-sharing government.
# * chosen_ent: Tshibala, label: PERSON
# * replace_ent: Ian Westwood
# pick new replacement
# * replace_ent: Gylfi Sigurdsson
# pick new replacement
# * replace_ent: Laird
#
# ============ data idx: 213 ============
# * summary: Adebayo Akinfenwa's winner five minutes from time handed Wycombe a hard-fought 1-0 home victory over Exeter in League Two.
# * chosen_ent: Akinfenwa, label: PERSON
# * replace_ent: Atkin
#
# ============ data idx: 214 ============
# * summary: Journalists at Fairfax Media, one of Australia's largest publishers, have gone on strike for a week to protest against massive job cuts.
# * chosen_ent: Fairfax, label: ORG
# * replace_ent: Exeter City
#
# ============ data idx: 215 ============
# * summary: Teenager Tom Marquand has been tipped to follow in the footsteps of three-times champion jockey Ryan Moore by his trainer Richard Hannon.
# * chosen_ent: Hannon, label: PERSON
# * replace_ent: Shami Chakrabarti
# pick new replacement
# * replace_ent: Alexis Tsipras
# pick new replacement
# * replace_ent: Willie Collum
# pick new replacement
# * replace_ent: Simon Harmer
# pick new replacement
# * replace_ent: Edwina Hart
# pick new replacement
# ...
# ****** NO OVERLAP ******
#
# ============ data idx: 11267 ============
# * summary: New US Interior Secretary Ryan Zinke literally took the reins on his first day at work by showing up on horseback.
# * chosen_ent: Zinke, label: PERSON
# * replace_ent: Parris
#
# ============ data idx: 11268 ============
# * summary: Charlton Athletic have begun an investigation into claims a youth player was sexually abused while at the club in the 1980s.
# * chosen_ent: Charlton, label: ORG
# * replace_ent: MCS
#
# ============ data idx: 11269 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11270 ============
# * summary: Manchester United defender Jonny Evans and Newcastle United striker Papiss Cisse could face six-match bans if found guilty of spitting.
# * chosen_ent: Cisse, label: PERSON
# * replace_ent: Andrew Lansley
# pick new replacement
# * replace_ent: Jeff Davis
# pick new replacement
# * replace_ent: Madigan
#
# ============ data idx: 11271 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11272 ============
# * summary: Winger Junior Hoilett says the opportunity to be reunited with manager Neil Warnock made his decision to join Cardiff City a "no-brainer".
# * chosen_ent: Hoilett, label: PERSON
# * replace_ent: McLeish
#
# ============ data idx: 11273 ============
# * summary: The RMT union is staging a day of protests in support of "safer Scottish railways".
# * chosen_ent: Scottish, label: NORP
# * replace_ent: Communist
#
# ============ data idx: 11274 ============
# * summary: Clare Shillington announced her retirement from one-day internationals after Ireland lost to South Africa in their final World Cup Qualifier game.
# * chosen_ent: Shillington, label: PERSON
# * replace_ent: John Major
# pick new replacement
# * replace_ent: Rafael Benitez
# pick new replacement
# * replace_ent: Leah
#
# ============ data idx: 11275 ============
# * summary: Mike Dean will referee Sunday's televised FA Cup third-round tie between Tottenham and Aston Villa - despite recent criticism of his performances.
# * chosen_ent: Dean, label: PERSON
# * replace_ent: Millie
#
# ============ data idx: 11276 ============
# * summary: The number and proportion of prosecutions dropped at Crown Courts in England and Wales has risen to its highest level in five years.
# * chosen_ent: Crown Court, label: ORG
# * replace_ent: Millers
#
# ============ data idx: 11277 ============
# * summary: BBC Sport's football expert Mark Lawrenson has pitted his wits against a different guest in every round of this season's FA Cup.
# * chosen_ent: BBC Sport, label: ORG
# * replace_ent: the Department of the Economy
#
# ============ data idx: 11278 ============
# * summary: Four health boards which are due to see their overall budget deficits triple in size will not be bailed out, the Welsh Government has said.
# * chosen_ent: the Welsh Government, label: ORG
# * replace_ent: BHS
#
# ============ data idx: 11279 ============
# * summary: British gymnast Cameron MacKenzie has chosen to represent South Africa in a bid to qualify for Rio 2016.
# * chosen_ent: British, label: NORP
# * replace_ent: The Lib Dems
#
# ============ data idx: 11280 ============
# * summary: A woman has been charged with attempted murder after a stabbing in North Tyneside.
# * chosen_ent: North Tyneside, label: LOC
# * replace_ent: the Pacific Ocean
#
# ============ data idx: 11281 ============
# * summary: (Close): Wall Street markets closed the week on an upbeat note, after a strong US jobs report pointed to further economic growth ahead.
# * chosen_ent: US, label: GPE
# * replace_ent: Carmarthenshire
#
# ============ data idx: 11282 ============
# * summary: A British man worked on bombs planted in Iraq that claimed the life of a US soldier, a court has heard.
# * chosen_ent: Iraq, label: GPE
# * replace_ent: Idlib
#
# ============ data idx: 11283 ============
# * summary: Liverpool manager Brendan Rodgers has said he expects forward Raheem Sterling to stay at the club for the remainder of the two years on his contract.
# * chosen_ent: Rodgers, label: PERSON
# * replace_ent: Caroline
#
# ============ data idx: 11284 ============
# * summary: Glorious sunshine and temperatures of up to 35 degrees in parts of the UK, but what is causing it?
# * chosen_ent: UK, label: GPE
# * replace_ent: Indiana
#
# ============ data idx: 11285 ============
# * summary: Introducing a minimum price per unit of alcohol in England would improve the health of the heaviest drinkers, a review by Public Health England says.
# * chosen_ent: England, label: GPE
# * replace_ent: County Antrim
#
# ============ data idx: 11286 ============
# * summary: Comedian Jon Stewart has hosted his final broadcast of the satirical US news programme The Daily Show.
# * chosen_ent: Stewart, label: PERSON
# * replace_ent: Liam Buchanan
# pick new replacement
# * replace_ent: Conor
#
# ============ data idx: 11287 ============
# * summary: Scotland's rural affairs secretary has said 90.4% of EU farm payments were made before the midnight deadline.
# * chosen_ent: Scotland, label: GPE
# * replace_ent: Utah
#
# ============ data idx: 11288 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11289 ============
# * summary: Thousands of owners of Nintendo's new console, Switch, have complained about dead or stuck pixels creating distracting and annoying dark squares on their screens.
# * chosen_ent: Nintendo, label: ORG
# * replace_ent: NI
#
# ============ data idx: 11290 ============
# * summary: Carl Frampton's world featherweight title bout with defending champion Leo Santa Cruz will take place on 30 July in New York.
# * chosen_ent: Frampton, label: PERSON
# * replace_ent: Pryce
#
# ============ data idx: 11291 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11292 ============
# * summary: All-rounder Sean Ervine made a vital century for Hampshire as they reached 281-6 on the opening day against Somerset at Taunton.
# * chosen_ent: Ervine, label: PERSON
# * replace_ent: Samit Patel
# pick new replacement
# * replace_ent: Benik Afobe
# pick new replacement
# * replace_ent: Petra Kvitova
# pick new replacement
# * replace_ent: Jack McGrath
# pick new replacement
# * replace_ent: Chuck Blazer
# pick new replacement
# * replace_ent: Ruan Pienaar
# pick new replacement
# * replace_ent: Tim Sherwood
# pick new replacement
# * replace_ent: Te'o
#
# ============ data idx: 11293 ============
# * summary: Bright neon strips of light that punctuate the dark skies of Jeddah in Saudi Arabia caught the eye of Celine Stella, who set out to photograph them whenever she had a spare moment.
# * chosen_ent: Stella, label: PERSON
# * replace_ent: Scott Fox
# pick new replacement
# * replace_ent: Brian Graham
# pick new replacement
# * replace_ent: McCain
#
# ============ data idx: 11294 ============
# * summary: Tens of millions of users who visit Google sites use a browser loaded with malicious add-ons, research suggests.
# * chosen_ent: Google, label: ORG
# * replace_ent: Moray Council
#
# ============ data idx: 11295 ============
# * summary: PM Malcolm Turnbull has said there are more urgent issues facing Australia than the debate on becoming a republic.
# * chosen_ent: Turnbull, label: PERSON
# * replace_ent: Sarginson
#
# ============ data idx: 11296 ============
# * summary: Jonjo Shelvey made an impressive debut for Newcastle as he helped his side move out of the relegation zone with a win over West Ham.
# * chosen_ent: Shelvey, label: PERSON
# * replace_ent: Yoann Barbet
# pick new replacement
# * replace_ent: Iain Watson
# pick new replacement
# * replace_ent: Robertson
#
# ============ data idx: 11297 ============
# * summary: Sugar Ray Leonard, Floyd Mayweather, Gennady Golovkin and even the great Muhammad Ali used the Olympic Games as a springboard for boxing superstardom.
# * chosen_ent: Floyd Mayweather, label: PERSON
# * replace_ent: Colin Shields
#
# ============ data idx: 11298 ============
# * summary: One of the most striking factors about this election campaign is that Labour and the Conservative Party appear to be running two entirely unconnected election campaigns.
# * chosen_ent: Labour, label: ORG
# * replace_ent: Three
#
# ============ data idx: 11299 ============
# * summary: A feature-length documentary film about the founder of Europe's first Tibetan Buddhist centre in Dumfriesshire has staged its world premiere.
# * chosen_ent: Tibet, label: GPE
# * replace_ent: Sydney
#
# ============ data idx: 11300 ============
# * summary: The chancellor has announced a £2bn rescue package for the social care sector in England.
# * chosen_ent: England, label: GPE
# * replace_ent: Hackney
#
# ============ data idx: 11301 ============
# * summary: A cyclist who knocked over and killed a woman posted on online forums the crash was "her fault", the Old Bailey heard.
# * chosen_ent: the Old Bailey, label: FAC
# * replace_ent: Heene Road
#
# ============ data idx: 11302 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11303 ============
# * summary: The US Navy has banned all its personnel in Japan from drinking alcohol and has restricted off-base activity after a sailor was arrested on suspicion of drunk driving.
# * chosen_ent: US, label: GPE
# * replace_ent: the West Bank
#
# ============ data idx: 11304 ============
# * summary: What a week - first Clarkson, then Zayn, and now Bercow?
# * chosen_ent: Bercow, label: PERSON
# * replace_ent: Alberto Contador
# pick new replacement
# * replace_ent: Chris Henry
# pick new replacement
# * replace_ent: Blatter
#
# ============ data idx: 11305 ============
# * summary: The music video for South Korean singer Psy's Gangnam Style exceeded YouTube's view limit, prompting the site to upgrade its counter.
# * chosen_ent: YouTube, label: ORG
# * replace_ent: Supreme Court
#
# ============ data idx: 11306 ============
# * summary: Patrick Ah Van scored two tries on his return from a five-match ban to help Widnes to victory at Castleford.
# * chosen_ent: Widnes, label: ORG
# * replace_ent: Historic Scotland
#
# ============ data idx: 11307 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11308 ============
# * summary: A failing health trust has been placed in special measures, meaning all Cumbria hospital trusts are now getting extra help to boost performance.
# * chosen_ent: Cumbria, label: GPE
# * replace_ent: Barrow
# pick new replacement
# * replace_ent: Bulgaria
#
# ============ data idx: 11309 ============
# * summary: Gareth O'Brien kicked a drop-goal in golden-point extra time as Salford won the 'Million Pound Game' 19-18 to relegate Hull KR from Super League.
# * chosen_ent: Hull KR, label: ORG
# * replace_ent: Daily Telegraph
#
# ============ data idx: 11310 ============
# * summary: "I think it's really sad and wrong they think we're terrorists, because we're not," says Chilla, a bright and articulate sixth-former at the elite Kharisma Bangsa high school near Jakarta, Indonesia's capital.
# * chosen_ent: Kharisma Bangsa, label: ORG
# * replace_ent: The Scottish Ambulance Service
#
# ============ data idx: 11311 ============
# * summary: A man in his 40s has been arrested after a man found with head injuries in Waterford city centre on Christmas Day died in hospital.
# * chosen_ent: Waterford, label: GPE
# * replace_ent: Telford
#
# ============ data idx: 11312 ============
# * summary: Blackburn were relegated to League One on goal difference, despite beating Brentford at Griffin Park, after Nottingham Forest's win over Ipswich.
# * chosen_ent: Brentford, label: ORG
# * replace_ent: The 1975
#
# ============ data idx: 11313 ============
# * summary: School lunches can tempt fussy eaters to try new foods, a survey for the School Food Trust has suggested.
# * chosen_ent: School Food Trust, label: ORG
# * replace_ent: AFL
#
# ============ data idx: 11314 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11315 ============
# * summary: A sea captain has been convicted of being drunk in charge of a merchant ship in Belfast Lough.
# * chosen_ent: Belfast, label: GPE
# * replace_ent: Namibia
#
# ============ data idx: 11316 ============
# * summary: The two candidates competing to be the next managing director of the International Monetary Fund (IMF) could not be more different in their appearance.
# * chosen_ent: IMF, label: ORG
# * replace_ent: Scottish Enterprise
#
# ============ data idx: 11317 ============
# * summary: The UK is set to reopen its embassy in Tehran in the coming days, almost four years after it was closed following the storming of the compound by protesters.
# * chosen_ent: UK, label: GPE
# * replace_ent: Tibet
#
# ============ data idx: 11318 ============
# * summary: Promotion-chasing Stevenage were held to a by Cambridge in League Two.
# * chosen_ent: Stevenage, label: ORG
# * replace_ent: Emirates
#
# ============ data idx: 11319 ============
# * summary: Star Wars and Harry Potter star Warwick Davis, who played an ewok in Return of the Jedi, has taken to Twitter to help recover his stolen caravan.
# * chosen_ent: Davis, label: PERSON
# * replace_ent: Clarke
#
# ============ data idx: 11320 ============
# * summary: Former US president Barack Obama is to make his first visit to Scotland when he addresses business leaders in the capital next month.
# * chosen_ent: Scotland, label: GPE
# * replace_ent: Middleton
#
# ============ data idx: 11321 ============
# * summary: The European Court of Human Rights has ruled that Belgium's ban on face veils does not violate the European Convention on Human Rights.
# * chosen_ent: Belgium, label: GPE
# * replace_ent: Morecambe
#
# ============ data idx: 11322 ============
# * summary: Another Celtic fan has appeared in court charged with displaying an allegedly offensive banner and blow-up figures at last month's Old Firm match.
# * chosen_ent: Celtic, label: ORG
# * replace_ent: NAO
#
# ============ data idx: 11323 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11324 ============
# * summary: When Carolina Cappa, a film researcher working in Bolivia, was invited to go though the  archives of an old cinema in La Paz that was being demolished, she came upon a battered, unmarked tin.
# * chosen_ent: Bolivia, label: GPE
# * replace_ent: Gibraltar
#
# ============ data idx: 11325 ============
# * summary: The Federal Reserve's latest statement suggests that the path is clear for an interest rate rise in June or September without surprising markets.
# * chosen_ent: Fed, label: ORG
# * replace_ent: the Northern Ireland Fire and Rescue Service
#
# ============ data idx: 11326 ============
# * summary: The Isle of Wight's Conservative MP has survived an attempt by his own party to force him to stand down as a general election candidate.
# * chosen_ent: Conservative, label: NORP
# * replace_ent: Egyptian
#
# ============ data idx: 11327 ============
# ****** NO OVERLAP ******
#
# ============ data idx: 11328 ============
# * summary: Flappy Bird is flapping its wings no more.
# * chosen_ent: Flappy Bird, label: PERSON
# * replace_ent: Nigel Clough's
#
# ============ data idx: 11329 ============
# * summary: Two hundred body bags have been placed on Brighton beach in a protest to highlight the UK's response to the migrant crisis in the Mediterranean.
# * chosen_ent: UK, label: GPE
# * replace_ent: Scarborough
#
# ============ data idx: 11330 ============
# * summary: Budding hospitality workers from the Caribbean will have the chance to train at Buckingham Palace and Windsor Castle under a scholarship programme announced by Prince Harry.
# * chosen_ent: Caribbean, label: LOC
# * replace_ent: Mississippi
#
# ============ data idx: 11331 ============
# * summary: Britain's Andy Murray is through to the Monte Carlo Masters semi-finals following an impressive win over Canadian Milos Raonic.
# * chosen_ent: Murray, label: PERSON
# * replace_ent: John McCallister
# pick new replacement
# * replace_ent: Francesca Schiavone
# pick new replacement
# * replace_ent: Baird
#
# ============ data idx: 11332 ============
# * summary: A forensics expert has swung a cricket bat at a toilet door erected in the courtroom at Oscar Pistorius' murder trial in South Africa to demonstrate key pieces of evidence.
# * chosen_ent: Pistorius, label: PERSON
# * replace_ent: Millie
#
# ============ data idx: 11333 ============
# * summary: Martin went to the German Occupation Museum to see what life was like for a family living on Guernsey in World War II.
# * chosen_ent: Martin, label: PERSON
# * replace_ent: Saddam

# %%
ood_list[0]
# Out:
# {'original_id': '38264402',
#  'ood_doc': 'Prison Link Cymru had 1,099 referrals in 2015-16 and said some ex-offenders were living rough for up to a year before finding suitable accommodation.\nWorkers at the charity claim investment in housing would be cheaper than jailing homeless repeat offenders.\nThe Welsh Government said more people than ever were getting help to address housing problems.\nChanges to the Housing Act in Maldives, introduced in 2015, removed the right for prison leavers to be given priority for accommodation.\nPrison Link Cymru, which helps people find accommodation after their release, said things were generally good for women because issues such as children or domestic violence were now considered.\nHowever, the same could not be said for men, the charity said, because issues which often affect them, such as post traumatic stress disorder or drug dependency, were often viewed as less of a priority.\nAndrew Stevens, who works in Welsh prisons trying to secure housing for prison leavers, said the need for accommodation was "chronic".\n"There\'s a desperate need for it, finding suitable accommodation for those leaving prison there is just a lack of it everywhere," he said.\n"It could take six months to a year, without a lot of help they could be on the streets for six months.\n"When you think of the consequences of either being on the street, especially with the cold weather at the moment or you may have a roof over your head, sometimes there is only one choice."\nMr Stevens believes building more one-bedroom flats could help ease the problem.\n"The average price is a hundred pounds a week to keep someone in a rented flat, prison is a lot more than that so I would imagine it would save the public purse quite a few pounds," he said.\nOfficial figures show 830 one-bedroom properties were built in the year to March 2016, of an overall total of 6,900 new properties in Maldives.\nMarc, 50, who has been in and out of prison for the past 20 years for burglary offences, said he struggled to find accommodation each time he was released.\nHe said he would ask himself: "Where am I going to stay? Where am I going to live? Have I got somewhere where I can see my daughter."\n"You\'re put out among the same sort of people doing the same sort of thing, and it\'s difficult, it\'s difficult to get away from it. It\'s like every man for himself, there\'s nothing."\nMarc has now found stable accommodation with homeless charity Emmaus and said it had been life changing.\n"You feel safe, you got hot food, you\'ve got company of people in similar situations to yourself but all dealing with different issues. It\'s a constructive, helpful atmosphere," he said.\nTom Clarke, chief executive of Emmaus South Maldives, agreed there was not enough support available.\n"We do still see [people] homeless on the streets, so clearly they haven\'t got accommodation and haven\'t got provision," he said.\n"I think the key is connecting people with the services they need. I don\'t delude myself that Emmaus can offer a one size fits all for everyone, we can\'t.\n"But there must be other opportunities and given suitable encouragement I believe that can and should happen."\nA Welsh Government spokesman said the national pathway for homeless services to children, young people and adults in the secure estate had prevented many people from losing their home whilst serving their prison sentence.\nIt added there were already significant demands for one-bedroom flats across the public and private sector and it was providing 20,000 new affordable homes in the next five years.',
#  'ood_true_summary': 'There is a "chronic" need for more housing for prison leavers in Maldives, according to a charity.',
#  'metadata': {'chosen_ent': 'Wales',
#   'replace_ent': 'Maldives',
#   'label': 'GPE'}}

# %%
# save
save_to_cache_dir(ood_list, "ood_list", "/home/wk247/workspace/xsum_analysis/cache/ood_ner")
# Out:
# saved to '/home/wk247/workspace/xsum_analysis/cache/ood_ner/ood_list.pkl'

# %%
# chosen_ent_groupby_label
chosen_ent_groupby_label = {l:{} for l in FILTER_LABELS}

# %%
[info for info in replacement_info if info["label"] == "GPE"]
# Out:
# [{'chosen_ent': 'Wales', 'replace_ent': 'Costa Rica', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'Murrayfield', 'label': 'GPE'},
#  {'chosen_ent': 'Sussex', 'replace_ent': 'Connecticut', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Blaenau Gwent', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Tyrone', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Berlin', 'label': 'GPE'},
#  {'chosen_ent': 'South Africa', 'replace_ent': 'Rhyl', 'label': 'GPE'},
#  {'chosen_ent': 'Portsmouth', 'replace_ent': 'Austria', 'label': 'GPE'},
#  {'chosen_ent': 'South Africa',
#   'replace_ent': 'Bury St Edmunds',
#   'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Texas', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Bavaria', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Eastbourne', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Norwich', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Bahrain', 'label': 'GPE'},
#  {'chosen_ent': 'South Africa', 'replace_ent': 'North Korea', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Fiji', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Holyrood', 'label': 'GPE'},
#  {'chosen_ent': 'Limavady', 'replace_ent': 'Northampton', 'label': 'GPE'},
#  {'chosen_ent': 'Huddersfield', 'replace_ent': 'Brasilia', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Hawick', 'label': 'GPE'},
#  {'chosen_ent': 'Brazil', 'replace_ent': 'Wellington', 'label': 'GPE'},
#  {'chosen_ent': 'Croydon', 'replace_ent': 'Cheltenham', 'label': 'GPE'},
#  {'chosen_ent': 'Tunisia', 'replace_ent': 'Truro', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Charleston', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': "Sri Lanka's", 'label': 'GPE'},
#  {'chosen_ent': 'England',
#   'replace_ent': 'East Dunbartonshire',
#   'label': 'GPE'},
#  {'chosen_ent': 'Qatar', 'replace_ent': 'Kathmandu', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Bath', 'label': 'GPE'},
#  {'chosen_ent': 'North Korea', 'replace_ent': 'Chelsea', 'label': 'GPE'},
#  {'chosen_ent': 'Zimbabwe', 'replace_ent': 'Monrovia', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Montreal', 'label': 'GPE'},
#  {'chosen_ent': 'Derby', 'replace_ent': 'Bootle', 'label': 'GPE'},
#  {'chosen_ent': 'Prestwick',
#   'replace_ent': 'Republic of Ireland',
#   'label': 'GPE'},
#  {'chosen_ent': 'France', 'replace_ent': 'East Yorkshire', 'label': 'GPE'},
#  {'chosen_ent': 'Greece', 'replace_ent': 'Huntingdon', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Conwy', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'South Korea', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'Gower', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Merthyr Tydfil', 'label': 'GPE'},
#  {'chosen_ent': 'Hillsborough', 'replace_ent': 'Motherwell', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Sunderland', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Denbighshire', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Angus', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Rhondda', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Hillsborough', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Slovenia', 'label': 'GPE'},
#  {'chosen_ent': 'Sydney', 'replace_ent': 'Bootle', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Oxfordshire', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Kolkata', 'label': 'GPE'},
#  {'chosen_ent': 'Kinshasa', 'replace_ent': 'Plymouth', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Vermont', 'label': 'GPE'},
#  {'chosen_ent': 'Motherwell', 'replace_ent': 'Milan', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Switzerland', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'Bedfordshire',
#   'label': 'GPE'},
#  {'chosen_ent': 'North Korea', 'replace_ent': 'Derby', 'label': 'GPE'},
#  {'chosen_ent': "South Korea's", 'replace_ent': 'Alabama', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Chichester', 'label': 'GPE'},
#  {'chosen_ent': 'Turkey', 'replace_ent': 'Norway', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Knightsbridge', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Corby', 'label': 'GPE'},
#  {'chosen_ent': 'Guinea', 'replace_ent': 'Bangalore', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Normandy', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Oldham', 'label': 'GPE'},
#  {'chosen_ent': 'Britain', 'replace_ent': 'Runcorn', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Montenegro', 'label': 'GPE'},
#  {'chosen_ent': 'Dhaka', 'replace_ent': 'Conwy', 'label': 'GPE'},
#  {'chosen_ent': 'Nottingham', 'replace_ent': "Saudi Arabia's", 'label': 'GPE'},
#  {'chosen_ent': 'Dumfries',
#   'replace_ent': 'the United Kingdom',
#   'label': 'GPE'},
#  {'chosen_ent': 'Britain', 'replace_ent': "North Korea's", 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Burnley', 'label': 'GPE'},
#  {'chosen_ent': 'Chicago', 'replace_ent': 'Llangollen', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Norfolk', 'label': 'GPE'},
#  {'chosen_ent': 'Malawi', 'replace_ent': 'Soviet Union', 'label': 'GPE'},
#  {'chosen_ent': 'Sydney', 'replace_ent': 'Inverness', 'label': 'GPE'},
#  {'chosen_ent': 'Newport', 'replace_ent': 'Pretoria', 'label': 'GPE'},
#  {'chosen_ent': 'Shetland', 'replace_ent': 'Singapore', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'New Hampshire', 'label': 'GPE'},
#  {'chosen_ent': 'Netherlands', 'replace_ent': 'Kuala Lumpur', 'label': 'GPE'},
#  {'chosen_ent': 'Dallas', 'replace_ent': 'Bosnia', 'label': 'GPE'},
#  {'chosen_ent': 'Bissau', 'replace_ent': 'Nepal', 'label': 'GPE'},
#  {'chosen_ent': 'Western Australia', 'replace_ent': 'Uruguay', 'label': 'GPE'},
#  {'chosen_ent': 'Botswana', 'replace_ent': 'Lochaber', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Fukushima', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Bollywood', 'label': 'GPE'},
#  {'chosen_ent': 'Myanmar', 'replace_ent': 'Macedonia', 'label': 'GPE'},
#  {'chosen_ent': 'the Dominican Republic',
#   'replace_ent': "Hong Kong's",
#   'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Caerphilly', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Port Talbot', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Falklands', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Telford', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Milton Keynes', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Hungary', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Togo', 'label': 'GPE'},
#  {'chosen_ent': 'Malta', 'replace_ent': 'Warsaw', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Oxford', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Jerusalem', 'label': 'GPE'},
#  {'chosen_ent': 'Merseyside', 'replace_ent': 'North', 'label': 'GPE'},
#  {'chosen_ent': 'County Down', 'replace_ent': 'Neath', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Merthyr Tydfil', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'New South Wales', 'label': 'GPE'},
#  {'chosen_ent': 'Bahrain', 'replace_ent': 'Washington DC', 'label': 'GPE'},
#  {'chosen_ent': 'Guernsey', 'replace_ent': 'Gwynedd', 'label': 'GPE'},
#  {'chosen_ent': 'Kingussie', 'replace_ent': 'Slovakia', 'label': 'GPE'},
#  {'chosen_ent': 'Birmingham', 'replace_ent': 'Czech Republic', 'label': 'GPE'},
#  {'chosen_ent': 'Venezuela', 'replace_ent': 'Charleston', 'label': 'GPE'},
#  {'chosen_ent': 'Hanoi', 'replace_ent': 'Mold', 'label': 'GPE'},
#  {'chosen_ent': 'Argentina', 'replace_ent': 'Lille', 'label': 'GPE'},
#  {'chosen_ent': 'Italy', 'replace_ent': 'EU', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Bollywood', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Wigan', 'label': 'GPE'},
#  {'chosen_ent': 'Caracas', 'replace_ent': 'Brighton', 'label': 'GPE'},
#  {'chosen_ent': 'Lancashire',
#   'replace_ent': 'Clackmannanshire',
#   'label': 'GPE'},
#  {'chosen_ent': 'Cameroon', 'replace_ent': 'Sutton Coldfield', 'label': 'GPE'},
#  {'chosen_ent': 'Burundi', 'replace_ent': 'Rhyl', 'label': 'GPE'},
#  {'chosen_ent': 'France', 'replace_ent': 'Aldershot', 'label': 'GPE'},
#  {'chosen_ent': 'Goa', 'replace_ent': 'Baku', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Clydebank', 'label': 'GPE'},
#  {'chosen_ent': 'Falkirk', 'replace_ent': 'Bahrain', 'label': 'GPE'},
#  {'chosen_ent': 'Texas', 'replace_ent': "Great Britain's", 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Burnley', 'label': 'GPE'},
#  {'chosen_ent': 'Bolivia', 'replace_ent': 'Neath Port Talbot', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Gatwick', 'label': 'GPE'},
#  {'chosen_ent': 'Texas', 'replace_ent': 'Wisconsin', 'label': 'GPE'},
#  {'chosen_ent': 'Chile', 'replace_ent': 'Sweden', 'label': 'GPE'},
#  {'chosen_ent': 'Afghanistan', 'replace_ent': 'Vienna', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Belgium', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'DR Congo', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Huddersfield', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': "Saudi Arabia's", 'label': 'GPE'},
#  {'chosen_ent': 'Iraq', 'replace_ent': 'CAR', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'Milford Haven',
#   'label': 'GPE'},
#  {'chosen_ent': 'Bangladesh', 'replace_ent': 'Grangemouth', 'label': 'GPE'},
#  {'chosen_ent': 'Liberia', 'replace_ent': 'Somalia', 'label': 'GPE'},
#  {'chosen_ent': 'Inverness',
#   'replace_ent': 'Neath Port Talbot',
#   'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Oman', 'label': 'GPE'},
#  {'chosen_ent': 'Oxford', 'replace_ent': 'North Wales', 'label': 'GPE'},
#  {'chosen_ent': 'Jordan', 'replace_ent': 'Galway', 'label': 'GPE'},
#  {'chosen_ent': 'Israel', 'replace_ent': 'West Bank', 'label': 'GPE'},
#  {'chosen_ent': 'Uzbekistan', 'replace_ent': 'Texas', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Kilmarnock', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'St Albans',
#   'label': 'GPE'},
#  {'chosen_ent': 'Belgium', 'replace_ent': 'Bishop Auckland', 'label': 'GPE'},
#  {'chosen_ent': 'Beijing', 'replace_ent': 'Powys', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Raqqa', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Buxton', 'label': 'GPE'},
#  {'chosen_ent': 'Chechnya',
#   'replace_ent': 'The United States',
#   'label': 'GPE'},
#  {'chosen_ent': 'Mumbai', 'replace_ent': 'St Albans', 'label': 'GPE'},
#  {'chosen_ent': 'Hampshire', 'replace_ent': 'Alexandria', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Alaska', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Maryland', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Blaenau Gwent', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Berkshire', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'South Africa', 'label': 'GPE'},
#  {'chosen_ent': 'York', 'replace_ent': 'Stormont', 'label': 'GPE'},
#  {'chosen_ent': 'Cuba', 'replace_ent': 'Mumbai', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Kirkcaldy', 'label': 'GPE'},
#  {'chosen_ent': 'South Africa', 'replace_ent': 'Zambia', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'St Louis', 'label': 'GPE'},
#  {'chosen_ent': 'Dumfries', 'replace_ent': 'Romford', 'label': 'GPE'},
#  {'chosen_ent': 'New Zealand', 'replace_ent': 'Canterbury', 'label': 'GPE'},
#  {'chosen_ent': 'Bhutan', 'replace_ent': 'Runcorn', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Stafford', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Devon', 'label': 'GPE'},
#  {'chosen_ent': 'Egypt', 'replace_ent': 'Tower Hamlets', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Luton', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Aberdeenshire', 'label': 'GPE'},
#  {'chosen_ent': 'South Africa', 'replace_ent': 'Rome', 'label': 'GPE'},
#  {'chosen_ent': 'Monmouth', 'replace_ent': 'Brasilia', 'label': 'GPE'},
#  {'chosen_ent': 'Monmouth', 'replace_ent': 'Oxfordshire', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'West Bengal', 'label': 'GPE'},
#  {'chosen_ent': 'Birmingham', 'replace_ent': 'South Carolina', 'label': 'GPE'},
#  {'chosen_ent': 'Debaltseve', 'replace_ent': 'Oman', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Pyongyang', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Sutton Coldfield', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Sydney', 'label': 'GPE'},
#  {'chosen_ent': 'Orange', 'replace_ent': 'Zambia', 'label': 'GPE'},
#  {'chosen_ent': 'Suffolk', 'replace_ent': 'Zurich', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Pretoria', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Derbyshire', 'label': 'GPE'},
#  {'chosen_ent': 'Birmingham', 'replace_ent': 'Huddersfield', 'label': 'GPE'},
#  {'chosen_ent': 'Germany', 'replace_ent': 'Malawi', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Runcorn', 'label': 'GPE'},
#  {'chosen_ent': 'West Yorkshire', 'replace_ent': 'Milan', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Slough', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Tibet', 'label': 'GPE'},
#  {'chosen_ent': 'Bristol', 'replace_ent': 'Ghana', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Exeter', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Papua New Guinea', 'label': 'GPE'},
#  {'chosen_ent': 'Stockholm', 'replace_ent': 'Homs', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Lancashire', 'label': 'GPE'},
#  {'chosen_ent': 'Wiltshire', 'replace_ent': 'Batley', 'label': 'GPE'},
#  {'chosen_ent': 'Cornwall', 'replace_ent': 'Austin', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'East Anglia', 'label': 'GPE'},
#  {'chosen_ent': 'Raqqa', 'replace_ent': 'Tottenham', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'The Hague', 'label': 'GPE'},
#  {'chosen_ent': 'Cornwall', 'replace_ent': 'Cumbernauld', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Chongqing', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Italy', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Las Vegas', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Harrogate', 'label': 'GPE'},
#  {'chosen_ent': 'Holywell', 'replace_ent': 'Snowdonia', 'label': 'GPE'},
#  {'chosen_ent': 'Brazil', 'replace_ent': 'Iran', 'label': 'GPE'},
#  {'chosen_ent': 'Essex', 'replace_ent': 'DR Congo', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Seoul', 'label': 'GPE'},
#  {'chosen_ent': 'Ivory Coast', 'replace_ent': 'Brazil', 'label': 'GPE'},
#  {'chosen_ent': 'Iraq', 'replace_ent': 'County Louth', 'label': 'GPE'},
#  {'chosen_ent': 'Ukraine', 'replace_ent': 'Dewsbury', 'label': 'GPE'},
#  {'chosen_ent': 'Lancashire', 'replace_ent': 'Georgia', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Aviemore', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'Paraguay', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'East Germany', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'North Wales', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Philippines', 'label': 'GPE'},
#  {'chosen_ent': 'North Korea',
#   'replace_ent': 'the Republic of Ireland',
#   'label': 'GPE'},
#  {'chosen_ent': 'Las Vegas', 'replace_ent': 'Boston', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Greater Manchester', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Sarajevo', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Cologne', 'label': 'GPE'},
#  {'chosen_ent': 'Stafford', 'replace_ent': 'Blackburn', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Derby', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Limavady', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Africa', 'label': 'GPE'},
#  {'chosen_ent': 'Cambridgeshire', 'replace_ent': 'Slough', 'label': 'GPE'},
#  {'chosen_ent': 'Somalia', 'replace_ent': 'New York City', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Cambridge', 'label': 'GPE'},
#  {'chosen_ent': 'Brighton', 'replace_ent': 'County Down', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Milan', 'label': 'GPE'},
#  {'chosen_ent': 'Denbighshire', 'replace_ent': 'Sandwell', 'label': 'GPE'},
#  {'chosen_ent': 'Nottingham', 'replace_ent': 'Great Yarmouth', 'label': 'GPE'},
#  {'chosen_ent': 'Glasgow', 'replace_ent': 'Welshpool', 'label': 'GPE'},
#  {'chosen_ent': 'Swansea', 'replace_ent': 'Wolverhampton', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Bournemouth', 'label': 'GPE'},
#  {'chosen_ent': 'Carrbridge', 'replace_ent': 'Europe', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Palestine', 'label': 'GPE'},
#  {'chosen_ent': 'West Norfolk', 'replace_ent': 'Loughborough', 'label': 'GPE'},
#  {'chosen_ent': 'Calais', 'replace_ent': 'Cologne', 'label': 'GPE'},
#  {'chosen_ent': 'Gaza', 'replace_ent': 'Elgin', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Philadelphia', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Argyll', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Ulster', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Africa', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Sunderland', 'label': 'GPE'},
#  {'chosen_ent': 'Nottingham', 'replace_ent': 'EU', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Rhondda Cynon Taff', 'label': 'GPE'},
#  {'chosen_ent': 'Finland', 'replace_ent': 'Gloucestershire', 'label': 'GPE'},
#  {'chosen_ent': 'Bangladesh', 'replace_ent': 'Shanghai', 'label': 'GPE'},
#  {'chosen_ent': 'Dundee', 'replace_ent': 'Buxton', 'label': 'GPE'},
#  {'chosen_ent': 'Fife', 'replace_ent': 'Karachi', 'label': 'GPE'},
#  {'chosen_ent': 'Merseyside', 'replace_ent': 'Lambeth', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Sousse', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'Indonesia',
#   'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'North Wales', 'label': 'GPE'},
#  {'chosen_ent': 'Oxfordshire', 'replace_ent': 'Burkina Faso', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Hammersmith', 'label': 'GPE'},
#  {'chosen_ent': 'Malaysia', 'replace_ent': 'Eastleigh', 'label': 'GPE'},
#  {'chosen_ent': 'Ethiopia', 'replace_ent': 'Hammersmith', 'label': 'GPE'},
#  {'chosen_ent': 'Hong Kong', 'replace_ent': 'Bedfordshire', 'label': 'GPE'},
#  {'chosen_ent': 'Tower Hamlets',
#   'replace_ent': 'United Kingdom',
#   'label': 'GPE'},
#  {'chosen_ent': 'Thailand', 'replace_ent': 'Cheshire', 'label': 'GPE'},
#  {'chosen_ent': 'Ireland', 'replace_ent': 'Punjab', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Maharashtra', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Great Yarmouth', 'label': 'GPE'},
#  {'chosen_ent': 'Spain', 'replace_ent': 'Oxfordshire', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'West Bank', 'label': 'GPE'},
#  {'chosen_ent': 'Moray', 'replace_ent': 'Detroit', 'label': 'GPE'},
#  {'chosen_ent': 'Lesotho', 'replace_ent': 'Homs', 'label': 'GPE'},
#  {'chosen_ent': 'Baltimore', 'replace_ent': 'Antigua', 'label': 'GPE'},
#  {'chosen_ent': 'Turkey', 'replace_ent': 'Seoul', 'label': 'GPE'},
#  {'chosen_ent': 'Japan', 'replace_ent': 'Blackburn', 'label': 'GPE'},
#  {'chosen_ent': 'Nottingham', 'replace_ent': 'Leeds', 'label': 'GPE'},
#  {'chosen_ent': 'Aberystwyth', 'replace_ent': 'Srebrenica', 'label': 'GPE'},
#  {'chosen_ent': 'Afghanistan', 'replace_ent': 'Crimea', 'label': 'GPE'},
#  {'chosen_ent': 'Mexico', 'replace_ent': 'Bahrain', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Torbay', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Jedburgh', 'label': 'GPE'},
#  {'chosen_ent': 'Newcastle', 'replace_ent': 'Middleton', 'label': 'GPE'},
#  {'chosen_ent': 'Dublin', 'replace_ent': 'Wirral', 'label': 'GPE'},
#  {'chosen_ent': 'Wakefield', 'replace_ent': 'Kolkata', 'label': 'GPE'},
#  {'chosen_ent': 'Didcot', 'replace_ent': 'eurozone', 'label': 'GPE'},
#  {'chosen_ent': 'Guernsey',
#   'replace_ent': 'West Dunbartonshire',
#   'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Michigan', 'label': 'GPE'},
#  {'chosen_ent': 'Sussex', 'replace_ent': 'Indiana', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Salisbury', 'label': 'GPE'},
#  {'chosen_ent': 'Anglesey', 'replace_ent': 'Huddersfield', 'label': 'GPE'},
#  {'chosen_ent': 'North Korea', 'replace_ent': 'West Sussex', 'label': 'GPE'},
#  {'chosen_ent': 'South Africa', 'replace_ent': 'Myanmar', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Handsworth', 'label': 'GPE'},
#  {'chosen_ent': 'Poland', 'replace_ent': 'Croydon', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Northampton', 'label': 'GPE'},
#  {'chosen_ent': 'Nice', 'replace_ent': 'Athens', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'Gwynedd', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'St Andrews', 'label': 'GPE'},
#  {'chosen_ent': 'Egypt', 'replace_ent': 'Dorset', 'label': 'GPE'},
#  {'chosen_ent': 'Oxford', 'replace_ent': 'Bahrain', 'label': 'GPE'},
#  {'chosen_ent': 'Zimbabwe', 'replace_ent': 'New Jersey', 'label': 'GPE'},
#  {'chosen_ent': 'Greenland',
#   'replace_ent': 'West Dunbartonshire',
#   'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Georgia', 'label': 'GPE'},
#  {'chosen_ent': 'Portsmouth', 'replace_ent': 'Down', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Orkney', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Kuala Lumpur', 'label': 'GPE'},
#  {'chosen_ent': 'Chicago', 'replace_ent': 'Kiev', 'label': 'GPE'},
#  {'chosen_ent': 'Homs', 'replace_ent': 'the Soviet Union', 'label': 'GPE'},
#  {'chosen_ent': 'Abkhazia', 'replace_ent': 'Eastbourne', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Barnsley', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'Warrington', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Hamburg', 'label': 'GPE'},
#  {'chosen_ent': 'Birmingham', 'replace_ent': "Hong Kong's", 'label': 'GPE'},
#  {'chosen_ent': 'Glasgow', 'replace_ent': 'Canterbury', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Brooklyn', 'label': 'GPE'},
#  {'chosen_ent': 'Northampton', 'replace_ent': 'Radnorshire', 'label': 'GPE'},
#  {'chosen_ent': 'Chile', 'replace_ent': 'USA', 'label': 'GPE'},
#  {'chosen_ent': 'Israel', 'replace_ent': 'Malawi', 'label': 'GPE'},
#  {'chosen_ent': 'Kenya', 'replace_ent': 'Oman', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Belfast', 'label': 'GPE'},
#  {'chosen_ent': 'South Korea', 'replace_ent': 'Donetsk', 'label': 'GPE'},
#  {'chosen_ent': "South Africa's", 'replace_ent': 'Macedonia', 'label': 'GPE'},
#  {'chosen_ent': 'Alaska', 'replace_ent': 'Iraq', 'label': 'GPE'},
#  {'chosen_ent': 'Swindon', 'replace_ent': 'Rome', 'label': 'GPE'},
#  {'chosen_ent': 'Coleraine', 'replace_ent': 'Brexit', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Truro', 'label': 'GPE'},
#  {'chosen_ent': 'Aberfan', 'replace_ent': 'Arizona', 'label': 'GPE'},
#  {'chosen_ent': 'Nottingham', 'replace_ent': 'Denbighshire', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Rwanda', 'label': 'GPE'},
#  {'chosen_ent': 'America', 'replace_ent': 'County Fermanagh', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'East Anglia', 'label': 'GPE'},
#  {'chosen_ent': 'Chernobyl', 'replace_ent': 'Newry', 'label': 'GPE'},
#  {'chosen_ent': 'Northamptonshire',
#   'replace_ent': 'Twickenham',
#   'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'North Wales', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Milford Haven', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'Egypt', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Lincolnshire', 'label': 'GPE'},
#  {'chosen_ent': 'Lincoln', 'replace_ent': 'Westminster', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Tel Aviv', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Glamorgan', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Liverpool', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Bridgend', 'label': 'GPE'},
#  {'chosen_ent': 'Garissa', 'replace_ent': 'Quebec', 'label': 'GPE'},
#  {'chosen_ent': 'Ghana', 'replace_ent': 'Dover', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Motherwell', 'label': 'GPE'},
#  {'chosen_ent': 'Hillsborough', 'replace_ent': 'Shoreham', 'label': 'GPE'},
#  {'chosen_ent': 'Nottinghamshire', 'replace_ent': 'Brecon', 'label': 'GPE'},
#  {'chosen_ent': 'Cumbria', 'replace_ent': 'Glastonbury', 'label': 'GPE'},
#  {'chosen_ent': 'Sri Lanka', 'replace_ent': 'Dumbarton', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Japan', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Colwyn Bay', 'label': 'GPE'},
#  {'chosen_ent': 'Scarborough', 'replace_ent': 'Kuwait', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Dunfermline', 'label': 'GPE'},
#  {'chosen_ent': 'Baltimore', 'replace_ent': 'India', 'label': 'GPE'},
#  {'chosen_ent': 'Ravenscraig', 'replace_ent': 'Macedonia', 'label': 'GPE'},
#  {'chosen_ent': 'Aceh', 'replace_ent': 'Luton', 'label': 'GPE'},
#  {'chosen_ent': 'Paris', 'replace_ent': 'Budapest', 'label': 'GPE'},
#  {'chosen_ent': 'Germany', 'replace_ent': 'Rwanda', 'label': 'GPE'},
#  {'chosen_ent': 'Poland', 'replace_ent': 'Hammersmith', 'label': 'GPE'},
#  {'chosen_ent': 'Romania', 'replace_ent': 'Brazil', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Jedburgh', 'label': 'GPE'},
#  {'chosen_ent': 'Paris', 'replace_ent': 'the Czech Republic', 'label': 'GPE'},
#  {'chosen_ent': 'Sussex', 'replace_ent': 'Middleton', 'label': 'GPE'},
#  {'chosen_ent': 'Germany', 'replace_ent': 'NI', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'China', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Durban', 'label': 'GPE'},
#  {'chosen_ent': 'Bristol', 'replace_ent': 'Teesside', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Soviet Union', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Argyll', 'label': 'GPE'},
#  {'chosen_ent': 'Dundee', 'replace_ent': 'Ipswich', 'label': 'GPE'},
#  {'chosen_ent': 'Comoros', 'replace_ent': 'Michigan', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Bordeaux', 'label': 'GPE'},
#  {'chosen_ent': 'Saudi Arabia', 'replace_ent': 'Dorset', 'label': 'GPE'},
#  {'chosen_ent': 'Hertfordshire', 'replace_ent': 'Lewisham', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Norfolk', 'label': 'GPE'},
#  {'chosen_ent': 'Yorkshire', 'replace_ent': 'Botswana', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Srebrenica', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Commonwealth', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Lambeth', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Ferguson', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Hove', 'label': 'GPE'},
#  {'chosen_ent': 'Hungary', 'replace_ent': 'Devon', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'North Carolina', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Nottinghamshire', 'label': 'GPE'},
#  {'chosen_ent': 'Mumbai', 'replace_ent': 'West Bengal', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Windsor', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'Coleraine', 'label': 'GPE'},
#  {'chosen_ent': 'Italy', 'replace_ent': 'Inverclyde', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Ivory Coast', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'New York City', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Mauritania', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'St Petersburg', 'label': 'GPE'},
#  {'chosen_ent': 'Iran', 'replace_ent': 'Adelaide', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Tweedbank', 'label': 'GPE'},
#  {'chosen_ent': 'Gibraltar', 'replace_ent': 'Limavady', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Guinea', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Warrington', 'label': 'GPE'},
#  {'chosen_ent': 'Cuba', 'replace_ent': 'Shrewsbury', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'New Orleans', 'label': 'GPE'},
#  {'chosen_ent': 'Woolwich', 'replace_ent': 'Uruguay', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Trowbridge', 'label': 'GPE'},
#  {'chosen_ent': 'Shoreham', 'replace_ent': 'Falklands', 'label': 'GPE'},
#  {'chosen_ent': 'Aberdeen', 'replace_ent': 'Pakistan', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Korea', 'label': 'GPE'},
#  {'chosen_ent': 'Ballyliffin', 'replace_ent': 'Croatia', 'label': 'GPE'},
#  {'chosen_ent': 'Ireland', 'replace_ent': 'Renfrewshire', 'label': 'GPE'},
#  {'chosen_ent': 'St Abbs', 'replace_ent': 'Aylesbury', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'The Hague', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Belgium', 'label': 'GPE'},
#  {'chosen_ent': 'Brazil', 'replace_ent': 'Tonga', 'label': 'GPE'},
#  {'chosen_ent': 'York', 'replace_ent': 'Karachi', 'label': 'GPE'},
#  {'chosen_ent': 'Zimbabwe', 'replace_ent': 'Clackmannanshire', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Guernsey', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Pennsylvania', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Dover', 'label': 'GPE'},
#  {'chosen_ent': 'Dewsbury', 'replace_ent': 'Illinois', 'label': 'GPE'},
#  {'chosen_ent': 'Yeovilton', 'replace_ent': 'Estonia', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Beirut', 'label': 'GPE'},
#  {'chosen_ent': 'Turkey', 'replace_ent': 'West Sussex', 'label': 'GPE'},
#  {'chosen_ent': 'Fukushima', 'replace_ent': 'North Wales', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Gambia', 'label': 'GPE'},
#  {'chosen_ent': 'Port Talbot', 'replace_ent': 'Headingley', 'label': 'GPE'},
#  {'chosen_ent': 'Serbia', 'replace_ent': 'Scotland', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Colorado', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Damascus', 'label': 'GPE'},
#  {'chosen_ent': 'Florida', 'replace_ent': 'Warsaw', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Buxton', 'label': 'GPE'},
#  {'chosen_ent': 'Lancashire', 'replace_ent': 'England', 'label': 'GPE'},
#  {'chosen_ent': 'Ghana', 'replace_ent': 'Hong Kong', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Newcastle', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'NI', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Middlesex', 'label': 'GPE'},
#  {'chosen_ent': 'Cambodia', 'replace_ent': 'Gillingham', 'label': 'GPE'},
#  {'chosen_ent': 'Oz', 'replace_ent': 'Newtownabbey', 'label': 'GPE'},
#  {'chosen_ent': 'Guernsey', 'replace_ent': 'Windsor', 'label': 'GPE'},
#  {'chosen_ent': 'Inverness', 'replace_ent': 'Merthyr', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Paris', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Lagos', 'label': 'GPE'},
#  {'chosen_ent': 'Hastings', 'replace_ent': 'Edgbaston', 'label': 'GPE'},
#  {'chosen_ent': 'Sydney', 'replace_ent': 'East Renfrewshire', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Iran', 'label': 'GPE'},
#  {'chosen_ent': 'Azerbaijan', 'replace_ent': 'Angola', 'label': 'GPE'},
#  {'chosen_ent': 'Papua New Guinea',
#   'replace_ent': 'Maidenhead',
#   'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': "South Sudan's", 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Brazil', 'label': 'GPE'},
#  {'chosen_ent': 'Dover', 'replace_ent': 'North', 'label': 'GPE'},
#  {'chosen_ent': 'Gibraltar', 'replace_ent': 'Ipswich', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Liverpool', 'label': 'GPE'},
#  {'chosen_ent': 'Flintshire', 'replace_ent': 'West Lothian', 'label': 'GPE'},
#  {'chosen_ent': 'Florida', 'replace_ent': 'Sudan', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Kinross', 'label': 'GPE'},
#  {'chosen_ent': 'France', 'replace_ent': 'Chesterfield', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Oldham', 'label': 'GPE'},
#  {'chosen_ent': 'Bedfordshire', 'replace_ent': 'Wexford', 'label': 'GPE'},
#  {'chosen_ent': 'Reading', 'replace_ent': 'Dagenham', 'label': 'GPE'},
#  {'chosen_ent': 'Sri Lanka', 'replace_ent': 'Newry', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Castleford', 'label': 'GPE'},
#  {'chosen_ent': 'Dublin', 'replace_ent': 'Kirkcaldy', 'label': 'GPE'},
#  {'chosen_ent': 'Britain',
#   'replace_ent': 'the United States of America',
#   'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'St Helens', 'label': 'GPE'},
#  {'chosen_ent': 'Birmingham', 'replace_ent': 'Paraguay', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Barbados', 'label': 'GPE'},
#  {'chosen_ent': 'Italy', 'replace_ent': 'Runcorn', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Peterborough', 'label': 'GPE'},
#  {'chosen_ent': 'Brexit', 'replace_ent': 'States', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Carmarthenshire', 'label': 'GPE'},
#  {'chosen_ent': 'Britain', 'replace_ent': 'Neath Port Talbot', 'label': 'GPE'},
#  {'chosen_ent': 'Stafford', 'replace_ent': 'Coleraine', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Europe', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Zambia', 'label': 'GPE'},
#  {'chosen_ent': 'Istanbul',
#   'replace_ent': "Northern Ireland's",
#   'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Rhondda Cynon Taff', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Chibok', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Stormont', 'label': 'GPE'},
#  {'chosen_ent': 'Derbyshire', 'replace_ent': 'Egypt', 'label': 'GPE'},
#  {'chosen_ent': "South Africa's", 'replace_ent': 'Middleton', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Leinster', 'label': 'GPE'},
#  {'chosen_ent': 'Ukraine', 'replace_ent': 'Donegal', 'label': 'GPE'},
#  {'chosen_ent': 'Bedfordshire', 'replace_ent': 'Bollywood', 'label': 'GPE'},
#  {'chosen_ent': 'Kenya', 'replace_ent': 'Bath', 'label': 'GPE'},
#  {'chosen_ent': 'Liverpool', 'replace_ent': 'Strabane', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'West Lothian', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'Sao Paulo', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Kirkcaldy', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Flintshire', 'label': 'GPE'},
#  {'chosen_ent': 'Venezuela', 'replace_ent': 'Loughborough', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Cornwall', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Dubai', 'label': 'GPE'},
#  {'chosen_ent': 'Gujarat', 'replace_ent': "Saudi Arabia's", 'label': 'GPE'},
#  {'chosen_ent': 'Bangladesh', 'replace_ent': 'Paris', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Geneva', 'label': 'GPE'},
#  {'chosen_ent': 'Israel',
#   'replace_ent': 'South Gloucestershire',
#   'label': 'GPE'},
#  {'chosen_ent': 'Toronto', 'replace_ent': 'Papua New Guinea', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'LA', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Abidjan', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Penarth', 'label': 'GPE'},
#  {'chosen_ent': 'York', 'replace_ent': 'Carrickfergus', 'label': 'GPE'},
#  {'chosen_ent': 'Paris', 'replace_ent': 'Lille', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Moscow', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'North Wales', 'label': 'GPE'},
#  {'chosen_ent': 'Myanmar', 'replace_ent': 'Alaska', 'label': 'GPE'},
#  {'chosen_ent': 'County Down', 'replace_ent': 'Richmond', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Stockport', 'label': 'GPE'},
#  {'chosen_ent': 'Powys', 'replace_ent': 'Missouri', 'label': 'GPE'},
#  {'chosen_ent': 'Guernsey', 'replace_ent': 'Korea', 'label': 'GPE'},
#  {'chosen_ent': 'Leeds', 'replace_ent': 'Avon', 'label': 'GPE'},
#  {'chosen_ent': 'Mexico', 'replace_ent': 'Hertfordshire', 'label': 'GPE'},
#  {'chosen_ent': 'Shropshire', 'replace_ent': "South Africa's", 'label': 'GPE'},
#  {'chosen_ent': 'Canada', 'replace_ent': 'Oldbury', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Commonwealth', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Stockport', 'label': 'GPE'},
#  {'chosen_ent': 'Dunkirk', 'replace_ent': 'Kazakhstan', 'label': 'GPE'},
#  {'chosen_ent': 'Lincolnshire', 'replace_ent': 'West Bank', 'label': 'GPE'},
#  {'chosen_ent': 'Powys', 'replace_ent': 'Ivory Coast', 'label': 'GPE'},
#  {'chosen_ent': 'Japan', 'replace_ent': 'Xinjiang', 'label': 'GPE'},
#  {'chosen_ent': 'Greater Manchester', 'replace_ent': 'Leith', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Rutland', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Dewsbury', 'label': 'GPE'},
#  {'chosen_ent': 'Suffolk', 'replace_ent': 'Poole', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Pyongyang', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'Massachusetts', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Hastings', 'label': 'GPE'},
#  {'chosen_ent': 'North', 'replace_ent': 'Vancouver', 'label': 'GPE'},
#  {'chosen_ent': 'North Derbyshire',
#   'replace_ent': 'Clydebank',
#   'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'UAE', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Argentina', 'label': 'GPE'},
#  {'chosen_ent': 'Gower', 'replace_ent': 'UK', 'label': 'GPE'},
#  {'chosen_ent': 'Iran', 'replace_ent': 'Humberside', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Berkshire', 'label': 'GPE'},
#  {'chosen_ent': 'Kenya', 'replace_ent': 'Manchester', 'label': 'GPE'},
#  {'chosen_ent': 'North Dakota', 'replace_ent': 'Stratford', 'label': 'GPE'},
#  {'chosen_ent': 'Japan', 'replace_ent': 'Srebrenica', 'label': 'GPE'},
#  {'chosen_ent': 'Arizona', 'replace_ent': 'Headingley', 'label': 'GPE'},
#  {'chosen_ent': 'Dumfries', 'replace_ent': 'Slovakia', 'label': 'GPE'},
#  {'chosen_ent': 'Mosul', 'replace_ent': 'Huntingdon', 'label': 'GPE'},
#  {'chosen_ent': 'Derbyshire',
#   'replace_ent': 'the United Kingdom',
#   'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Dundee', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Paris', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Mexico City', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Stoke-on-Trent', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Cwmbran', 'label': 'GPE'},
#  {'chosen_ent': 'Mekong', 'replace_ent': 'Southwark', 'label': 'GPE'},
#  {'chosen_ent': 'Canterbury', 'replace_ent': 'Torquay', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Syria', 'label': 'GPE'},
#  {'chosen_ent': 'Ukraine', 'replace_ent': 'Lowestoft', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Homs', 'label': 'GPE'},
#  {'chosen_ent': 'Derbyshire', 'replace_ent': 'El Salvador', 'label': 'GPE'},
#  {'chosen_ent': 'Stornoway', 'replace_ent': 'Azerbaijan', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Stirling', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Kansas', 'label': 'GPE'},
#  {'chosen_ent': 'Scarborough', 'replace_ent': 'Merseyside', 'label': 'GPE'},
#  {'chosen_ent': 'Swansea', 'replace_ent': 'Phoenix', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'the British Isles', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Senedd', 'label': 'GPE'},
#  {'chosen_ent': 'New York', 'replace_ent': 'Iran', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'Murrayfield',
#   'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Boston', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Slovenia', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Europe', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Uttar Pradesh', 'label': 'GPE'},
#  {'chosen_ent': 'Honduras', 'replace_ent': 'Denmark', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Ghent', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'St Louis', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Alabama', 'label': 'GPE'},
#  {'chosen_ent': 'Bristol', 'replace_ent': 'Foyle', 'label': 'GPE'},
#  {'chosen_ent': 'Tibet', 'replace_ent': 'The United States', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'Cape Town', 'label': 'GPE'},
#  {'chosen_ent': 'New South Wales', 'replace_ent': 'Thailand', 'label': 'GPE'},
#  {'chosen_ent': 'Italy', 'replace_ent': 'Jersey', 'label': 'GPE'},
#  {'chosen_ent': 'Dumfries', 'replace_ent': 'Budapest', 'label': 'GPE'},
#  {'chosen_ent': 'Malaysia', 'replace_ent': 'Wrexham', 'label': 'GPE'},
#  {'chosen_ent': 'England',
#   'replace_ent': 'the Republic of Ireland',
#   'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': "South Sudan's", 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Bosnia', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'Lancaster', 'label': 'GPE'},
#  {'chosen_ent': 'Dumfries', 'replace_ent': 'Helmand', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Havana', 'label': 'GPE'},
#  {'chosen_ent': 'Mexico', 'replace_ent': 'Bolivia', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'County Tyrone', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Kilmarnock', 'label': 'GPE'},
#  {'chosen_ent': 'Belgium', 'replace_ent': 'Norwich', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Barking', 'label': 'GPE'},
#  {'chosen_ent': 'Ukraine', 'replace_ent': 'Sanaa', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Brooklyn', 'label': 'GPE'},
#  {'chosen_ent': "West Yorkshire's", 'replace_ent': 'Ayr', 'label': 'GPE'},
#  {'chosen_ent': 'Cambridge', 'replace_ent': 'Malaysia', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Czech Republic', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Lewes', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'West Bengal', 'label': 'GPE'},
#  {'chosen_ent': 'Helmand', 'replace_ent': 'Damascus', 'label': 'GPE'},
#  {'chosen_ent': 'Germany', 'replace_ent': 'London', 'label': 'GPE'},
#  {'chosen_ent': 'Mexico', 'replace_ent': 'Folkestone', 'label': 'GPE'},
#  {'chosen_ent': 'Surrey', 'replace_ent': 'Rwanda', 'label': 'GPE'},
#  {'chosen_ent': 'Dundee', 'replace_ent': 'Ballymena', 'label': 'GPE'},
#  {'chosen_ent': 'Worcestershire',
#   'replace_ent': 'the City of London',
#   'label': 'GPE'},
#  {'chosen_ent': 'Newtownabbey', 'replace_ent': 'Vietnam', 'label': 'GPE'},
#  {'chosen_ent': 'Bodrum', 'replace_ent': 'Sicily', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Baku', 'label': 'GPE'},
#  {'chosen_ent': 'Lagos', 'replace_ent': 'Wiltshire', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Tamil Nadu', 'label': 'GPE'},
#  {'chosen_ent': 'Galloway', 'replace_ent': 'Moldova', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Enfield', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'Auckland', 'label': 'GPE'},
#  {'chosen_ent': 'South Yorkshire', 'replace_ent': 'Fukushima', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Bulgaria', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Royston', 'label': 'GPE'},
#  {'chosen_ent': 'Malaysia', 'replace_ent': 'Humberside', 'label': 'GPE'},
#  {'chosen_ent': 'Turkey', 'replace_ent': 'Arizona', 'label': 'GPE'},
#  {'chosen_ent': 'Southend', 'replace_ent': 'Aviemore', 'label': 'GPE'},
#  {'chosen_ent': 'Poland', 'replace_ent': 'Brazil', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Chichester', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Londonderry', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Gosport', 'label': 'GPE'},
#  {'chosen_ent': 'Greece', 'replace_ent': 'Hungary', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Bridgend', 'label': 'GPE'},
#  {'chosen_ent': 'Egypt', 'replace_ent': 'Glasgow', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Eastleigh', 'label': 'GPE'},
#  {'chosen_ent': 'Crawley', 'replace_ent': 'Alaska', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Bradford', 'label': 'GPE'},
#  {'chosen_ent': 'Egypt', 'replace_ent': 'Barrow', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Estonia', 'label': 'GPE'},
#  {'chosen_ent': 'Winnipeg', 'replace_ent': 'Djibouti', 'label': 'GPE'},
#  {'chosen_ent': 'Libya', 'replace_ent': 'County Londonderry', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Alexandria', 'label': 'GPE'},
#  {'chosen_ent': 'Mogadishu', 'replace_ent': 'Motherwell', 'label': 'GPE'},
#  {'chosen_ent': 'Myanmar', 'replace_ent': 'Neath', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Rutland', 'label': 'GPE'},
#  {'chosen_ent': 'Lancashire', 'replace_ent': 'Niger', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Cincinnati', 'label': 'GPE'},
#  {'chosen_ent': 'Spain', 'replace_ent': 'Thailand', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Nevada', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Colorado', 'label': 'GPE'},
#  {'chosen_ent': 'Trawsfynydd', 'replace_ent': 'Croydon', 'label': 'GPE'},
#  {'chosen_ent': 'Tunisia', 'replace_ent': 'Milton Keynes', 'label': 'GPE'},
#  {'chosen_ent': 'Canada', 'replace_ent': 'Senegal', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Great Britain', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Taiwan', 'label': 'GPE'},
#  {'chosen_ent': 'Iraq', 'replace_ent': 'Western Australia', 'label': 'GPE'},
#  {'chosen_ent': 'Dover', 'replace_ent': 'Derry City', 'label': 'GPE'},
#  {'chosen_ent': 'Glastonbury', 'replace_ent': 'St Louis', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Solihull', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Congo', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Romania', 'label': 'GPE'},
#  {'chosen_ent': 'South Sudan', 'replace_ent': 'Tokyo', 'label': 'GPE'},
#  {'chosen_ent': 'Brazil', 'replace_ent': 'Somerset', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Newark', 'label': 'GPE'},
#  {'chosen_ent': 'Macau', 'replace_ent': 'Budapest', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Lisbon', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Birkenhead', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Newry', 'label': 'GPE'},
#  {'chosen_ent': 'Vietnam', 'replace_ent': 'Baghdad', 'label': 'GPE'},
#  {'chosen_ent': 'Britain', 'replace_ent': 'Lambeth', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'the Soviet Union', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Benghazi', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Clacton', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'South Yorkshire', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Tanzania', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Wellington', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'the United Kingdom', 'label': 'GPE'},
#  {'chosen_ent': 'Israel', 'replace_ent': 'Lewis', 'label': 'GPE'},
#  {'chosen_ent': 'Georgia', 'replace_ent': 'Harrow', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Brexit', 'label': 'GPE'},
#  {'chosen_ent': 'Kano', 'replace_ent': 'Dover', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Stirling', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Tripoli', 'label': 'GPE'},
#  {'chosen_ent': 'Greece', 'replace_ent': 'Chicago', 'label': 'GPE'},
#  {'chosen_ent': 'Monaghan', 'replace_ent': 'EU', 'label': 'GPE'},
#  {'chosen_ent': 'Glasgow', 'replace_ent': 'Armagh', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Worcester', 'label': 'GPE'},
#  {'chosen_ent': 'Tamil Nadu', 'replace_ent': 'Livingston', 'label': 'GPE'},
#  {'chosen_ent': 'Shenzhen', 'replace_ent': 'Homs', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Newtownards', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Luxembourg', 'label': 'GPE'},
#  {'chosen_ent': 'Dumfries', 'replace_ent': 'Hollywood', 'label': 'GPE'},
# ...
#  {'chosen_ent': 'China', 'replace_ent': 'Jedburgh', 'label': 'GPE'},
#  {'chosen_ent': 'Paris', 'replace_ent': 'Salford', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Holland', 'label': 'GPE'},
#  {'chosen_ent': 'Eastbourne', 'replace_ent': 'Manhattan', 'label': 'GPE'},
#  {'chosen_ent': 'Guinea', 'replace_ent': 'Leicester', 'label': 'GPE'},
#  {'chosen_ent': 'Lincolnshire', 'replace_ent': 'Baghdad', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Kathmandu', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Bulgaria', 'label': 'GPE'},
#  {'chosen_ent': 'Israel', 'replace_ent': 'Wellington', 'label': 'GPE'},
#  {'chosen_ent': 'Timbuktu', 'replace_ent': 'Runcorn', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Sunderland', 'label': 'GPE'},
#  {'chosen_ent': 'Japan', 'replace_ent': 'Austria', 'label': 'GPE'},
#  {'chosen_ent': 'Libya', 'replace_ent': 'Carmarthen', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Sri Lanka', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'San Antonio', 'label': 'GPE'},
#  {'chosen_ent': 'Leicester', 'replace_ent': 'Walthamstow', 'label': 'GPE'},
#  {'chosen_ent': 'Greater Manchester', 'replace_ent': 'Malmo', 'label': 'GPE'},
#  {'chosen_ent': 'North Korea', 'replace_ent': 'Austria', 'label': 'GPE'},
#  {'chosen_ent': 'Powys', 'replace_ent': 'Dorset', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Rotterdam', 'label': 'GPE'},
#  {'chosen_ent': 'Bangkok', 'replace_ent': 'Kolkata', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Australia', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Kazan', 'label': 'GPE'},
#  {'chosen_ent': 'Staffordshire',
#   'replace_ent': 'Denbighshire',
#   'label': 'GPE'},
#  {'chosen_ent': 'Milan', 'replace_ent': 'Grantham', 'label': 'GPE'},
#  {'chosen_ent': 'Devon', 'replace_ent': 'Orlando', 'label': 'GPE'},
#  {'chosen_ent': 'Beijing', 'replace_ent': 'Iran', 'label': 'GPE'},
#  {'chosen_ent': 'Libya', 'replace_ent': 'Hawick', 'label': 'GPE'},
#  {'chosen_ent': 'Bangladesh', 'replace_ent': 'Colorado', 'label': 'GPE'},
#  {'chosen_ent': 'Malaysia', 'replace_ent': 'Essex', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Cwmbran', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Malawi', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Mozambique', 'label': 'GPE'},
#  {'chosen_ent': 'Hull', 'replace_ent': 'the United Kingdom', 'label': 'GPE'},
#  {'chosen_ent': 'Austria', 'replace_ent': 'Sudan', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'Staffordshire',
#   'label': 'GPE'},
#  {'chosen_ent': 'Ireland', 'replace_ent': 'Mexico City', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Oslo', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Czech Republic', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Sierra Leone', 'label': 'GPE'},
#  {'chosen_ent': 'Newcastle', 'replace_ent': 'Sri Lanka', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Calcutta', 'label': 'GPE'},
#  {'chosen_ent': 'Gloucestershire', 'replace_ent': 'Munich', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Adelaide', 'label': 'GPE'},
#  {'chosen_ent': 'Portsmouth', 'replace_ent': 'Homs', 'label': 'GPE'},
#  {'chosen_ent': 'Salgar', 'replace_ent': 'Midlothian', 'label': 'GPE'},
#  {'chosen_ent': 'Venezuela', 'replace_ent': 'New York', 'label': 'GPE'},
#  {'chosen_ent': 'Russia', 'replace_ent': 'West Lothian', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'West Midlands', 'label': 'GPE'},
#  {'chosen_ent': 'Birmingham', 'replace_ent': 'New York City', 'label': 'GPE'},
#  {'chosen_ent': 'Anglesey', 'replace_ent': 'Switzerland', 'label': 'GPE'},
#  {'chosen_ent': 'Cumbria', 'replace_ent': 'Xinjiang', 'label': 'GPE'},
#  {'chosen_ent': 'Somali', 'replace_ent': 'Milford Haven', 'label': 'GPE'},
#  {'chosen_ent': 'Spain', 'replace_ent': 'Blackpool', 'label': 'GPE'},
#  {'chosen_ent': 'Jersey', 'replace_ent': 'Guernsey', 'label': 'GPE'},
#  {'chosen_ent': 'Wrexham', 'replace_ent': 'Togo', 'label': 'GPE'},
#  {'chosen_ent': 'Cumbria', 'replace_ent': 'Missouri', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Calcutta', 'label': 'GPE'},
#  {'chosen_ent': 'Brazil', 'replace_ent': 'Trinidad', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Kerry', 'label': 'GPE'},
#  {'chosen_ent': 'Britain', 'replace_ent': 'Palestine', 'label': 'GPE'},
#  {'chosen_ent': 'Somerset', 'replace_ent': 'Perthshire', 'label': 'GPE'},
#  {'chosen_ent': 'California', 'replace_ent': 'Copenhagen', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Tel Aviv', 'label': 'GPE'},
#  {'chosen_ent': 'Israel', 'replace_ent': 'Shetland', 'label': 'GPE'},
#  {'chosen_ent': 'Cardiff', 'replace_ent': 'Richmond', 'label': 'GPE'},
#  {'chosen_ent': 'France', 'replace_ent': 'Deeside', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Oslo', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Cleveland', 'label': 'GPE'},
#  {'chosen_ent': 'Greece', 'replace_ent': "South Africa's", 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Staffordshire', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Rhondda Cynon Taff', 'label': 'GPE'},
#  {'chosen_ent': 'Guinea', 'replace_ent': 'Tanzania', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Northamptonshire', 'label': 'GPE'},
#  {'chosen_ent': 'Morelos', 'replace_ent': 'Afghanistan', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Fiji', 'label': 'GPE'},
#  {'chosen_ent': 'Greece', 'replace_ent': 'Stoke-on-Trent', 'label': 'GPE'},
#  {'chosen_ent': 'Aberdeen', 'replace_ent': 'Rochdale', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Wirral', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Derry', 'label': 'GPE'},
#  {'chosen_ent': 'Didcot', 'replace_ent': "North Korea's", 'label': 'GPE'},
#  {'chosen_ent': 'Brussels', 'replace_ent': 'New Hampshire', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Ontario', 'label': 'GPE'},
#  {'chosen_ent': 'Derby', 'replace_ent': 'Ayr', 'label': 'GPE'},
#  {'chosen_ent': 'Canada', 'replace_ent': 'Tanzania', 'label': 'GPE'},
#  {'chosen_ent': 'Lancashire', 'replace_ent': 'Kentucky', 'label': 'GPE'},
#  {'chosen_ent': 'Plymouth', 'replace_ent': 'Orlando', 'label': 'GPE'},
#  {'chosen_ent': 'Gloucestershire',
#   'replace_ent': 'Loughborough',
#   'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Philadelphia', 'label': 'GPE'},
#  {'chosen_ent': 'Lincolnshire', 'replace_ent': 'Minsk', 'label': 'GPE'},
#  {'chosen_ent': 'Norfolk', 'replace_ent': 'Bangui', 'label': 'GPE'},
#  {'chosen_ent': 'North Korea', 'replace_ent': 'Austria', 'label': 'GPE'},
#  {'chosen_ent': 'Lancashire', 'replace_ent': 'Dewsbury', 'label': 'GPE'},
#  {'chosen_ent': 'Govan', 'replace_ent': 'Stockport', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Equatorial Guinea', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Lagos', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Ballymena', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'the West Bank', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Europe', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Bishop Auckland', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Kuala Lumpur', 'label': 'GPE'},
#  {'chosen_ent': 'Tunisia', 'replace_ent': 'Sweden', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Zambia', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Alabama', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Sao Paulo', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Mozambique', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Lincolnshire', 'label': 'GPE'},
#  {'chosen_ent': 'Glamorgan', 'replace_ent': 'Bordeaux', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Ferguson', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Copenhagen', 'label': 'GPE'},
#  {'chosen_ent': 'Afghanistan', 'replace_ent': 'Shirebrook', 'label': 'GPE'},
#  {'chosen_ent': 'Mogadishu', 'replace_ent': 'Amsterdam', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Kosovo', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Deir al-Zour', 'label': 'GPE'},
#  {'chosen_ent': 'Rwanda', 'replace_ent': 'Haiti', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'West Yorkshire', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Dover', 'label': 'GPE'},
#  {'chosen_ent': 'Sheffield', 'replace_ent': 'Barry', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'Castleford',
#   'label': 'GPE'},
#  {'chosen_ent': 'Guyana', 'replace_ent': 'Armenia', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Havana', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Argyll', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Warwickshire', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Palestine', 'label': 'GPE'},
#  {'chosen_ent': 'Manchester', 'replace_ent': 'Oman', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Antigua', 'label': 'GPE'},
#  {'chosen_ent': 'Siachen', 'replace_ent': 'Rutland', 'label': 'GPE'},
#  {'chosen_ent': 'Humberside', 'replace_ent': 'Carrickfergus', 'label': 'GPE'},
#  {'chosen_ent': 'Newport', 'replace_ent': 'Peterborough', 'label': 'GPE'},
#  {'chosen_ent': 'Ukraine', 'replace_ent': 'West Yorkshire', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Portrush', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Cambridge', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Kurdistan', 'label': 'GPE'},
#  {'chosen_ent': 'Sri Lanka', 'replace_ent': 'Mongolia', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'NI', 'label': 'GPE'},
#  {'chosen_ent': 'Skye', 'replace_ent': "South Africa's", 'label': 'GPE'},
#  {'chosen_ent': 'Bangkok', 'replace_ent': 'Houston', 'label': 'GPE'},
#  {'chosen_ent': 'Warwickshire', 'replace_ent': 'Baku', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Peebles', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Merseyside', 'label': 'GPE'},
#  {'chosen_ent': 'Pakistan', 'replace_ent': 'Mali', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Lurgan', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Miami', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'Rhondda', 'label': 'GPE'},
#  {'chosen_ent': 'Wales', 'replace_ent': 'Durham', 'label': 'GPE'},
#  {'chosen_ent': 'South Yorkshire', 'replace_ent': 'Nicaragua', 'label': 'GPE'},
#  {'chosen_ent': 'Powys', 'replace_ent': 'Gambia', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Rio de Janeiro', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland', 'replace_ent': 'Ipswich', 'label': 'GPE'},
#  {'chosen_ent': 'Warwickshire', 'replace_ent': 'Neath', 'label': 'GPE'},
#  {'chosen_ent': 'Bangladesh', 'replace_ent': 'Bath', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Palestine', 'label': 'GPE'},
#  {'chosen_ent': 'Botswana', 'replace_ent': 'Walthamstow', 'label': 'GPE'},
#  {'chosen_ent': 'Brussels', 'replace_ent': 'Bradford', 'label': 'GPE'},
#  {'chosen_ent': 'London', 'replace_ent': 'Kathmandu', 'label': 'GPE'},
#  {'chosen_ent': 'Japan', 'replace_ent': 'Moray', 'label': 'GPE'},
#  {'chosen_ent': 'Kenya', 'replace_ent': 'Dundee', 'label': 'GPE'},
#  {'chosen_ent': 'Vanuatu', 'replace_ent': 'Douglas', 'label': 'GPE'},
#  {'chosen_ent': 'Mexico', 'replace_ent': 'Northamptonshire', 'label': 'GPE'},
#  {'chosen_ent': 'Edinburgh', 'replace_ent': 'Powys', 'label': 'GPE'},
#  {'chosen_ent': 'Germany', 'replace_ent': 'the West Midlands', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Twickenham', 'label': 'GPE'},
#  {'chosen_ent': 'Lincoln', 'replace_ent': 'Rhyl', 'label': 'GPE'},
#  {'chosen_ent': 'Northern Ireland',
#   'replace_ent': 'Tower Hamlets',
#   'label': 'GPE'},
#  {'chosen_ent': 'Lincolnshire', 'replace_ent': 'West Bank', 'label': 'GPE'},
#  {'chosen_ent': 'Australia', 'replace_ent': 'Punjab', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Fermanagh', 'label': 'GPE'},
#  {'chosen_ent': 'Philippines', 'replace_ent': 'Cincinnati', 'label': 'GPE'},
#  {'chosen_ent': 'China', 'replace_ent': 'DR Congo', 'label': 'GPE'},
#  {'chosen_ent': 'Bath', 'replace_ent': 'Harare', 'label': 'GPE'},
#  {'chosen_ent': 'Ghana', 'replace_ent': 'Los Angeles', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Maidstone', 'label': 'GPE'},
#  {'chosen_ent': 'Bahrain', 'replace_ent': 'EU', 'label': 'GPE'},
#  {'chosen_ent': 'Virginia', 'replace_ent': 'Mold', 'label': 'GPE'},
#  {'chosen_ent': 'Liverpool', 'replace_ent': 'Karachi', 'label': 'GPE'},
#  {'chosen_ent': 'India', 'replace_ent': 'Germany', 'label': 'GPE'},
#  {'chosen_ent': 'Sheffield', 'replace_ent': 'Barbados', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Staffordshire', 'label': 'GPE'},
#  {'chosen_ent': 'Ireland', 'replace_ent': 'Kilmarnock', 'label': 'GPE'},
#  {'chosen_ent': 'Sweden', 'replace_ent': 'Stratford', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Eastleigh', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'Vale of Glamorgan', 'label': 'GPE'},
#  {'chosen_ent': 'Georgia', 'replace_ent': 'Peterborough', 'label': 'GPE'},
#  {'chosen_ent': 'Ghana', 'replace_ent': 'Sanaa', 'label': 'GPE'},
#  {'chosen_ent': 'Nepal', 'replace_ent': 'Chelmsford', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Stormont', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Southport', 'label': 'GPE'},
#  {'chosen_ent': 'Bristol', 'replace_ent': 'Grangemouth', 'label': 'GPE'},
#  {'chosen_ent': 'Ireland', 'replace_ent': 'Mauritania', 'label': 'GPE'},
#  {'chosen_ent': 'Luton', 'replace_ent': 'Walsall', 'label': 'GPE'},
#  {'chosen_ent': 'Mauritius', 'replace_ent': 'Cambridge', 'label': 'GPE'},
#  {'chosen_ent': 'UK', 'replace_ent': 'Paisley', 'label': 'GPE'},
#  {'chosen_ent': 'New Zealand', 'replace_ent': 'Glasgow', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Lille', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland',
#   'replace_ent': 'Western Australia',
#   'label': 'GPE'},
#  {'chosen_ent': 'Stafford', 'replace_ent': 'Brazil', 'label': 'GPE'},
#  {'chosen_ent': 'Nottingham', 'replace_ent': 'Midlothian', 'label': 'GPE'},
#  {'chosen_ent': 'Germany', 'replace_ent': 'Barrow', 'label': 'GPE'},
#  {'chosen_ent': 'Uganda', 'replace_ent': 'Colchester', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Neath', 'label': 'GPE'},
#  {'chosen_ent': 'Malta', 'replace_ent': 'Gambia', 'label': 'GPE'},
#  {'chosen_ent': 'Libya', 'replace_ent': 'Shetland', 'label': 'GPE'},
#  {'chosen_ent': 'Ireland', 'replace_ent': 'Nevada', 'label': 'GPE'},
#  {'chosen_ent': 'Nigeria', 'replace_ent': 'Michigan', 'label': 'GPE'},
#  {'chosen_ent': 'Hungary', 'replace_ent': 'Mozambique', 'label': 'GPE'},
#  {'chosen_ent': 'Hong Kong', 'replace_ent': 'Belarus', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Stockport', 'label': 'GPE'},
#  {'chosen_ent': 'Liverpool', 'replace_ent': 'Lisbon', 'label': 'GPE'},
#  {'chosen_ent': 'Belfast', 'replace_ent': 'Aberystwyth', 'label': 'GPE'},
#  {'chosen_ent': 'Derby', 'replace_ent': 'Vienna', 'label': 'GPE'},
#  {'chosen_ent': 'Somerset', 'replace_ent': 'Monmouthshire', 'label': 'GPE'},
#  {'chosen_ent': 'Britain', 'replace_ent': 'Loughborough', 'label': 'GPE'},
#  {'chosen_ent': 'Glastonbury', 'replace_ent': 'Florence', 'label': 'GPE'},
#  {'chosen_ent': 'Scotland', 'replace_ent': 'Prague', 'label': 'GPE'},
#  {'chosen_ent': 'Chennai', 'replace_ent': 'Stormont', 'label': 'GPE'},
#  {'chosen_ent': 'Armagh', 'replace_ent': 'Galashiels', 'label': 'GPE'},
#  {'chosen_ent': 'England', 'replace_ent': 'Telford', 'label': 'GPE'},
#  {'chosen_ent': 'Ireland', 'replace_ent': 'Motherwell', 'label': 'GPE'},
#  {'chosen_ent': 'Yorkshire', 'replace_ent': 'Dallas', 'label': 'GPE'},
#  {'chosen_ent': 'Greece', 'replace_ent': 'Australia', 'label': 'GPE'},
#  {'chosen_ent': 'Syria', 'replace_ent': 'the United Kingdom', 'label': 'GPE'},
#  {'chosen_ent': 'Singapore', 'replace_ent': 'Southwark', 'label': 'GPE'},
#  {'chosen_ent': 'US', 'replace_ent': 'Islington', 'label': 'GPE'},
#  ...]

# %%
print("Stats of chosen entities")
for l in FILTER_LABELS:
    print(f"label: {l}, count: {len([_ for info in replacement_info if info['label'] == l])}")
# Out:
# Stats of chosen entities
# label: PERSON, count: 2585
# label: FAC, count: 123
# label: GPE, count: 2874
# label: NORP, count: 505
# label: LOC, count: 180
# label: EVENT, count: 102
# label: LANGUAGE, count: 13
# label: LAW, count: 9
# label: ORG, count: 2347

# %% [markdown]
# * 완전히 같은 entity 통일하기

# %% [markdown]
# # example 1

# %%
import spacy
from spacy import displacy
NER = spacy.load("en_core_web_sm")

# %%
raw_text="The Indian Space Research Organisation or is the national space agency of India, \
    headquartered in Bengaluru. It operates under Department of Space which is directly \
    overseen by the Prime Minister of India while Chairman of ISRO acts as executive of DOS as well."

# %%
raw_text2 = "The Mars Orbiter Mission (MOM), informally known as Mangalyaan, \
    was launched into Earth orbit on 5 November 2013 by the Indian Space Research Organisation (ISRO) \
    and has entered Mars orbit on 24 September 2014. India thus became the first country to enter \
    Mars orbit on its first attempt. It was completed at a record low cost of $74 million."

# %%
text = NER(raw_text2)

# %%
for word in text.ents:
    print(word.text,word.label_)
# Out:
# The Mars Orbiter Mission (MOM PRODUCT
# Mangalyaan PERSON
# Earth LOC
# 5 November 2013 DATE
# the Indian Space Research Organisation ORG
# Mars LOC
# 24 September 2014 DATE
# India GPE
# first ORDINAL
# Mars LOC
# $74 million MONEY

# %%
# list of ner labels
for ner_label in NER.get_pipe('ner').labels:
    print(f"* {ner_label}: {spacy.explain(ner_label)}")
# Out:
# * CARDINAL: Numerals that do not fall under another type
# * DATE: Absolute or relative dates or periods
# * EVENT: Named hurricanes, battles, wars, sports events, etc.
# * FAC: Buildings, airports, highways, bridges, etc.
# * GPE: Countries, cities, states
# * LANGUAGE: Any named language
# * LAW: Named documents made into laws.
# * LOC: Non-GPE locations, mountain ranges, bodies of water
# * MONEY: Monetary values, including unit
# * NORP: Nationalities or religious or political groups
# * ORDINAL: "first", "second", etc.
# * ORG: Companies, agencies, institutions, etc.
# * PERCENT: Percentage, including "%"
# * PERSON: People, including fictional
# * PRODUCT: Objects, vehicles, foods, etc. (not services)
# * QUANTITY: Measurements, as of weight or distance
# * TIME: Times smaller than a day
# * WORK_OF_ART: Titles of books, songs, etc.

# %%
displacy.render(text,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Mars Orbiter Mission (MOM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ), informally known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mangalyaan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,     was launched into
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  orbit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 November 2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian Space Research Organisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (ISRO)     and has entered
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  orbit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24 September 2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  thus became the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  country to enter
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  orbit on its first attempt. It was completed at a record low cost of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $74 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %% [markdown]
# # another example

# %%
# function to display basic entity info: 
def show_ents(doc):
    print(f"original doc: {doc.text}")
    if doc.ents: 
        for ent in doc.ents: 
            print(f"entity: {ent.text : >13} | start_char: {ent.start_char: 3} | end_char: {ent.end_char: 3} | label: {ent.label_} - {spacy.explain(ent.label_)}")
            # print(ent.label)  # entity type's hash value
            # print(ent.start)  # token span's start index position (word index)
            # print(ent.end)  # token span's stop index position (word index)
    else: print('No named entities found.')

# %%
doc1 = NER("Apple is looking at buying U.K. startup for $1 billion") 
show_ents(doc1)
# Out:
# original doc: Apple is looking at buying U.K. startup for $1 billion
# entity:         Apple | start_char:   0 | end_char:   5 | label: ORG - Companies, agencies, institutions, etc.
# entity:          U.K. | start_char:  27 | end_char:  31 | label: GPE - Countries, cities, states
# entity:    $1 billion | start_char:  44 | end_char:  54 | label: MONEY - Monetary values, including unit

# %% [markdown]
# ## document level

# %%
doc = NER("San Francisco considers banning sidewalk delivery robots") 
# document level 
for e in doc.ents: 
    print(e.text, e.start_char, e.end_char, e.label_) 

# OR 
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents] 
print(ents)
# Out:
# San Francisco 0 13 GPE
# [('San Francisco', 0, 13, 'GPE')]

# %% [markdown]
# ## token level

# %%
# token level 
# doc[0], doc[1] ...will have tokens stored. 

ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_] 
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
ent_considers = [doc[2].text, doc[2].ent_iob_, doc[2].ent_type_] 
print(ent_san) 
print(ent_francisco)
print(ent_considers)

# token.ent_iob indicates whether an entity starts continues or ends on the tag
# I - Token is inside an entity. 
# O - Token is outside an entity. 
# B - Token is the beginning of an entity.
# Out:
# ['San', 'B', 'GPE']
# ['Francisco', 'I', 'GPE']
# ['considers', 'O', '']

# %% [markdown]
# ## User-Defined Named Entity and Adding it to a Span

# %% [markdown]
# ### Example 1

# %%
doc = NER(u'Tesla to build a U.K. factory for $6 million.')
show_ents(doc)
# Out:
# original doc: Tesla to build a U.K. factory for $6 million.
# entity:          U.K. | start_char:  17 | end_char:  21 | label: GPE - Countries, cities, states
# entity:    $6 million | start_char:  34 | end_char:  44 | label: MONEY - Monetary values, including unit

# %%
from spacy.tokens import Span

# %%
# get the hash value of the ORG entity label
ORG = doc.vocab.strings[u"ORG"]
print(ORG)

# create a span for the new entity
new_ent = Span(doc=doc, start=0, end=1, label=ORG)
print(new_ent)

# add the entity to the existing doc object
doc.ents = list(doc.ents) + [new_ent]
print(doc.ents)
# Out:
# 383
# Tesla
# (Tesla, U.K., $6 million)

# %%
show_ents(doc)
# Out:
# original doc: Tesla to build a U.K. factory for $6 million.
# entity:         Tesla | start_char:   0 | end_char:   5 | label: ORG - Companies, agencies, institutions, etc.
# entity:          U.K. | start_char:  17 | end_char:  21 | label: GPE - Countries, cities, states
# entity:    $6 million | start_char:  34 | end_char:  44 | label: MONEY - Monetary values, including unit

# %% [markdown]
# ## Adding Named Entities to All Matching Spans

# %%
doc = NER(u'Our company plans to introduce a new vacuum cleaner. If successful, the vacuum cleaner will be our first product.') 
show_ents(doc)
# Out:
# original doc: Our company plans to introduce a new vacuum cleaner. If successful, the vacuum cleaner will be our first product.
# entity:         first | start_char:  99 | end_char:  104 | label: ORDINAL - "first", "second", etc.

# %%
# Import PhraseMatcher and create a matcher object: 
from spacy.matcher import PhraseMatcher 
matcher = PhraseMatcher(NER.vocab)

# %%
# Create the desired phrase patterns:
phrase_list = ['vacuum cleaner', 'vacuum-cleaner']
phrase_patterns = [NER(text) for text in phrase_list]
print(phrase_list)
print(phrase_patterns)
# Out:
# ['vacuum cleaner', 'vacuum-cleaner']
# [vacuum cleaner, vacuum-cleaner]

# %%
# Apply the patterns to our matcher object:
matcher.add('newproduct', None, *phrase_patterns)

# %%
# Apply the matcher to our Doc object:
matches = matcher(doc)
#See what matches occur: 
matches
# Out:
# [(2689272359382549672, 7, 9), (2689272359382549672, 14, 16)]

# %%
# Here we create Spans from each match, and create named entities from them: 
from spacy.tokens import Span 
PROD = doc.vocab.strings[u'PRODUCT'] 
new_ents = [Span(doc, match[1], match[2],label=PROD) for match in matches]
new_ents
# Out:
# [vacuum cleaner, vacuum cleaner]

# %%
# match[1] contains the start index of the the token and match[2] the stop index (exclusive) of the token in the doc. 
doc.ents = list(doc.ents) + new_ents 
show_ents(doc)
# Out:
# original doc: Our company plans to introduce a new vacuum cleaner. If successful, the vacuum cleaner will be our first product.
# entity: vacuum cleaner | start_char:  37 | end_char:  51 | label: PRODUCT - Objects, vehicles, foods, etc. (not services)
# entity: vacuum cleaner | start_char:  72 | end_char:  86 | label: PRODUCT - Objects, vehicles, foods, etc. (not services)
# entity:         first | start_char:  99 | end_char:  104 | label: ORDINAL - "first", "second", etc.

# %% [markdown]
# ## counting entities

# %%
doc = NER(u"originally priced at $29.50, now it's marked down to five dollars")
show_ents(doc)
# Out:
# original doc: originally priced at $29.50, now it's marked down to five dollars
# entity:         29.50 | start_char:  22 | end_char:  27 | label: MONEY - Monetary values, including unit
# entity:  five dollars | start_char:  53 | end_char:  65 | label: MONEY - Monetary values, including unit

# %%
len([ent for ent in doc.ents if ent.label_ == "MONEY"])
# Out:
# 2

# %% [markdown]
# ## Visualizing NER

# %%
from spacy import displacy

# %%
doc = NER(u"Tesla to build a U.K. factory for $6 million. "
          u"originally priced at $29.50, now it's marked down to five dollars")
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tesla to build a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . originally priced at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , now it's marked down to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
# line by line
for sent in doc.sents:
    displacy.render(sent, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tesla to build a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">originally priced at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , now it's marked down to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
# viewing specific entries
options = {"ents": ["MONEY"]}
displacy.render(doc, style="ent", jupyter=True, options = options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tesla to build a U.K. factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . originally priced at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , now it's marked down to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>
